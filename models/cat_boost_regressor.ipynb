# %%
import pandas as pd
from catboost import CatBoostRegressor
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score
import numpy as np

# %%
train_route = '../data/waiting_times_train.csv'
validation_route = '../data/waiting_times_X_test_val.csv'
test_route = '../data/waiting_times_X_test_final.csv'
weather_route = '../data/weather_data.csv'

train_file = pd.read_csv(train_route)
validation_file = pd.read_csv(validation_route)
test_file = pd.read_csv(test_route)
weather_file = pd.read_csv(weather_route)

# %%
X_train = train_file.copy()
X_train['DATETIME'] = pd.to_datetime(X_train['DATETIME'], errors='coerce')

weather_file['DATETIME'] = pd.to_datetime(weather_file['DATETIME'], errors='coerce')
weather_file = weather_file.fillna(0)

X_train = pd.merge(X_train, weather_file, on='DATETIME', how='left')
print(X_train.columns)
X_train['year'] = X_train['DATETIME'].dt.year
X_train['month'] = X_train['DATETIME'].dt.month
X_train['day'] = X_train['DATETIME'].dt.day
X_train['hour'] = X_train['DATETIME'].dt.hour
X_train['minute'] = X_train['DATETIME'].dt.minute

X_train['TIME_TO_PARADE_1'] = X_train['TIME_TO_PARADE_1'].fillna(250)
X_train['TIME_TO_PARADE_2'] = X_train['TIME_TO_PARADE_2'].fillna(0)

X_train = X_train.sort_values(by='DATETIME')
print(X_train.head())

# Fill NaNs by column
for col in X_train.select_dtypes(include=['number']).columns:
    # Compute mean and std of non-NaN values
    mean = X_train[col].mean()
    std = X_train[col].std()
    
    # Find number of NaNs
    n_nan = X_train[col].isna().sum()
    
    # Generate random numbers for NaNs
    random_values = np.random.normal(loc=mean, scale=std, size=n_nan)
    
    # Fill NaNs
    X_train.loc[X_train[col].isna(), col] = random_values

X_train = X_train.sort_index()
y_train = X_train['WAIT_TIME_IN_2H']
X_train = X_train.select_dtypes(include=['number']).drop(columns=['WAIT_TIME_IN_2H','DOWNTIME','minute','clouds_all'])
# Out:
# Index(['DATETIME', 'ENTITY_DESCRIPTION_SHORT', 'ADJUST_CAPACITY', 'DOWNTIME',
#        'CURRENT_WAIT_TIME', 'TIME_TO_PARADE_1', 'TIME_TO_PARADE_2',
#        'TIME_TO_NIGHT_SHOW', 'WAIT_TIME_IN_2H', 'temp', 'dew_point',
#        'feels_like', 'pressure', 'humidity', 'wind_speed', 'rain_1h',
#        'snow_1h', 'clouds_all'],
#       dtype='object')
#                  DATETIME ENTITY_DESCRIPTION_SHORT  ADJUST_CAPACITY  DOWNTIME  \
# 5927  2018-10-01 12:15:00               Water Ride            224.5         0
# 8149  2018-10-01 12:15:00           Flying Coaster            756.0         0
# 12003 2018-10-01 12:15:00              Pirate Ship            153.0         0
# 13978 2018-10-01 12:30:00              Pirate Ship            153.0         0
# 23029 2018-10-01 12:30:00               Water Ride            224.5         0
#
#        CURRENT_WAIT_TIME  TIME_TO_PARADE_1  TIME_TO_PARADE_2  \
# 5927                  20             315.0              -5.0
# 8149                  10             315.0              -5.0
# 12003                 25             315.0              -5.0
# 13978                 25             300.0             -20.0
# 23029                 20             300.0             -20.0
#
#        TIME_TO_NIGHT_SHOW  WAIT_TIME_IN_2H   temp  ...  humidity  wind_speed  \
# 5927                465.0             20.0  13.01  ...      60.0      5.7725
# 8149                465.0             10.0  13.01  ...      60.0      5.7725
# 12003               465.0             25.0  13.01  ...      60.0      5.7725
# 13978               450.0             25.0  13.25  ...      59.0      5.8750
# 23029               450.0             20.0  13.25  ...      59.0      5.8750
#
#        rain_1h  snow_1h  clouds_all  year  month  day  hour  minute
# 5927    0.1213      0.0        49.0  2018     10    1    12      15
# 8149    0.1213      0.0        49.0  2018     10    1    12      15
# 12003   0.1213      0.0        49.0  2018     10    1    12      15
# 13978   0.1226      0.0        53.0  2018     10    1    12      30
# 23029   0.1226      0.0        53.0  2018     10    1    12      30
#
# [5 rows x 23 columns]

# %%
optimized_estimators = 450
'''max_score = float('-inf')
for n in range(100, 5000, 100):
    model = XGBRegressor(n_estimators=n, learning_rate=0.1)
    scores = cross_val_score(model, X_train, y_train, scoring='neg_root_mean_squared_error', cv=5)
    score_mean = scores.mean()
    print(f"n_estimators: {n}, CV Mean RMSE: {-score_mean}")
    if score_mean > max_score:
        optimized_estimators = n
        max_score = score_mean'''



model = CatBoostRegressor(n_estimators=optimized_estimators, learning_rate=0.1, random_state=10)
scores = cross_val_score(model, X_train, y_train, scoring='neg_root_mean_squared_error', cv=5)
print(scores.mean(), scores.std())
model.fit(X_train, y_train)

y_pred = model.predict(X_train)
evaluate_model(y_train, y_pred)

importances = model.get_feature_importance()
feature_names = X_train.columns

for name, imp in zip(feature_names, importances):
    print(f"{name}: {imp:.4f}")
# Out:
# 0:	learn: 13.6939284	total: 7.22ms	remaining: 3.24s
# 1:	learn: 13.1832137	total: 13.7ms	remaining: 3.07s
# 2:	learn: 12.7519195	total: 18.4ms	remaining: 2.73s
# 3:	learn: 12.3671556	total: 22.8ms	remaining: 2.54s
# 4:	learn: 12.0347290	total: 29.2ms	remaining: 2.6s
# 5:	learn: 11.7486297	total: 35.1ms	remaining: 2.6s
# 6:	learn: 11.5052395	total: 40.5ms	remaining: 2.56s
# 7:	learn: 11.2905067	total: 46.8ms	remaining: 2.59s
# 8:	learn: 11.1044486	total: 51.3ms	remaining: 2.51s
# 9:	learn: 10.9360221	total: 55.7ms	remaining: 2.45s
# 10:	learn: 10.7969761	total: 62.8ms	remaining: 2.51s
# 11:	learn: 10.6736685	total: 70.8ms	remaining: 2.58s
# 12:	learn: 10.5604389	total: 78.7ms	remaining: 2.64s
# 13:	learn: 10.4625155	total: 87.5ms	remaining: 2.72s
# 14:	learn: 10.3762116	total: 93.4ms	remaining: 2.71s
# 15:	learn: 10.2974851	total: 99.8ms	remaining: 2.71s
# 16:	learn: 10.2214072	total: 104ms	remaining: 2.65s
# 17:	learn: 10.1589933	total: 110ms	remaining: 2.63s
# 18:	learn: 10.1005729	total: 115ms	remaining: 2.6s
# 19:	learn: 10.0450000	total: 119ms	remaining: 2.56s
# 20:	learn: 9.9945053	total: 125ms	remaining: 2.55s
# 21:	learn: 9.9452592	total: 129ms	remaining: 2.52s
# 22:	learn: 9.9034957	total: 134ms	remaining: 2.48s
# 23:	learn: 9.8625697	total: 139ms	remaining: 2.47s
# 24:	learn: 9.8252866	total: 144ms	remaining: 2.44s
# 25:	learn: 9.7868146	total: 148ms	remaining: 2.41s
# 26:	learn: 9.7629658	total: 152ms	remaining: 2.38s
# 27:	learn: 9.7397073	total: 160ms	remaining: 2.41s
# 28:	learn: 9.7175059	total: 165ms	remaining: 2.39s
# 29:	learn: 9.6878661	total: 169ms	remaining: 2.36s
# 30:	learn: 9.6595608	total: 175ms	remaining: 2.37s
# 31:	learn: 9.6316028	total: 180ms	remaining: 2.35s
# 32:	learn: 9.6096035	total: 184ms	remaining: 2.32s
# 33:	learn: 9.5829613	total: 191ms	remaining: 2.34s
# 34:	learn: 9.5586530	total: 196ms	remaining: 2.32s
# 35:	learn: 9.5310217	total: 200ms	remaining: 2.3s
# 36:	learn: 9.5102939	total: 209ms	remaining: 2.33s
# 37:	learn: 9.4819163	total: 213ms	remaining: 2.31s
# 38:	learn: 9.4614047	total: 220ms	remaining: 2.32s
# 39:	learn: 9.4425388	total: 224ms	remaining: 2.3s
# 40:	learn: 9.4232250	total: 229ms	remaining: 2.28s
# 41:	learn: 9.4025007	total: 234ms	remaining: 2.27s
# 42:	learn: 9.3862107	total: 239ms	remaining: 2.26s
# 43:	learn: 9.3731998	total: 243ms	remaining: 2.24s
# 44:	learn: 9.3647484	total: 248ms	remaining: 2.23s
# 45:	learn: 9.3502342	total: 255ms	remaining: 2.24s
# 46:	learn: 9.3294102	total: 259ms	remaining: 2.22s
# 47:	learn: 9.3124446	total: 263ms	remaining: 2.2s
# 48:	learn: 9.3002403	total: 270ms	remaining: 2.21s
# 49:	learn: 9.2892710	total: 275ms	remaining: 2.2s
# 50:	learn: 9.2672808	total: 279ms	remaining: 2.18s
# 51:	learn: 9.2529360	total: 285ms	remaining: 2.18s
# 52:	learn: 9.2446183	total: 289ms	remaining: 2.17s
# 53:	learn: 9.2309447	total: 294ms	remaining: 2.15s
# 54:	learn: 9.2119738	total: 299ms	remaining: 2.15s
# 55:	learn: 9.2008171	total: 304ms	remaining: 2.13s
# 56:	learn: 9.1927864	total: 307ms	remaining: 2.12s
# 57:	learn: 9.1775136	total: 313ms	remaining: 2.12s
# 58:	learn: 9.1634012	total: 318ms	remaining: 2.11s
# 59:	learn: 9.1518183	total: 322ms	remaining: 2.09s
# 60:	learn: 9.1445677	total: 326ms	remaining: 2.08s
# 61:	learn: 9.1298579	total: 335ms	remaining: 2.09s
# 62:	learn: 9.1142457	total: 339ms	remaining: 2.08s
# 63:	learn: 9.0992935	total: 345ms	remaining: 2.08s
# 64:	learn: 9.0888714	total: 350ms	remaining: 2.07s
# 65:	learn: 9.0775528	total: 354ms	remaining: 2.06s
# 66:	learn: 9.0669329	total: 359ms	remaining: 2.05s
# 67:	learn: 9.0595368	total: 364ms	remaining: 2.04s
# 68:	learn: 9.0479049	total: 368ms	remaining: 2.03s
# 69:	learn: 9.0358099	total: 374ms	remaining: 2.03s
# 70:	learn: 9.0281777	total: 380ms	remaining: 2.02s
# 71:	learn: 9.0195647	total: 384ms	remaining: 2.01s
# 72:	learn: 9.0100938	total: 388ms	remaining: 2s
# 73:	learn: 8.9986202	total: 393ms	remaining: 2s
# 74:	learn: 8.9869944	total: 398ms	remaining: 1.99s
# 75:	learn: 8.9827606	total: 402ms	remaining: 1.98s
# 76:	learn: 8.9702571	total: 407ms	remaining: 1.97s
# 77:	learn: 8.9589307	total: 412ms	remaining: 1.96s
# 78:	learn: 8.9533360	total: 416ms	remaining: 1.95s
# 79:	learn: 8.9411278	total: 421ms	remaining: 1.95s
# 80:	learn: 8.9318346	total: 426ms	remaining: 1.94s
# 81:	learn: 8.9227201	total: 431ms	remaining: 1.93s
# 82:	learn: 8.9184369	total: 435ms	remaining: 1.92s
# 83:	learn: 8.9103036	total: 440ms	remaining: 1.92s
# 84:	learn: 8.9004420	total: 445ms	remaining: 1.91s
# 85:	learn: 8.8907412	total: 450ms	remaining: 1.9s
# 86:	learn: 8.8819673	total: 455ms	remaining: 1.9s
# 87:	learn: 8.8703920	total: 463ms	remaining: 1.9s
# 88:	learn: 8.8609546	total: 470ms	remaining: 1.91s
# 89:	learn: 8.8538753	total: 476ms	remaining: 1.9s
# 90:	learn: 8.8458885	total: 480ms	remaining: 1.9s
# 91:	learn: 8.8384391	total: 485ms	remaining: 1.89s
# 92:	learn: 8.8331505	total: 492ms	remaining: 1.89s
# 93:	learn: 8.8270044	total: 496ms	remaining: 1.88s
# 94:	learn: 8.8180769	total: 500ms	remaining: 1.87s
# 95:	learn: 8.8125783	total: 507ms	remaining: 1.87s
# 96:	learn: 8.8084376	total: 511ms	remaining: 1.86s
# 97:	learn: 8.7978884	total: 516ms	remaining: 1.85s
# 98:	learn: 8.7926740	total: 523ms	remaining: 1.85s
# 99:	learn: 8.7878885	total: 528ms	remaining: 1.85s
# 100:	learn: 8.7799288	total: 536ms	remaining: 1.85s
# 101:	learn: 8.7696277	total: 541ms	remaining: 1.84s
# 102:	learn: 8.7595594	total: 546ms	remaining: 1.84s
# 103:	learn: 8.7486996	total: 554ms	remaining: 1.84s
# 104:	learn: 8.7435136	total: 559ms	remaining: 1.83s
# 105:	learn: 8.7400054	total: 564ms	remaining: 1.83s
# 106:	learn: 8.7343820	total: 571ms	remaining: 1.83s
# 107:	learn: 8.7263704	total: 576ms	remaining: 1.82s
# 108:	learn: 8.7170145	total: 584ms	remaining: 1.83s
# 109:	learn: 8.7104668	total: 589ms	remaining: 1.82s
# 110:	learn: 8.7029543	total: 597ms	remaining: 1.82s
# 111:	learn: 8.6956007	total: 605ms	remaining: 1.82s
# 112:	learn: 8.6870832	total: 611ms	remaining: 1.82s
# 113:	learn: 8.6788112	total: 618ms	remaining: 1.82s
# 114:	learn: 8.6699267	total: 625ms	remaining: 1.82s
# 115:	learn: 8.6625337	total: 631ms	remaining: 1.82s
# 116:	learn: 8.6539980	total: 637ms	remaining: 1.81s
# 117:	learn: 8.6484454	total: 642ms	remaining: 1.81s
# 118:	learn: 8.6429274	total: 649ms	remaining: 1.8s
# 119:	learn: 8.6368859	total: 655ms	remaining: 1.8s
# 120:	learn: 8.6287854	total: 662ms	remaining: 1.8s
# 121:	learn: 8.6228938	total: 668ms	remaining: 1.79s
# 122:	learn: 8.6151562	total: 673ms	remaining: 1.79s
# 123:	learn: 8.6078508	total: 678ms	remaining: 1.78s
# 124:	learn: 8.5997629	total: 682ms	remaining: 1.77s
# 125:	learn: 8.5907995	total: 686ms	remaining: 1.76s
# 126:	learn: 8.5839490	total: 691ms	remaining: 1.76s
# 127:	learn: 8.5769944	total: 696ms	remaining: 1.75s
# 128:	learn: 8.5692893	total: 700ms	remaining: 1.74s
# 129:	learn: 8.5625773	total: 704ms	remaining: 1.73s
# 130:	learn: 8.5506664	total: 710ms	remaining: 1.73s
# 131:	learn: 8.5437449	total: 715ms	remaining: 1.72s
# 132:	learn: 8.5378513	total: 719ms	remaining: 1.71s
# 133:	learn: 8.5294448	total: 725ms	remaining: 1.71s
# 134:	learn: 8.5243507	total: 731ms	remaining: 1.71s
# 135:	learn: 8.5179782	total: 737ms	remaining: 1.7s
# 136:	learn: 8.5103356	total: 743ms	remaining: 1.7s
# 137:	learn: 8.5040824	total: 748ms	remaining: 1.69s
# 138:	learn: 8.4955624	total: 752ms	remaining: 1.68s
# 139:	learn: 8.4875268	total: 758ms	remaining: 1.68s
# 140:	learn: 8.4814387	total: 763ms	remaining: 1.67s
# 141:	learn: 8.4757748	total: 767ms	remaining: 1.66s
# 142:	learn: 8.4666055	total: 773ms	remaining: 1.66s
# 143:	learn: 8.4601922	total: 777ms	remaining: 1.65s
# 144:	learn: 8.4526476	total: 781ms	remaining: 1.64s
# 145:	learn: 8.4443743	total: 786ms	remaining: 1.64s
# 146:	learn: 8.4383107	total: 792ms	remaining: 1.63s
# 147:	learn: 8.4311554	total: 796ms	remaining: 1.62s
# 148:	learn: 8.4287557	total: 800ms	remaining: 1.62s
# 149:	learn: 8.4249384	total: 806ms	remaining: 1.61s
# 150:	learn: 8.4190642	total: 811ms	remaining: 1.6s
# 151:	learn: 8.4119030	total: 815ms	remaining: 1.6s
# 152:	learn: 8.4048123	total: 822ms	remaining: 1.59s
# 153:	learn: 8.3973639	total: 826ms	remaining: 1.59s
# 154:	learn: 8.3900996	total: 831ms	remaining: 1.58s
# 155:	learn: 8.3851929	total: 836ms	remaining: 1.57s
# 156:	learn: 8.3815700	total: 840ms	remaining: 1.57s
# 157:	learn: 8.3760777	total: 844ms	remaining: 1.56s
# 158:	learn: 8.3708571	total: 851ms	remaining: 1.56s
# 159:	learn: 8.3673873	total: 856ms	remaining: 1.55s
# 160:	learn: 8.3618361	total: 861ms	remaining: 1.54s
# 161:	learn: 8.3562445	total: 871ms	remaining: 1.55s
# 162:	learn: 8.3530643	total: 875ms	remaining: 1.54s
# 163:	learn: 8.3480828	total: 880ms	remaining: 1.53s
# 164:	learn: 8.3432946	total: 885ms	remaining: 1.53s
# 165:	learn: 8.3365717	total: 889ms	remaining: 1.52s
# 166:	learn: 8.3350380	total: 893ms	remaining: 1.51s
# 167:	learn: 8.3296072	total: 899ms	remaining: 1.51s
# 168:	learn: 8.3240512	total: 903ms	remaining: 1.5s
# 169:	learn: 8.3184354	total: 908ms	remaining: 1.5s
# 170:	learn: 8.3124236	total: 914ms	remaining: 1.49s
# 171:	learn: 8.3071287	total: 918ms	remaining: 1.48s
# 172:	learn: 8.3005883	total: 924ms	remaining: 1.48s
# 173:	learn: 8.2961904	total: 929ms	remaining: 1.47s
# 174:	learn: 8.2913960	total: 933ms	remaining: 1.47s
# 175:	learn: 8.2863178	total: 938ms	remaining: 1.46s
# 176:	learn: 8.2802749	total: 942ms	remaining: 1.45s
# 177:	learn: 8.2758295	total: 947ms	remaining: 1.45s
# 178:	learn: 8.2715066	total: 953ms	remaining: 1.44s
# 179:	learn: 8.2697505	total: 957ms	remaining: 1.44s
# 180:	learn: 8.2655260	total: 962ms	remaining: 1.43s
# 181:	learn: 8.2618297	total: 966ms	remaining: 1.42s
# 182:	learn: 8.2576014	total: 971ms	remaining: 1.42s
# 183:	learn: 8.2561080	total: 976ms	remaining: 1.41s
# 184:	learn: 8.2508278	total: 981ms	remaining: 1.4s
# 185:	learn: 8.2447002	total: 985ms	remaining: 1.4s
# 186:	learn: 8.2421685	total: 989ms	remaining: 1.39s
# 187:	learn: 8.2357927	total: 994ms	remaining: 1.39s
# 188:	learn: 8.2313843	total: 1s	remaining: 1.38s
# 189:	learn: 8.2255043	total: 1.01s	remaining: 1.38s
# 190:	learn: 8.2182923	total: 1.01s	remaining: 1.37s
# 191:	learn: 8.2140475	total: 1.02s	remaining: 1.37s
# 192:	learn: 8.2076956	total: 1.02s	remaining: 1.36s
# 193:	learn: 8.2062693	total: 1.03s	remaining: 1.36s
# 194:	learn: 8.2001017	total: 1.03s	remaining: 1.35s
# 195:	learn: 8.1958271	total: 1.04s	remaining: 1.35s
# 196:	learn: 8.1935870	total: 1.04s	remaining: 1.34s
# 197:	learn: 8.1878541	total: 1.05s	remaining: 1.34s
# 198:	learn: 8.1826902	total: 1.06s	remaining: 1.33s
# 199:	learn: 8.1775753	total: 1.06s	remaining: 1.33s
# 200:	learn: 8.1708088	total: 1.06s	remaining: 1.32s
# 201:	learn: 8.1653543	total: 1.07s	remaining: 1.31s
# 202:	learn: 8.1600593	total: 1.08s	remaining: 1.31s
# 203:	learn: 8.1547084	total: 1.08s	remaining: 1.3s
# 204:	learn: 8.1494715	total: 1.08s	remaining: 1.3s
# 205:	learn: 8.1480182	total: 1.09s	remaining: 1.29s
# 206:	learn: 8.1469819	total: 1.09s	remaining: 1.28s
# 207:	learn: 8.1447593	total: 1.1s	remaining: 1.28s
# 208:	learn: 8.1394564	total: 1.1s	remaining: 1.27s
# 209:	learn: 8.1342914	total: 1.11s	remaining: 1.27s
# 210:	learn: 8.1266174	total: 1.11s	remaining: 1.26s
# 211:	learn: 8.1238628	total: 1.12s	remaining: 1.26s
# 212:	learn: 8.1199004	total: 1.12s	remaining: 1.25s
# 213:	learn: 8.1183296	total: 1.13s	remaining: 1.24s
# 214:	learn: 8.1132388	total: 1.14s	remaining: 1.24s
# 215:	learn: 8.1086709	total: 1.14s	remaining: 1.24s
# 216:	learn: 8.1026492	total: 1.15s	remaining: 1.23s
# 217:	learn: 8.0967126	total: 1.15s	remaining: 1.23s
# 218:	learn: 8.0894326	total: 1.16s	remaining: 1.22s
# 219:	learn: 8.0855169	total: 1.16s	remaining: 1.22s
# 220:	learn: 8.0811230	total: 1.17s	remaining: 1.21s
# 221:	learn: 8.0738998	total: 1.17s	remaining: 1.2s
# 222:	learn: 8.0699920	total: 1.18s	remaining: 1.2s
# 223:	learn: 8.0647670	total: 1.18s	remaining: 1.19s
# 224:	learn: 8.0592233	total: 1.19s	remaining: 1.19s
# 225:	learn: 8.0556177	total: 1.19s	remaining: 1.18s
# 226:	learn: 8.0523170	total: 1.2s	remaining: 1.18s
# 227:	learn: 8.0482059	total: 1.2s	remaining: 1.17s
# 228:	learn: 8.0430807	total: 1.21s	remaining: 1.17s
# 229:	learn: 8.0363886	total: 1.21s	remaining: 1.16s
# 230:	learn: 8.0318973	total: 1.22s	remaining: 1.16s
# 231:	learn: 8.0283950	total: 1.22s	remaining: 1.15s
# 232:	learn: 8.0243668	total: 1.23s	remaining: 1.14s
# 233:	learn: 8.0201979	total: 1.23s	remaining: 1.14s
# 234:	learn: 8.0154166	total: 1.24s	remaining: 1.13s
# 235:	learn: 8.0107600	total: 1.24s	remaining: 1.13s
# 236:	learn: 8.0072845	total: 1.25s	remaining: 1.12s
# 237:	learn: 8.0028189	total: 1.25s	remaining: 1.11s
# 238:	learn: 8.0004450	total: 1.26s	remaining: 1.11s
# 239:	learn: 7.9942975	total: 1.26s	remaining: 1.1s
# 240:	learn: 7.9890210	total: 1.27s	remaining: 1.1s
# 241:	learn: 7.9858519	total: 1.27s	remaining: 1.09s
# 242:	learn: 7.9826603	total: 1.28s	remaining: 1.09s
# 243:	learn: 7.9771469	total: 1.28s	remaining: 1.08s
# 244:	learn: 7.9707767	total: 1.29s	remaining: 1.08s
# 245:	learn: 7.9672689	total: 1.29s	remaining: 1.07s
# 246:	learn: 7.9631695	total: 1.3s	remaining: 1.07s
# 247:	learn: 7.9601072	total: 1.3s	remaining: 1.06s
# 248:	learn: 7.9575255	total: 1.31s	remaining: 1.05s
# 249:	learn: 7.9521413	total: 1.31s	remaining: 1.05s
# 250:	learn: 7.9472555	total: 1.32s	remaining: 1.04s
# 251:	learn: 7.9431838	total: 1.32s	remaining: 1.04s
# 252:	learn: 7.9388790	total: 1.33s	remaining: 1.03s
# 253:	learn: 7.9361075	total: 1.33s	remaining: 1.03s
# 254:	learn: 7.9323383	total: 1.33s	remaining: 1.02s
# 255:	learn: 7.9269677	total: 1.34s	remaining: 1.02s
# 256:	learn: 7.9229880	total: 1.34s	remaining: 1.01s
# 257:	learn: 7.9191043	total: 1.35s	remaining: 1s
# 258:	learn: 7.9143344	total: 1.35s	remaining: 1000ms
# 259:	learn: 7.9114008	total: 1.36s	remaining: 993ms
# 260:	learn: 7.9040828	total: 1.36s	remaining: 989ms
# 261:	learn: 7.8987756	total: 1.37s	remaining: 985ms
# 262:	learn: 7.8951215	total: 1.38s	remaining: 979ms
# 263:	learn: 7.8912380	total: 1.38s	remaining: 973ms
# 264:	learn: 7.8853635	total: 1.39s	remaining: 968ms
# 265:	learn: 7.8837555	total: 1.39s	remaining: 962ms
# 266:	learn: 7.8801330	total: 1.4s	remaining: 956ms
# 267:	learn: 7.8731244	total: 1.4s	remaining: 951ms
# 268:	learn: 7.8696552	total: 1.41s	remaining: 945ms
# 269:	learn: 7.8667548	total: 1.41s	remaining: 940ms
# 270:	learn: 7.8645553	total: 1.42s	remaining: 936ms
# 271:	learn: 7.8625082	total: 1.42s	remaining: 930ms
# 272:	learn: 7.8581845	total: 1.43s	remaining: 925ms
# 273:	learn: 7.8530603	total: 1.43s	remaining: 920ms
# 274:	learn: 7.8487507	total: 1.44s	remaining: 915ms
# 275:	learn: 7.8445269	total: 1.44s	remaining: 910ms
# 276:	learn: 7.8414447	total: 1.45s	remaining: 904ms
# 277:	learn: 7.8361772	total: 1.45s	remaining: 899ms
# 278:	learn: 7.8343345	total: 1.46s	remaining: 893ms
# 279:	learn: 7.8308892	total: 1.46s	remaining: 887ms
# 280:	learn: 7.8262896	total: 1.47s	remaining: 882ms
# 281:	learn: 7.8229016	total: 1.47s	remaining: 878ms
# 282:	learn: 7.8195338	total: 1.48s	remaining: 872ms
# 283:	learn: 7.8159444	total: 1.48s	remaining: 867ms
# 284:	learn: 7.8110050	total: 1.49s	remaining: 861ms
# 285:	learn: 7.8068751	total: 1.49s	remaining: 856ms
# 286:	learn: 7.8033276	total: 1.5s	remaining: 850ms
# 287:	learn: 7.7995211	total: 1.5s	remaining: 845ms
# 288:	learn: 7.7957616	total: 1.51s	remaining: 839ms
# 289:	learn: 7.7916338	total: 1.51s	remaining: 833ms
# 290:	learn: 7.7887840	total: 1.52s	remaining: 828ms
# 291:	learn: 7.7840832	total: 1.52s	remaining: 823ms
# 292:	learn: 7.7801910	total: 1.52s	remaining: 817ms
# 293:	learn: 7.7778750	total: 1.53s	remaining: 812ms
# 294:	learn: 7.7752760	total: 1.54s	remaining: 807ms
# 295:	learn: 7.7682985	total: 1.54s	remaining: 801ms
# 296:	learn: 7.7654782	total: 1.55s	remaining: 798ms
# 297:	learn: 7.7610229	total: 1.55s	remaining: 792ms
# 298:	learn: 7.7562188	total: 1.56s	remaining: 787ms
# 299:	learn: 7.7527034	total: 1.56s	remaining: 781ms
# 300:	learn: 7.7488995	total: 1.57s	remaining: 776ms
# 301:	learn: 7.7448454	total: 1.57s	remaining: 770ms
# 302:	learn: 7.7410705	total: 1.58s	remaining: 766ms
# 303:	learn: 7.7363723	total: 1.58s	remaining: 760ms
# 304:	learn: 7.7318904	total: 1.59s	remaining: 755ms
# 305:	learn: 7.7282058	total: 1.59s	remaining: 750ms
# 306:	learn: 7.7242879	total: 1.6s	remaining: 744ms
# 307:	learn: 7.7199321	total: 1.6s	remaining: 738ms
# 308:	learn: 7.7176729	total: 1.61s	remaining: 733ms
# 309:	learn: 7.7143869	total: 1.61s	remaining: 728ms
# 310:	learn: 7.7114608	total: 1.61s	remaining: 722ms
# 311:	learn: 7.7083073	total: 1.62s	remaining: 717ms
# 312:	learn: 7.7048580	total: 1.63s	remaining: 713ms
# 313:	learn: 7.7000945	total: 1.63s	remaining: 708ms
# 314:	learn: 7.6941024	total: 1.64s	remaining: 704ms
# 315:	learn: 7.6902128	total: 1.65s	remaining: 699ms
# 316:	learn: 7.6879154	total: 1.65s	remaining: 694ms
# 317:	learn: 7.6832205	total: 1.66s	remaining: 689ms
# 318:	learn: 7.6778758	total: 1.67s	remaining: 685ms
# 319:	learn: 7.6725039	total: 1.67s	remaining: 680ms
# 320:	learn: 7.6689433	total: 1.68s	remaining: 676ms
# 321:	learn: 7.6661512	total: 1.69s	remaining: 672ms
# 322:	learn: 7.6631999	total: 1.7s	remaining: 667ms
# 323:	learn: 7.6586492	total: 1.7s	remaining: 662ms
# 324:	learn: 7.6558811	total: 1.71s	remaining: 657ms
# 325:	learn: 7.6518130	total: 1.71s	remaining: 652ms
# 326:	learn: 7.6478788	total: 1.72s	remaining: 647ms
# 327:	learn: 7.6430140	total: 1.73s	remaining: 642ms
# 328:	learn: 7.6393956	total: 1.73s	remaining: 637ms
# 329:	learn: 7.6373559	total: 1.74s	remaining: 633ms
# 330:	learn: 7.6366705	total: 1.74s	remaining: 627ms
# 331:	learn: 7.6342833	total: 1.75s	remaining: 622ms
# 332:	learn: 7.6310765	total: 1.76s	remaining: 617ms
# 333:	learn: 7.6281068	total: 1.76s	remaining: 612ms
# 334:	learn: 7.6240566	total: 1.77s	remaining: 607ms
# 335:	learn: 7.6211971	total: 1.77s	remaining: 602ms
# 336:	learn: 7.6188953	total: 1.78s	remaining: 597ms
# 337:	learn: 7.6142618	total: 1.78s	remaining: 592ms
# 338:	learn: 7.6093681	total: 1.79s	remaining: 586ms
# 339:	learn: 7.6067276	total: 1.79s	remaining: 581ms
# 340:	learn: 7.6016935	total: 1.8s	remaining: 575ms
# 341:	learn: 7.5990193	total: 1.8s	remaining: 570ms
# 342:	learn: 7.5959137	total: 1.81s	remaining: 564ms
# 343:	learn: 7.5913563	total: 1.81s	remaining: 559ms
# 344:	learn: 7.5865113	total: 1.82s	remaining: 555ms
# 345:	learn: 7.5823706	total: 1.83s	remaining: 549ms
# 346:	learn: 7.5793051	total: 1.83s	remaining: 544ms
# 347:	learn: 7.5772676	total: 1.84s	remaining: 539ms
# 348:	learn: 7.5711569	total: 1.84s	remaining: 533ms
# 349:	learn: 7.5678310	total: 1.85s	remaining: 528ms
# 350:	learn: 7.5650365	total: 1.85s	remaining: 523ms
# 351:	learn: 7.5606863	total: 1.86s	remaining: 517ms
# 352:	learn: 7.5568322	total: 1.86s	remaining: 512ms
# 353:	learn: 7.5510410	total: 1.87s	remaining: 506ms
# 354:	learn: 7.5482600	total: 1.87s	remaining: 501ms
# 355:	learn: 7.5455529	total: 1.88s	remaining: 495ms
# 356:	learn: 7.5433874	total: 1.88s	remaining: 490ms
# 357:	learn: 7.5389392	total: 1.89s	remaining: 484ms
# 358:	learn: 7.5348944	total: 1.89s	remaining: 479ms
# 359:	learn: 7.5305667	total: 1.9s	remaining: 474ms
# 360:	learn: 7.5274512	total: 1.9s	remaining: 468ms
# 361:	learn: 7.5250064	total: 1.9s	remaining: 463ms
# 362:	learn: 7.5213029	total: 1.91s	remaining: 458ms
# 363:	learn: 7.5179641	total: 1.91s	remaining: 452ms
# 364:	learn: 7.5179033	total: 1.92s	remaining: 447ms
# 365:	learn: 7.5159300	total: 1.92s	remaining: 442ms
# 366:	learn: 7.5124045	total: 1.93s	remaining: 436ms
# 367:	learn: 7.5072761	total: 1.93s	remaining: 431ms
# 368:	learn: 7.5047799	total: 1.94s	remaining: 425ms
# 369:	learn: 7.5025498	total: 1.94s	remaining: 420ms
# 370:	learn: 7.4995530	total: 1.95s	remaining: 415ms
# 371:	learn: 7.4963151	total: 1.95s	remaining: 409ms
# 372:	learn: 7.4936478	total: 1.96s	remaining: 405ms
# 373:	learn: 7.4916142	total: 1.96s	remaining: 399ms
# 374:	learn: 7.4866578	total: 1.97s	remaining: 394ms
# 375:	learn: 7.4828279	total: 1.98s	remaining: 389ms
# 376:	learn: 7.4803461	total: 1.98s	remaining: 384ms
# 377:	learn: 7.4764147	total: 1.99s	remaining: 378ms
# 378:	learn: 7.4732879	total: 1.99s	remaining: 373ms
# 379:	learn: 7.4713138	total: 2s	remaining: 368ms
# 380:	learn: 7.4679090	total: 2s	remaining: 362ms
# 381:	learn: 7.4649947	total: 2s	remaining: 357ms
# 382:	learn: 7.4624437	total: 2.01s	remaining: 351ms
# 383:	learn: 7.4594610	total: 2.01s	remaining: 346ms
# 384:	learn: 7.4569477	total: 2.02s	remaining: 341ms
# 385:	learn: 7.4534340	total: 2.02s	remaining: 336ms
# 386:	learn: 7.4511756	total: 2.03s	remaining: 330ms
# 387:	learn: 7.4475456	total: 2.03s	remaining: 325ms
# 388:	learn: 7.4453505	total: 2.04s	remaining: 320ms
# 389:	learn: 7.4420536	total: 2.04s	remaining: 314ms
# 390:	learn: 7.4390731	total: 2.05s	remaining: 309ms
# 391:	learn: 7.4371314	total: 2.05s	remaining: 304ms
# 392:	learn: 7.4327475	total: 2.06s	remaining: 298ms
# 393:	learn: 7.4303553	total: 2.06s	remaining: 293ms
# 394:	learn: 7.4279819	total: 2.06s	remaining: 288ms
# 395:	learn: 7.4239033	total: 2.07s	remaining: 282ms
# 396:	learn: 7.4194881	total: 2.08s	remaining: 277ms
# 397:	learn: 7.4166214	total: 2.08s	remaining: 272ms
# 398:	learn: 7.4115926	total: 2.08s	remaining: 267ms
# 399:	learn: 7.4084392	total: 2.09s	remaining: 262ms
# 400:	learn: 7.4060166	total: 2.1s	remaining: 256ms
# 401:	learn: 7.4019165	total: 2.1s	remaining: 251ms
# 402:	learn: 7.3983961	total: 2.11s	remaining: 246ms
# 403:	learn: 7.3952255	total: 2.11s	remaining: 240ms
# 404:	learn: 7.3915168	total: 2.12s	remaining: 235ms
# 405:	learn: 7.3885348	total: 2.12s	remaining: 230ms
# 406:	learn: 7.3866400	total: 2.13s	remaining: 225ms
# 407:	learn: 7.3830089	total: 2.13s	remaining: 220ms
# 408:	learn: 7.3795380	total: 2.14s	remaining: 214ms
# 409:	learn: 7.3761526	total: 2.14s	remaining: 209ms
# 410:	learn: 7.3745481	total: 2.15s	remaining: 204ms
# 411:	learn: 7.3692897	total: 2.15s	remaining: 198ms
# 412:	learn: 7.3648949	total: 2.15s	remaining: 193ms
# 413:	learn: 7.3646288	total: 2.16s	remaining: 188ms
# 414:	learn: 7.3608769	total: 2.16s	remaining: 183ms
# 415:	learn: 7.3572174	total: 2.17s	remaining: 177ms
# 416:	learn: 7.3536637	total: 2.17s	remaining: 172ms
# 417:	learn: 7.3504590	total: 2.18s	remaining: 167ms
# 418:	learn: 7.3481490	total: 2.18s	remaining: 162ms
# 419:	learn: 7.3450577	total: 2.19s	remaining: 156ms
# 420:	learn: 7.3419616	total: 2.19s	remaining: 151ms
# 421:	learn: 7.3395411	total: 2.2s	remaining: 146ms
# 422:	learn: 7.3377444	total: 2.2s	remaining: 141ms
# 423:	learn: 7.3323690	total: 2.21s	remaining: 135ms
# 424:	learn: 7.3292932	total: 2.21s	remaining: 130ms
# 425:	learn: 7.3275371	total: 2.22s	remaining: 125ms
# 426:	learn: 7.3241092	total: 2.22s	remaining: 120ms
# 427:	learn: 7.3210577	total: 2.23s	remaining: 115ms
# 428:	learn: 7.3184092	total: 2.23s	remaining: 109ms
# 429:	learn: 7.3154021	total: 2.24s	remaining: 104ms
# 430:	learn: 7.3121261	total: 2.24s	remaining: 98.9ms
# 431:	learn: 7.3089605	total: 2.25s	remaining: 93.7ms
# 432:	learn: 7.3060306	total: 2.25s	remaining: 88.5ms
# 433:	learn: 7.3039276	total: 2.26s	remaining: 83.3ms
# 434:	learn: 7.3001577	total: 2.26s	remaining: 78ms
# 435:	learn: 7.2978943	total: 2.27s	remaining: 72.8ms
# 436:	learn: 7.2957284	total: 2.27s	remaining: 67.6ms
# 437:	learn: 7.2920346	total: 2.28s	remaining: 62.4ms
# 438:	learn: 7.2900090	total: 2.28s	remaining: 57.2ms
# 439:	learn: 7.2858921	total: 2.29s	remaining: 51.9ms
# 440:	learn: 7.2856800	total: 2.29s	remaining: 46.7ms
# 441:	learn: 7.2824415	total: 2.29s	remaining: 41.5ms
# 442:	learn: 7.2808501	total: 2.3s	remaining: 36.3ms
# 443:	learn: 7.2776341	total: 2.31s	remaining: 31.2ms
# 444:	learn: 7.2732491	total: 2.31s	remaining: 26ms
# 445:	learn: 7.2713706	total: 2.31s	remaining: 20.8ms
# 446:	learn: 7.2697004	total: 2.32s	remaining: 15.6ms
# 447:	learn: 7.2665378	total: 2.32s	remaining: 10.4ms
# 448:	learn: 7.2640039	total: 2.33s	remaining: 5.19ms
# 449:	learn: 7.2621852	total: 2.33s	remaining: 0us
# 0:	learn: 13.6616844	total: 5.84ms	remaining: 2.62s
# 1:	learn: 13.1383349	total: 12.2ms	remaining: 2.72s
# 2:	learn: 12.6982437	total: 17.1ms	remaining: 2.54s
# 3:	learn: 12.3090614	total: 21.5ms	remaining: 2.4s
# 4:	learn: 11.9786665	total: 27.7ms	remaining: 2.47s
# 5:	learn: 11.6831722	total: 32.1ms	remaining: 2.37s
# 6:	learn: 11.4273263	total: 39.7ms	remaining: 2.51s
# 7:	learn: 11.2248518	total: 44.1ms	remaining: 2.44s
# 8:	learn: 11.0342605	total: 48.5ms	remaining: 2.38s
# 9:	learn: 10.8706053	total: 53.1ms	remaining: 2.34s
# 10:	learn: 10.7377738	total: 58.6ms	remaining: 2.34s
# 11:	learn: 10.6252572	total: 62.7ms	remaining: 2.29s
# 12:	learn: 10.5084943	total: 67ms	remaining: 2.25s
# 13:	learn: 10.4194509	total: 72.8ms	remaining: 2.27s
# 14:	learn: 10.3319866	total: 84.9ms	remaining: 2.46s
# 15:	learn: 10.2645142	total: 98.9ms	remaining: 2.68s
# 16:	learn: 10.1984923	total: 117ms	remaining: 2.98s
# 17:	learn: 10.1401059	total: 131ms	remaining: 3.14s
# 18:	learn: 10.0822321	total: 152ms	remaining: 3.44s
# 19:	learn: 10.0287265	total: 158ms	remaining: 3.4s
# 20:	learn: 9.9750435	total: 163ms	remaining: 3.33s
# 21:	learn: 9.9253753	total: 169ms	remaining: 3.29s
# 22:	learn: 9.8770376	total: 174ms	remaining: 3.23s
# 23:	learn: 9.8300441	total: 178ms	remaining: 3.16s
# 24:	learn: 9.7944709	total: 183ms	remaining: 3.11s
# 25:	learn: 9.7639807	total: 188ms	remaining: 3.06s
# 26:	learn: 9.7281323	total: 192ms	remaining: 3s
# 27:	learn: 9.6993992	total: 197ms	remaining: 2.97s
# 28:	learn: 9.6718096	total: 202ms	remaining: 2.92s
# 29:	learn: 9.6492943	total: 207ms	remaining: 2.9s
# 30:	learn: 9.6202038	total: 214ms	remaining: 2.88s
# 31:	learn: 9.5961194	total: 218ms	remaining: 2.85s
# 32:	learn: 9.5673569	total: 223ms	remaining: 2.81s
# 33:	learn: 9.5410954	total: 228ms	remaining: 2.79s
# 34:	learn: 9.5205493	total: 233ms	remaining: 2.76s
# 35:	learn: 9.5017267	total: 238ms	remaining: 2.73s
# 36:	learn: 9.4865186	total: 242ms	remaining: 2.7s
# 37:	learn: 9.4644654	total: 247ms	remaining: 2.68s
# 38:	learn: 9.4478717	total: 251ms	remaining: 2.65s
# 39:	learn: 9.4269129	total: 256ms	remaining: 2.62s
# 40:	learn: 9.4099957	total: 261ms	remaining: 2.6s
# 41:	learn: 9.3845008	total: 265ms	remaining: 2.58s
# 42:	learn: 9.3716346	total: 270ms	remaining: 2.56s
# 43:	learn: 9.3599240	total: 274ms	remaining: 2.53s
# 44:	learn: 9.3489952	total: 281ms	remaining: 2.53s
# 45:	learn: 9.3354542	total: 286ms	remaining: 2.52s
# 46:	learn: 9.3242507	total: 292ms	remaining: 2.5s
# 47:	learn: 9.3114675	total: 296ms	remaining: 2.48s
# 48:	learn: 9.3004948	total: 300ms	remaining: 2.46s
# 49:	learn: 9.2872275	total: 304ms	remaining: 2.44s
# 50:	learn: 9.2735686	total: 311ms	remaining: 2.43s
# 51:	learn: 9.2505834	total: 316ms	remaining: 2.42s
# 52:	learn: 9.2414245	total: 320ms	remaining: 2.39s
# 53:	learn: 9.2259380	total: 326ms	remaining: 2.39s
# 54:	learn: 9.2171109	total: 330ms	remaining: 2.37s
# 55:	learn: 9.2089148	total: 334ms	remaining: 2.35s
# 56:	learn: 9.2000874	total: 341ms	remaining: 2.35s
# 57:	learn: 9.1883055	total: 346ms	remaining: 2.34s
# 58:	learn: 9.1763120	total: 351ms	remaining: 2.33s
# 59:	learn: 9.1592614	total: 358ms	remaining: 2.33s
# 60:	learn: 9.1465517	total: 363ms	remaining: 2.31s
# 61:	learn: 9.1346106	total: 369ms	remaining: 2.31s
# 62:	learn: 9.1234558	total: 375ms	remaining: 2.3s
# 63:	learn: 9.1124770	total: 380ms	remaining: 2.29s
# 64:	learn: 9.1014286	total: 388ms	remaining: 2.3s
# 65:	learn: 9.0879507	total: 393ms	remaining: 2.29s
# 66:	learn: 9.0701080	total: 399ms	remaining: 2.28s
# 67:	learn: 9.0637122	total: 406ms	remaining: 2.28s
# 68:	learn: 9.0552886	total: 411ms	remaining: 2.27s
# 69:	learn: 9.0471175	total: 421ms	remaining: 2.29s
# 70:	learn: 9.0388696	total: 427ms	remaining: 2.28s
# 71:	learn: 9.0309540	total: 433ms	remaining: 2.27s
# 72:	learn: 9.0178632	total: 439ms	remaining: 2.27s
# 73:	learn: 9.0088304	total: 445ms	remaining: 2.26s
# 74:	learn: 8.9949063	total: 451ms	remaining: 2.25s
# 75:	learn: 8.9863514	total: 457ms	remaining: 2.25s
# 76:	learn: 8.9731328	total: 462ms	remaining: 2.24s
# 77:	learn: 8.9649900	total: 469ms	remaining: 2.23s
# 78:	learn: 8.9570512	total: 475ms	remaining: 2.23s
# 79:	learn: 8.9452756	total: 481ms	remaining: 2.23s
# 80:	learn: 8.9361055	total: 486ms	remaining: 2.21s
# 81:	learn: 8.9274694	total: 492ms	remaining: 2.21s
# 82:	learn: 8.9181166	total: 499ms	remaining: 2.21s
# 83:	learn: 8.9125135	total: 504ms	remaining: 2.2s
# 84:	learn: 8.9038632	total: 508ms	remaining: 2.18s
# 85:	learn: 8.8967290	total: 514ms	remaining: 2.17s
# 86:	learn: 8.8854418	total: 518ms	remaining: 2.16s
# 87:	learn: 8.8764803	total: 523ms	remaining: 2.15s
# 88:	learn: 8.8680524	total: 529ms	remaining: 2.15s
# 89:	learn: 8.8592582	total: 533ms	remaining: 2.13s
# 90:	learn: 8.8525683	total: 538ms	remaining: 2.12s
# 91:	learn: 8.8420722	total: 543ms	remaining: 2.11s
# 92:	learn: 8.8339133	total: 548ms	remaining: 2.1s
# 93:	learn: 8.8245600	total: 552ms	remaining: 2.09s
# 94:	learn: 8.8144383	total: 557ms	remaining: 2.08s
# 95:	learn: 8.8108681	total: 564ms	remaining: 2.08s
# 96:	learn: 8.8039416	total: 568ms	remaining: 2.07s
# 97:	learn: 8.7955865	total: 577ms	remaining: 2.07s
# 98:	learn: 8.7832256	total: 582ms	remaining: 2.06s
# 99:	learn: 8.7746768	total: 586ms	remaining: 2.05s
# 100:	learn: 8.7631139	total: 591ms	remaining: 2.04s
# 101:	learn: 8.7557669	total: 596ms	remaining: 2.03s
# 102:	learn: 8.7482717	total: 600ms	remaining: 2.02s
# 103:	learn: 8.7432172	total: 605ms	remaining: 2.01s
# 104:	learn: 8.7356055	total: 610ms	remaining: 2s
# 105:	learn: 8.7272710	total: 614ms	remaining: 1.99s
# 106:	learn: 8.7169247	total: 619ms	remaining: 1.98s
# 107:	learn: 8.7076624	total: 625ms	remaining: 1.98s
# 108:	learn: 8.7003775	total: 629ms	remaining: 1.97s
# 109:	learn: 8.6945539	total: 634ms	remaining: 1.96s
# 110:	learn: 8.6873750	total: 640ms	remaining: 1.95s
# 111:	learn: 8.6796624	total: 644ms	remaining: 1.94s
# 112:	learn: 8.6703833	total: 648ms	remaining: 1.93s
# 113:	learn: 8.6635587	total: 652ms	remaining: 1.92s
# 114:	learn: 8.6563598	total: 658ms	remaining: 1.92s
# 115:	learn: 8.6498206	total: 662ms	remaining: 1.91s
# 116:	learn: 8.6400198	total: 666ms	remaining: 1.9s
# 117:	learn: 8.6326099	total: 672ms	remaining: 1.89s
# 118:	learn: 8.6249907	total: 677ms	remaining: 1.88s
# 119:	learn: 8.6182608	total: 681ms	remaining: 1.87s
# 120:	learn: 8.6109615	total: 685ms	remaining: 1.86s
# 121:	learn: 8.6031555	total: 690ms	remaining: 1.85s
# 122:	learn: 8.5964805	total: 699ms	remaining: 1.86s
# 123:	learn: 8.5914172	total: 704ms	remaining: 1.85s
# 124:	learn: 8.5852683	total: 709ms	remaining: 1.84s
# 125:	learn: 8.5786067	total: 714ms	remaining: 1.83s
# 126:	learn: 8.5705526	total: 719ms	remaining: 1.83s
# 127:	learn: 8.5644974	total: 724ms	remaining: 1.82s
# 128:	learn: 8.5544906	total: 729ms	remaining: 1.81s
# 129:	learn: 8.5486496	total: 734ms	remaining: 1.8s
# 130:	learn: 8.5416800	total: 739ms	remaining: 1.8s
# 131:	learn: 8.5329722	total: 743ms	remaining: 1.79s
# 132:	learn: 8.5261226	total: 747ms	remaining: 1.78s
# 133:	learn: 8.5197829	total: 753ms	remaining: 1.77s
# 134:	learn: 8.5127627	total: 757ms	remaining: 1.77s
# 135:	learn: 8.5066094	total: 761ms	remaining: 1.76s
# 136:	learn: 8.4982195	total: 767ms	remaining: 1.75s
# 137:	learn: 8.4918491	total: 771ms	remaining: 1.74s
# 138:	learn: 8.4850479	total: 776ms	remaining: 1.74s
# 139:	learn: 8.4783995	total: 780ms	remaining: 1.73s
# 140:	learn: 8.4719702	total: 785ms	remaining: 1.72s
# 141:	learn: 8.4666538	total: 790ms	remaining: 1.71s
# 142:	learn: 8.4587701	total: 794ms	remaining: 1.7s
# 143:	learn: 8.4549499	total: 801ms	remaining: 1.7s
# 144:	learn: 8.4498212	total: 805ms	remaining: 1.69s
# 145:	learn: 8.4431874	total: 809ms	remaining: 1.68s
# 146:	learn: 8.4382416	total: 815ms	remaining: 1.68s
# 147:	learn: 8.4321996	total: 819ms	remaining: 1.67s
# 148:	learn: 8.4263520	total: 824ms	remaining: 1.66s
# 149:	learn: 8.4165773	total: 832ms	remaining: 1.66s
# 150:	learn: 8.4097723	total: 837ms	remaining: 1.66s
# 151:	learn: 8.4039543	total: 842ms	remaining: 1.65s
# 152:	learn: 8.3981453	total: 847ms	remaining: 1.64s
# 153:	learn: 8.3903836	total: 852ms	remaining: 1.64s
# 154:	learn: 8.3845036	total: 856ms	remaining: 1.63s
# 155:	learn: 8.3787775	total: 862ms	remaining: 1.62s
# 156:	learn: 8.3745383	total: 866ms	remaining: 1.61s
# 157:	learn: 8.3692894	total: 870ms	remaining: 1.61s
# 158:	learn: 8.3619563	total: 875ms	remaining: 1.6s
# 159:	learn: 8.3559448	total: 879ms	remaining: 1.59s
# 160:	learn: 8.3494029	total: 884ms	remaining: 1.59s
# 161:	learn: 8.3433379	total: 889ms	remaining: 1.58s
# 162:	learn: 8.3382170	total: 895ms	remaining: 1.57s
# 163:	learn: 8.3328826	total: 899ms	remaining: 1.57s
# 164:	learn: 8.3273786	total: 904ms	remaining: 1.56s
# 165:	learn: 8.3199374	total: 909ms	remaining: 1.55s
# 166:	learn: 8.3118475	total: 913ms	remaining: 1.55s
# 167:	learn: 8.3079498	total: 918ms	remaining: 1.54s
# 168:	learn: 8.3008609	total: 923ms	remaining: 1.53s
# 169:	learn: 8.2956147	total: 927ms	remaining: 1.53s
# 170:	learn: 8.2895979	total: 932ms	remaining: 1.52s
# 171:	learn: 8.2861032	total: 936ms	remaining: 1.51s
# 172:	learn: 8.2797948	total: 941ms	remaining: 1.51s
# 173:	learn: 8.2758891	total: 946ms	remaining: 1.5s
# 174:	learn: 8.2716695	total: 950ms	remaining: 1.49s
# 175:	learn: 8.2675938	total: 955ms	remaining: 1.49s
# 176:	learn: 8.2600553	total: 960ms	remaining: 1.48s
# 177:	learn: 8.2540625	total: 967ms	remaining: 1.48s
# 178:	learn: 8.2447477	total: 972ms	remaining: 1.47s
# 179:	learn: 8.2390408	total: 977ms	remaining: 1.47s
# 180:	learn: 8.2334556	total: 981ms	remaining: 1.46s
# 181:	learn: 8.2281940	total: 987ms	remaining: 1.45s
# 182:	learn: 8.2195952	total: 992ms	remaining: 1.45s
# 183:	learn: 8.2154729	total: 996ms	remaining: 1.44s
# 184:	learn: 8.2095085	total: 1s	remaining: 1.43s
# 185:	learn: 8.2051825	total: 1s	remaining: 1.43s
# 186:	learn: 8.1982633	total: 1.01s	remaining: 1.42s
# 187:	learn: 8.1920726	total: 1.01s	remaining: 1.41s
# 188:	learn: 8.1856668	total: 1.02s	remaining: 1.41s
# 189:	learn: 8.1800783	total: 1.02s	remaining: 1.4s
# 190:	learn: 8.1752149	total: 1.03s	remaining: 1.4s
# 191:	learn: 8.1707597	total: 1.03s	remaining: 1.39s
# 192:	learn: 8.1662212	total: 1.04s	remaining: 1.38s
# 193:	learn: 8.1611283	total: 1.04s	remaining: 1.38s
# 194:	learn: 8.1555842	total: 1.05s	remaining: 1.37s
# 195:	learn: 8.1498047	total: 1.05s	remaining: 1.36s
# 196:	learn: 8.1436604	total: 1.06s	remaining: 1.36s
# 197:	learn: 8.1372723	total: 1.06s	remaining: 1.35s
# 198:	learn: 8.1314837	total: 1.07s	remaining: 1.35s
# 199:	learn: 8.1253676	total: 1.07s	remaining: 1.34s
# 200:	learn: 8.1219229	total: 1.07s	remaining: 1.33s
# 201:	learn: 8.1170948	total: 1.08s	remaining: 1.33s
# 202:	learn: 8.1121229	total: 1.08s	remaining: 1.32s
# 203:	learn: 8.1067249	total: 1.09s	remaining: 1.31s
# 204:	learn: 8.1029154	total: 1.09s	remaining: 1.31s
# 205:	learn: 8.0973368	total: 1.1s	remaining: 1.3s
# 206:	learn: 8.0908112	total: 1.11s	remaining: 1.3s
# 207:	learn: 8.0852162	total: 1.11s	remaining: 1.3s
# 208:	learn: 8.0786798	total: 1.12s	remaining: 1.29s
# 209:	learn: 8.0721978	total: 1.12s	remaining: 1.28s
# 210:	learn: 8.0682424	total: 1.13s	remaining: 1.28s
# 211:	learn: 8.0632587	total: 1.13s	remaining: 1.27s
# 212:	learn: 8.0588080	total: 1.14s	remaining: 1.27s
# 213:	learn: 8.0513534	total: 1.14s	remaining: 1.26s
# 214:	learn: 8.0439619	total: 1.15s	remaining: 1.26s
# 215:	learn: 8.0366825	total: 1.15s	remaining: 1.25s
# 216:	learn: 8.0326103	total: 1.16s	remaining: 1.24s
# 217:	learn: 8.0293608	total: 1.16s	remaining: 1.24s
# 218:	learn: 8.0234961	total: 1.17s	remaining: 1.23s
# 219:	learn: 8.0163122	total: 1.17s	remaining: 1.23s
# 220:	learn: 8.0125447	total: 1.18s	remaining: 1.22s
# 221:	learn: 8.0072330	total: 1.18s	remaining: 1.22s
# 222:	learn: 8.0016161	total: 1.19s	remaining: 1.21s
# 223:	learn: 7.9974575	total: 1.19s	remaining: 1.2s
# 224:	learn: 7.9918587	total: 1.2s	remaining: 1.2s
# 225:	learn: 7.9888693	total: 1.2s	remaining: 1.19s
# 226:	learn: 7.9849349	total: 1.21s	remaining: 1.18s
# 227:	learn: 7.9800731	total: 1.21s	remaining: 1.18s
# 228:	learn: 7.9757903	total: 1.22s	remaining: 1.17s
# 229:	learn: 7.9704044	total: 1.22s	remaining: 1.17s
# 230:	learn: 7.9667087	total: 1.23s	remaining: 1.16s
# 231:	learn: 7.9631882	total: 1.23s	remaining: 1.16s
# 232:	learn: 7.9586639	total: 1.24s	remaining: 1.15s
# 233:	learn: 7.9537139	total: 1.24s	remaining: 1.15s
# 234:	learn: 7.9494612	total: 1.25s	remaining: 1.14s
# 235:	learn: 7.9430053	total: 1.25s	remaining: 1.14s
# 236:	learn: 7.9372799	total: 1.26s	remaining: 1.13s
# 237:	learn: 7.9317775	total: 1.26s	remaining: 1.12s
# 238:	learn: 7.9261923	total: 1.27s	remaining: 1.12s
# 239:	learn: 7.9217602	total: 1.27s	remaining: 1.11s
# 240:	learn: 7.9168525	total: 1.28s	remaining: 1.11s
# 241:	learn: 7.9127982	total: 1.28s	remaining: 1.1s
# 242:	learn: 7.9088957	total: 1.28s	remaining: 1.09s
# 243:	learn: 7.9047642	total: 1.29s	remaining: 1.09s
# 244:	learn: 7.8992576	total: 1.3s	remaining: 1.08s
# 245:	learn: 7.8968272	total: 1.3s	remaining: 1.08s
# 246:	learn: 7.8932264	total: 1.31s	remaining: 1.07s
# 247:	learn: 7.8900600	total: 1.31s	remaining: 1.07s
# 248:	learn: 7.8866265	total: 1.31s	remaining: 1.06s
# 249:	learn: 7.8834473	total: 1.32s	remaining: 1.06s
# 250:	learn: 7.8774646	total: 1.32s	remaining: 1.05s
# 251:	learn: 7.8729673	total: 1.33s	remaining: 1.04s
# 252:	learn: 7.8694322	total: 1.34s	remaining: 1.04s
# 253:	learn: 7.8668668	total: 1.34s	remaining: 1.03s
# 254:	learn: 7.8626609	total: 1.35s	remaining: 1.03s
# 255:	learn: 7.8581316	total: 1.35s	remaining: 1.02s
# 256:	learn: 7.8549843	total: 1.36s	remaining: 1.02s
# 257:	learn: 7.8499764	total: 1.36s	remaining: 1.01s
# 258:	learn: 7.8451504	total: 1.37s	remaining: 1.01s
# 259:	learn: 7.8423744	total: 1.37s	remaining: 1s
# 260:	learn: 7.8383269	total: 1.38s	remaining: 999ms
# 261:	learn: 7.8342048	total: 1.39s	remaining: 995ms
# 262:	learn: 7.8302806	total: 1.39s	remaining: 989ms
# 263:	learn: 7.8248034	total: 1.4s	remaining: 985ms
# 264:	learn: 7.8225118	total: 1.4s	remaining: 979ms
# 265:	learn: 7.8185196	total: 1.41s	remaining: 973ms
# 266:	learn: 7.8157104	total: 1.41s	remaining: 967ms
# 267:	learn: 7.8120717	total: 1.42s	remaining: 962ms
# 268:	learn: 7.8085919	total: 1.42s	remaining: 956ms
# 269:	learn: 7.8051609	total: 1.43s	remaining: 951ms
# 270:	learn: 7.8013345	total: 1.43s	remaining: 945ms
# 271:	learn: 7.7971606	total: 1.44s	remaining: 939ms
# 272:	learn: 7.7934919	total: 1.44s	remaining: 933ms
# 273:	learn: 7.7900084	total: 1.45s	remaining: 928ms
# 274:	learn: 7.7864661	total: 1.45s	remaining: 922ms
# 275:	learn: 7.7831999	total: 1.45s	remaining: 916ms
# 276:	learn: 7.7815464	total: 1.46s	remaining: 911ms
# 277:	learn: 7.7771328	total: 1.47s	remaining: 907ms
# 278:	learn: 7.7749564	total: 1.47s	remaining: 901ms
# 279:	learn: 7.7738421	total: 1.48s	remaining: 897ms
# 280:	learn: 7.7710688	total: 1.48s	remaining: 892ms
# 281:	learn: 7.7683664	total: 1.49s	remaining: 887ms
# 282:	learn: 7.7648201	total: 1.5s	remaining: 882ms
# 283:	learn: 7.7624678	total: 1.5s	remaining: 877ms
# 284:	learn: 7.7580899	total: 1.51s	remaining: 874ms
# 285:	learn: 7.7524797	total: 1.51s	remaining: 869ms
# 286:	learn: 7.7494523	total: 1.52s	remaining: 864ms
# 287:	learn: 7.7463017	total: 1.53s	remaining: 859ms
# 288:	learn: 7.7423653	total: 1.53s	remaining: 855ms
# 289:	learn: 7.7386237	total: 1.54s	remaining: 850ms
# 290:	learn: 7.7345539	total: 1.54s	remaining: 845ms
# 291:	learn: 7.7312922	total: 1.55s	remaining: 839ms
# 292:	learn: 7.7275073	total: 1.56s	remaining: 835ms
# 293:	learn: 7.7244075	total: 1.56s	remaining: 829ms
# 294:	learn: 7.7201434	total: 1.57s	remaining: 824ms
# 295:	learn: 7.7166151	total: 1.57s	remaining: 820ms
# 296:	learn: 7.7136117	total: 1.58s	remaining: 815ms
# 297:	learn: 7.7125760	total: 1.59s	remaining: 809ms
# 298:	learn: 7.7076230	total: 1.59s	remaining: 804ms
# 299:	learn: 7.7019082	total: 1.6s	remaining: 799ms
# 300:	learn: 7.6982944	total: 1.6s	remaining: 794ms
# 301:	learn: 7.6953557	total: 1.61s	remaining: 789ms
# 302:	learn: 7.6906196	total: 1.61s	remaining: 783ms
# 303:	learn: 7.6869242	total: 1.62s	remaining: 778ms
# 304:	learn: 7.6838007	total: 1.62s	remaining: 772ms
# 305:	learn: 7.6809708	total: 1.63s	remaining: 767ms
# 306:	learn: 7.6768461	total: 1.63s	remaining: 761ms
# 307:	learn: 7.6726941	total: 1.64s	remaining: 757ms
# 308:	learn: 7.6678838	total: 1.65s	remaining: 751ms
# 309:	learn: 7.6634849	total: 1.65s	remaining: 745ms
# 310:	learn: 7.6604021	total: 1.66s	remaining: 740ms
# 311:	learn: 7.6573348	total: 1.66s	remaining: 734ms
# 312:	learn: 7.6537990	total: 1.66s	remaining: 729ms
# 313:	learn: 7.6503191	total: 1.67s	remaining: 724ms
# 314:	learn: 7.6458033	total: 1.68s	remaining: 718ms
# 315:	learn: 7.6425161	total: 1.68s	remaining: 713ms
# 316:	learn: 7.6389842	total: 1.69s	remaining: 707ms
# 317:	learn: 7.6365890	total: 1.69s	remaining: 702ms
# 318:	learn: 7.6334797	total: 1.69s	remaining: 696ms
# 319:	learn: 7.6287073	total: 1.7s	remaining: 691ms
# 320:	learn: 7.6238890	total: 1.7s	remaining: 685ms
# 321:	learn: 7.6194727	total: 1.71s	remaining: 679ms
# 322:	learn: 7.6170945	total: 1.71s	remaining: 674ms
# 323:	learn: 7.6137257	total: 1.72s	remaining: 668ms
# 324:	learn: 7.6096842	total: 1.72s	remaining: 663ms
# 325:	learn: 7.6074448	total: 1.73s	remaining: 657ms
# 326:	learn: 7.6035653	total: 1.73s	remaining: 652ms
# 327:	learn: 7.5980116	total: 1.74s	remaining: 646ms
# 328:	learn: 7.5958821	total: 1.74s	remaining: 641ms
# 329:	learn: 7.5908929	total: 1.75s	remaining: 636ms
# 330:	learn: 7.5869111	total: 1.75s	remaining: 630ms
# 331:	learn: 7.5855304	total: 1.76s	remaining: 624ms
# 332:	learn: 7.5813861	total: 1.76s	remaining: 619ms
# 333:	learn: 7.5781396	total: 1.76s	remaining: 613ms
# 334:	learn: 7.5733802	total: 1.77s	remaining: 608ms
# 335:	learn: 7.5706035	total: 1.78s	remaining: 604ms
# 336:	learn: 7.5675226	total: 1.78s	remaining: 598ms
# 337:	learn: 7.5654569	total: 1.79s	remaining: 593ms
# 338:	learn: 7.5634012	total: 1.79s	remaining: 587ms
# 339:	learn: 7.5592536	total: 1.8s	remaining: 582ms
# 340:	learn: 7.5568706	total: 1.8s	remaining: 576ms
# 341:	learn: 7.5541104	total: 1.81s	remaining: 571ms
# 342:	learn: 7.5519967	total: 1.81s	remaining: 565ms
# 343:	learn: 7.5469774	total: 1.82s	remaining: 560ms
# 344:	learn: 7.5435684	total: 1.82s	remaining: 555ms
# 345:	learn: 7.5423038	total: 1.83s	remaining: 549ms
# 346:	learn: 7.5391735	total: 1.83s	remaining: 544ms
# 347:	learn: 7.5359550	total: 1.83s	remaining: 538ms
# 348:	learn: 7.5326327	total: 1.84s	remaining: 533ms
# 349:	learn: 7.5290598	total: 1.85s	remaining: 528ms
# 350:	learn: 7.5259276	total: 1.85s	remaining: 523ms
# 351:	learn: 7.5219885	total: 1.86s	remaining: 518ms
# 352:	learn: 7.5199412	total: 1.87s	remaining: 513ms
# 353:	learn: 7.5158961	total: 1.87s	remaining: 508ms
# 354:	learn: 7.5133301	total: 1.88s	remaining: 502ms
# 355:	learn: 7.5108855	total: 1.88s	remaining: 497ms
# 356:	learn: 7.5080059	total: 1.89s	remaining: 491ms
# 357:	learn: 7.5034787	total: 1.89s	remaining: 486ms
# 358:	learn: 7.4990366	total: 1.9s	remaining: 481ms
# 359:	learn: 7.4960909	total: 1.9s	remaining: 475ms
# 360:	learn: 7.4924795	total: 1.91s	remaining: 470ms
# 361:	learn: 7.4880380	total: 1.91s	remaining: 465ms
# 362:	learn: 7.4851663	total: 1.92s	remaining: 459ms
# 363:	learn: 7.4820826	total: 1.92s	remaining: 454ms
# 364:	learn: 7.4795781	total: 1.93s	remaining: 449ms
# 365:	learn: 7.4750736	total: 1.93s	remaining: 443ms
# 366:	learn: 7.4724724	total: 1.94s	remaining: 438ms
# 367:	learn: 7.4679991	total: 1.94s	remaining: 433ms
# 368:	learn: 7.4646451	total: 1.95s	remaining: 427ms
# 369:	learn: 7.4610866	total: 1.95s	remaining: 422ms
# 370:	learn: 7.4577041	total: 1.96s	remaining: 417ms
# 371:	learn: 7.4555555	total: 1.96s	remaining: 411ms
# 372:	learn: 7.4531716	total: 1.97s	remaining: 406ms
# 373:	learn: 7.4482833	total: 1.97s	remaining: 401ms
# 374:	learn: 7.4448498	total: 1.98s	remaining: 395ms
# 375:	learn: 7.4409163	total: 1.98s	remaining: 390ms
# 376:	learn: 7.4389791	total: 1.99s	remaining: 384ms
# 377:	learn: 7.4354299	total: 1.99s	remaining: 379ms
# 378:	learn: 7.4328463	total: 1.99s	remaining: 373ms
# 379:	learn: 7.4300795	total: 2s	remaining: 368ms
# 380:	learn: 7.4272690	total: 2s	remaining: 363ms
# 381:	learn: 7.4251745	total: 2.01s	remaining: 357ms
# 382:	learn: 7.4225523	total: 2.01s	remaining: 352ms
# 383:	learn: 7.4199669	total: 2.02s	remaining: 347ms
# 384:	learn: 7.4167143	total: 2.02s	remaining: 341ms
# 385:	learn: 7.4140503	total: 2.03s	remaining: 336ms
# 386:	learn: 7.4118582	total: 2.03s	remaining: 331ms
# 387:	learn: 7.4099482	total: 2.04s	remaining: 325ms
# 388:	learn: 7.4074375	total: 2.04s	remaining: 320ms
# 389:	learn: 7.4047505	total: 2.05s	remaining: 315ms
# 390:	learn: 7.4026568	total: 2.05s	remaining: 310ms
# 391:	learn: 7.3994963	total: 2.06s	remaining: 305ms
# 392:	learn: 7.3966964	total: 2.06s	remaining: 299ms
# 393:	learn: 7.3950125	total: 2.07s	remaining: 294ms
# 394:	learn: 7.3921369	total: 2.07s	remaining: 289ms
# 395:	learn: 7.3891708	total: 2.08s	remaining: 283ms
# 396:	learn: 7.3853495	total: 2.08s	remaining: 278ms
# 397:	learn: 7.3819256	total: 2.09s	remaining: 273ms
# 398:	learn: 7.3780753	total: 2.09s	remaining: 267ms
# 399:	learn: 7.3756006	total: 2.1s	remaining: 262ms
# 400:	learn: 7.3742534	total: 2.1s	remaining: 257ms
# 401:	learn: 7.3721323	total: 2.1s	remaining: 251ms
# 402:	learn: 7.3692628	total: 2.11s	remaining: 246ms
# 403:	learn: 7.3664661	total: 2.12s	remaining: 241ms
# 404:	learn: 7.3613417	total: 2.12s	remaining: 236ms
# 405:	learn: 7.3583822	total: 2.13s	remaining: 230ms
# 406:	learn: 7.3558842	total: 2.13s	remaining: 225ms
# 407:	learn: 7.3546590	total: 2.13s	remaining: 220ms
# 408:	learn: 7.3509792	total: 2.14s	remaining: 214ms
# 409:	learn: 7.3483264	total: 2.14s	remaining: 209ms
# 410:	learn: 7.3459699	total: 2.15s	remaining: 204ms
# 411:	learn: 7.3432947	total: 2.15s	remaining: 199ms
# 412:	learn: 7.3411737	total: 2.16s	remaining: 193ms
# 413:	learn: 7.3368575	total: 2.16s	remaining: 188ms
# 414:	learn: 7.3353771	total: 2.17s	remaining: 183ms
# 415:	learn: 7.3324629	total: 2.17s	remaining: 178ms
# 416:	learn: 7.3304156	total: 2.18s	remaining: 173ms
# 417:	learn: 7.3266927	total: 2.18s	remaining: 167ms
# 418:	learn: 7.3225213	total: 2.19s	remaining: 162ms
# 419:	learn: 7.3185767	total: 2.19s	remaining: 157ms
# 420:	learn: 7.3166992	total: 2.2s	remaining: 151ms
# 421:	learn: 7.3146701	total: 2.2s	remaining: 146ms
# 422:	learn: 7.3128304	total: 2.21s	remaining: 141ms
# 423:	learn: 7.3096556	total: 2.21s	remaining: 136ms
# 424:	learn: 7.3060686	total: 2.22s	remaining: 130ms
# 425:	learn: 7.3045614	total: 2.22s	remaining: 125ms
# 426:	learn: 7.3007045	total: 2.23s	remaining: 120ms
# 427:	learn: 7.2972776	total: 2.23s	remaining: 115ms
# 428:	learn: 7.2937180	total: 2.24s	remaining: 110ms
# 429:	learn: 7.2915918	total: 2.24s	remaining: 104ms
# 430:	learn: 7.2897739	total: 2.25s	remaining: 99ms
# 431:	learn: 7.2869250	total: 2.25s	remaining: 93.8ms
# 432:	learn: 7.2853556	total: 2.25s	remaining: 88.5ms
# 433:	learn: 7.2830333	total: 2.26s	remaining: 83.3ms
# 434:	learn: 7.2796501	total: 2.26s	remaining: 78.1ms
# 435:	learn: 7.2747343	total: 2.27s	remaining: 72.9ms
# 436:	learn: 7.2721103	total: 2.27s	remaining: 67.6ms
# 437:	learn: 7.2685825	total: 2.28s	remaining: 62.4ms
# 438:	learn: 7.2660527	total: 2.28s	remaining: 57.2ms
# 439:	learn: 7.2659971	total: 2.29s	remaining: 52ms
# 440:	learn: 7.2627144	total: 2.29s	remaining: 46.8ms
# 441:	learn: 7.2609799	total: 2.3s	remaining: 41.6ms
# 442:	learn: 7.2580661	total: 2.3s	remaining: 36.4ms
# 443:	learn: 7.2565091	total: 2.31s	remaining: 31.2ms
# 444:	learn: 7.2536004	total: 2.31s	remaining: 26ms
# 445:	learn: 7.2514696	total: 2.32s	remaining: 20.8ms
# 446:	learn: 7.2504978	total: 2.32s	remaining: 15.6ms
# 447:	learn: 7.2481488	total: 2.33s	remaining: 10.4ms
# 448:	learn: 7.2451854	total: 2.33s	remaining: 5.2ms
# 449:	learn: 7.2426400	total: 2.34s	remaining: 0us
# 0:	learn: 13.7033911	total: 6.17ms	remaining: 2.77s
# 1:	learn: 13.1921781	total: 10.7ms	remaining: 2.4s
# 2:	learn: 12.7572159	total: 16.2ms	remaining: 2.41s
# 3:	learn: 12.3827129	total: 22.3ms	remaining: 2.49s
# 4:	learn: 12.0470797	total: 26.9ms	remaining: 2.39s
# 5:	learn: 11.7624423	total: 33.6ms	remaining: 2.48s
# 6:	learn: 11.5131202	total: 38.1ms	remaining: 2.41s
# 7:	learn: 11.2931762	total: 42.2ms	remaining: 2.33s
# 8:	learn: 11.1137067	total: 48.2ms	remaining: 2.36s
# 9:	learn: 10.9598731	total: 53.4ms	remaining: 2.35s
# 10:	learn: 10.8129128	total: 57.7ms	remaining: 2.3s
# 11:	learn: 10.7062033	total: 63.2ms	remaining: 2.31s
# 12:	learn: 10.5814099	total: 67.5ms	remaining: 2.27s
# 13:	learn: 10.4847853	total: 72ms	remaining: 2.24s
# 14:	learn: 10.3900980	total: 77.4ms	remaining: 2.24s
# 15:	learn: 10.3126689	total: 82.8ms	remaining: 2.25s
# 16:	learn: 10.2463909	total: 86.8ms	remaining: 2.21s
# 17:	learn: 10.1820654	total: 91.1ms	remaining: 2.19s
# 18:	learn: 10.1287935	total: 97.1ms	remaining: 2.2s
# 19:	learn: 10.0792108	total: 101ms	remaining: 2.17s
# 20:	learn: 10.0268218	total: 105ms	remaining: 2.15s
# 21:	learn: 9.9789375	total: 112ms	remaining: 2.18s
# 22:	learn: 9.9370889	total: 116ms	remaining: 2.16s
# 23:	learn: 9.8873104	total: 121ms	remaining: 2.14s
# 24:	learn: 9.8508719	total: 128ms	remaining: 2.18s
# 25:	learn: 9.8152875	total: 134ms	remaining: 2.19s
# 26:	learn: 9.7852102	total: 140ms	remaining: 2.19s
# 27:	learn: 9.7513244	total: 145ms	remaining: 2.18s
# ...
# 151:	learn: 8.4323989	total: 1.04s	remaining: 2.04s
# 152:	learn: 8.4263484	total: 1.05s	remaining: 2.03s
# 153:	learn: 8.4204514	total: 1.05s	remaining: 2.02s
# 154:	learn: 8.4172166	total: 1.06s	remaining: 2.02s
# 155:	learn: 8.4107672	total: 1.06s	remaining: 2s
# 156:	learn: 8.4039851	total: 1.07s	remaining: 1.99s
# 157:	learn: 8.3954258	total: 1.07s	remaining: 1.99s
# 158:	learn: 8.3902531	total: 1.08s	remaining: 1.98s
# 159:	learn: 8.3837292	total: 1.08s	remaining: 1.97s
# 160:	learn: 8.3784502	total: 1.09s	remaining: 1.96s
# 161:	learn: 8.3729227	total: 1.1s	remaining: 1.95s
# 162:	learn: 8.3663879	total: 1.1s	remaining: 1.94s
# 163:	learn: 8.3600761	total: 1.11s	remaining: 1.93s
# 164:	learn: 8.3550687	total: 1.11s	remaining: 1.92s
# 165:	learn: 8.3476459	total: 1.12s	remaining: 1.91s
# 166:	learn: 8.3430041	total: 1.12s	remaining: 1.91s
# 167:	learn: 8.3372446	total: 1.13s	remaining: 1.9s
# 168:	learn: 8.3353016	total: 1.13s	remaining: 1.88s
# 169:	learn: 8.3306970	total: 1.14s	remaining: 1.88s
# 170:	learn: 8.3245295	total: 1.14s	remaining: 1.87s
# 171:	learn: 8.3172888	total: 1.15s	remaining: 1.86s
# 172:	learn: 8.3116641	total: 1.16s	remaining: 1.85s
# 173:	learn: 8.3056018	total: 1.16s	remaining: 1.84s
# 174:	learn: 8.3042993	total: 1.16s	remaining: 1.83s
# 175:	learn: 8.2990398	total: 1.17s	remaining: 1.83s
# 176:	learn: 8.2924750	total: 1.18s	remaining: 1.82s
# 177:	learn: 8.2859075	total: 1.18s	remaining: 1.81s
# 178:	learn: 8.2787763	total: 1.19s	remaining: 1.8s
# 179:	learn: 8.2727832	total: 1.19s	remaining: 1.79s
# 180:	learn: 8.2661424	total: 1.2s	remaining: 1.79s
# 181:	learn: 8.2610501	total: 1.21s	remaining: 1.78s
# 182:	learn: 8.2558880	total: 1.21s	remaining: 1.77s
# 183:	learn: 8.2501346	total: 1.22s	remaining: 1.76s
# 184:	learn: 8.2449033	total: 1.22s	remaining: 1.75s
# 185:	learn: 8.2398773	total: 1.23s	remaining: 1.74s
# 186:	learn: 8.2344603	total: 1.23s	remaining: 1.74s
# 187:	learn: 8.2282948	total: 1.24s	remaining: 1.73s
# 188:	learn: 8.2222738	total: 1.24s	remaining: 1.72s
# 189:	learn: 8.2159746	total: 1.25s	remaining: 1.71s
# 190:	learn: 8.2096526	total: 1.25s	remaining: 1.7s
# 191:	learn: 8.2029487	total: 1.26s	remaining: 1.69s
# 192:	learn: 8.1983261	total: 1.26s	remaining: 1.68s
# 193:	learn: 8.1944326	total: 1.27s	remaining: 1.68s
# 194:	learn: 8.1913045	total: 1.27s	remaining: 1.67s
# 195:	learn: 8.1859625	total: 1.28s	remaining: 1.66s
# 196:	learn: 8.1802564	total: 1.28s	remaining: 1.65s
# 197:	learn: 8.1760641	total: 1.29s	remaining: 1.64s
# 198:	learn: 8.1700067	total: 1.3s	remaining: 1.64s
# 199:	learn: 8.1649731	total: 1.3s	remaining: 1.63s
# 200:	learn: 8.1596520	total: 1.31s	remaining: 1.62s
# 201:	learn: 8.1540744	total: 1.31s	remaining: 1.61s
# 202:	learn: 8.1492910	total: 1.32s	remaining: 1.61s
# 203:	learn: 8.1454400	total: 1.33s	remaining: 1.6s
# 204:	learn: 8.1392409	total: 1.33s	remaining: 1.59s
# 205:	learn: 8.1349312	total: 1.34s	remaining: 1.58s
# 206:	learn: 8.1335051	total: 1.34s	remaining: 1.58s
# 207:	learn: 8.1273039	total: 1.35s	remaining: 1.57s
# 208:	learn: 8.1206288	total: 1.35s	remaining: 1.56s
# 209:	learn: 8.1156372	total: 1.36s	remaining: 1.55s
# 210:	learn: 8.1099954	total: 1.37s	remaining: 1.55s
# 211:	learn: 8.1061952	total: 1.37s	remaining: 1.54s
# 212:	learn: 8.1016022	total: 1.38s	remaining: 1.53s
# 213:	learn: 8.0976342	total: 1.38s	remaining: 1.52s
# 214:	learn: 8.0945055	total: 1.39s	remaining: 1.52s
# 215:	learn: 8.0893340	total: 1.39s	remaining: 1.51s
# 216:	learn: 8.0854154	total: 1.4s	remaining: 1.5s
# 217:	learn: 8.0816359	total: 1.4s	remaining: 1.49s
# 218:	learn: 8.0807506	total: 1.41s	remaining: 1.49s
# 219:	learn: 8.0775804	total: 1.41s	remaining: 1.48s
# 220:	learn: 8.0735261	total: 1.42s	remaining: 1.47s
# 221:	learn: 8.0730803	total: 1.43s	remaining: 1.46s
# 222:	learn: 8.0685476	total: 1.43s	remaining: 1.46s
# 223:	learn: 8.0638413	total: 1.43s	remaining: 1.45s
# 224:	learn: 8.0590268	total: 1.44s	remaining: 1.44s
# 225:	learn: 8.0542285	total: 1.45s	remaining: 1.43s
# 226:	learn: 8.0490115	total: 1.45s	remaining: 1.43s
# 227:	learn: 8.0439114	total: 1.46s	remaining: 1.42s
# 228:	learn: 8.0380665	total: 1.47s	remaining: 1.42s
# 229:	learn: 8.0342280	total: 1.47s	remaining: 1.41s
# 230:	learn: 8.0302660	total: 1.48s	remaining: 1.4s
# 231:	learn: 8.0246250	total: 1.48s	remaining: 1.39s
# 232:	learn: 8.0196962	total: 1.49s	remaining: 1.39s
# 233:	learn: 8.0153017	total: 1.5s	remaining: 1.38s
# 234:	learn: 8.0104134	total: 1.5s	remaining: 1.37s
# 235:	learn: 8.0041369	total: 1.51s	remaining: 1.37s
# 236:	learn: 8.0002639	total: 1.51s	remaining: 1.36s
# 237:	learn: 7.9969817	total: 1.52s	remaining: 1.35s
# 238:	learn: 7.9914972	total: 1.52s	remaining: 1.34s
# 239:	learn: 7.9869371	total: 1.53s	remaining: 1.34s
# 240:	learn: 7.9832569	total: 1.53s	remaining: 1.33s
# 241:	learn: 7.9778356	total: 1.54s	remaining: 1.32s
# 242:	learn: 7.9729981	total: 1.54s	remaining: 1.31s
# 243:	learn: 7.9684866	total: 1.55s	remaining: 1.31s
# 244:	learn: 7.9645400	total: 1.55s	remaining: 1.3s
# 245:	learn: 7.9589349	total: 1.56s	remaining: 1.29s
# 246:	learn: 7.9541924	total: 1.56s	remaining: 1.28s
# 247:	learn: 7.9485463	total: 1.57s	remaining: 1.28s
# 248:	learn: 7.9441350	total: 1.57s	remaining: 1.27s
# 249:	learn: 7.9388732	total: 1.58s	remaining: 1.27s
# 250:	learn: 7.9357164	total: 1.59s	remaining: 1.26s
# 251:	learn: 7.9311649	total: 1.59s	remaining: 1.25s
# 252:	learn: 7.9276473	total: 1.6s	remaining: 1.25s
# 253:	learn: 7.9243589	total: 1.61s	remaining: 1.24s
# 254:	learn: 7.9177246	total: 1.61s	remaining: 1.23s
# 255:	learn: 7.9112776	total: 1.62s	remaining: 1.23s
# 256:	learn: 7.9086373	total: 1.62s	remaining: 1.22s
# 257:	learn: 7.9049583	total: 1.63s	remaining: 1.21s
# 258:	learn: 7.8987310	total: 1.63s	remaining: 1.2s
# 259:	learn: 7.8955181	total: 1.64s	remaining: 1.2s
# 260:	learn: 7.8913163	total: 1.64s	remaining: 1.19s
# 261:	learn: 7.8874477	total: 1.65s	remaining: 1.18s
# 262:	learn: 7.8836660	total: 1.66s	remaining: 1.18s
# 263:	learn: 7.8787066	total: 1.66s	remaining: 1.17s
# 264:	learn: 7.8752159	total: 1.67s	remaining: 1.16s
# 265:	learn: 7.8709643	total: 1.67s	remaining: 1.16s
# 266:	learn: 7.8663214	total: 1.68s	remaining: 1.15s
# 267:	learn: 7.8617514	total: 1.68s	remaining: 1.14s
# 268:	learn: 7.8583319	total: 1.69s	remaining: 1.13s
# 269:	learn: 7.8544402	total: 1.69s	remaining: 1.13s
# 270:	learn: 7.8495326	total: 1.7s	remaining: 1.12s
# 271:	learn: 7.8494347	total: 1.7s	remaining: 1.11s
# 272:	learn: 7.8475841	total: 1.71s	remaining: 1.11s
# 273:	learn: 7.8442164	total: 1.71s	remaining: 1.1s
# 274:	learn: 7.8396377	total: 1.72s	remaining: 1.09s
# 275:	learn: 7.8344502	total: 1.72s	remaining: 1.08s
# 276:	learn: 7.8309516	total: 1.73s	remaining: 1.08s
# 277:	learn: 7.8269741	total: 1.73s	remaining: 1.07s
# 278:	learn: 7.8227306	total: 1.74s	remaining: 1.06s
# 279:	learn: 7.8177634	total: 1.75s	remaining: 1.06s
# 280:	learn: 7.8139071	total: 1.75s	remaining: 1.05s
# 281:	learn: 7.8105250	total: 1.76s	remaining: 1.05s
# 282:	learn: 7.8069198	total: 1.76s	remaining: 1.04s
# 283:	learn: 7.8024128	total: 1.77s	remaining: 1.03s
# 284:	learn: 7.7983289	total: 1.77s	remaining: 1.03s
# 285:	learn: 7.7962902	total: 1.78s	remaining: 1.02s
# 286:	learn: 7.7915658	total: 1.78s	remaining: 1.01s
# 287:	learn: 7.7904932	total: 1.79s	remaining: 1.01s
# 288:	learn: 7.7872519	total: 1.8s	remaining: 1s
# 289:	learn: 7.7832972	total: 1.8s	remaining: 994ms
# 290:	learn: 7.7803976	total: 1.81s	remaining: 987ms
# 291:	learn: 7.7776552	total: 1.81s	remaining: 980ms
# 292:	learn: 7.7735417	total: 1.82s	remaining: 974ms
# 293:	learn: 7.7695729	total: 1.82s	remaining: 967ms
# 294:	learn: 7.7665380	total: 1.83s	remaining: 960ms
# 295:	learn: 7.7635574	total: 1.83s	remaining: 953ms
# 296:	learn: 7.7589019	total: 1.84s	remaining: 947ms
# 297:	learn: 7.7576968	total: 1.84s	remaining: 940ms
# 298:	learn: 7.7540200	total: 1.85s	remaining: 933ms
# 299:	learn: 7.7498831	total: 1.85s	remaining: 926ms
# 300:	learn: 7.7469898	total: 1.86s	remaining: 919ms
# 301:	learn: 7.7439216	total: 1.86s	remaining: 913ms
# 302:	learn: 7.7412892	total: 1.87s	remaining: 906ms
# 303:	learn: 7.7389351	total: 1.87s	remaining: 900ms
# 304:	learn: 7.7354916	total: 1.88s	remaining: 893ms
# 305:	learn: 7.7318693	total: 1.89s	remaining: 891ms
# 306:	learn: 7.7289958	total: 1.9s	remaining: 887ms
# 307:	learn: 7.7256715	total: 1.91s	remaining: 880ms
# 308:	learn: 7.7240931	total: 1.92s	remaining: 874ms
# 309:	learn: 7.7201431	total: 1.92s	remaining: 868ms
# 310:	learn: 7.7153305	total: 1.93s	remaining: 861ms
# 311:	learn: 7.7123498	total: 1.93s	remaining: 856ms
# 312:	learn: 7.7092531	total: 1.94s	remaining: 849ms
# 313:	learn: 7.7072398	total: 1.94s	remaining: 842ms
# 314:	learn: 7.7035645	total: 1.95s	remaining: 836ms
# 315:	learn: 7.6993349	total: 1.96s	remaining: 829ms
# 316:	learn: 7.6952251	total: 1.96s	remaining: 822ms
# 317:	learn: 7.6914038	total: 1.97s	remaining: 816ms
# 318:	learn: 7.6887654	total: 1.97s	remaining: 809ms
# 319:	learn: 7.6861890	total: 1.98s	remaining: 803ms
# 320:	learn: 7.6822173	total: 1.98s	remaining: 797ms
# 321:	learn: 7.6773802	total: 1.99s	remaining: 791ms
# 322:	learn: 7.6725435	total: 2s	remaining: 786ms
# 323:	learn: 7.6691288	total: 2s	remaining: 779ms
# 324:	learn: 7.6660929	total: 2.01s	remaining: 773ms
# 325:	learn: 7.6637283	total: 2.02s	remaining: 767ms
# 326:	learn: 7.6613205	total: 2.02s	remaining: 761ms
# 327:	learn: 7.6575931	total: 2.03s	remaining: 756ms
# 328:	learn: 7.6542947	total: 2.04s	remaining: 750ms
# 329:	learn: 7.6512277	total: 2.05s	remaining: 744ms
# 330:	learn: 7.6473775	total: 2.05s	remaining: 738ms
# 331:	learn: 7.6445847	total: 2.06s	remaining: 732ms
# 332:	learn: 7.6416215	total: 2.07s	remaining: 726ms
# 333:	learn: 7.6380901	total: 2.07s	remaining: 721ms
# 334:	learn: 7.6351956	total: 2.08s	remaining: 714ms
# 335:	learn: 7.6319504	total: 2.09s	remaining: 708ms
# 336:	learn: 7.6270369	total: 2.1s	remaining: 703ms
# 337:	learn: 7.6227355	total: 2.1s	remaining: 696ms
# 338:	learn: 7.6199764	total: 2.11s	remaining: 690ms
# 339:	learn: 7.6170881	total: 2.12s	remaining: 684ms
# 340:	learn: 7.6137611	total: 2.12s	remaining: 678ms
# 341:	learn: 7.6117369	total: 2.13s	remaining: 672ms
# 342:	learn: 7.6075685	total: 2.13s	remaining: 666ms
# 343:	learn: 7.6041099	total: 2.14s	remaining: 660ms
# 344:	learn: 7.6011694	total: 2.15s	remaining: 653ms
# 345:	learn: 7.5992442	total: 2.15s	remaining: 647ms
# 346:	learn: 7.5963080	total: 2.16s	remaining: 640ms
# 347:	learn: 7.5918453	total: 2.16s	remaining: 634ms
# 348:	learn: 7.5879080	total: 2.17s	remaining: 627ms
# 349:	learn: 7.5842616	total: 2.18s	remaining: 622ms
# 350:	learn: 7.5823303	total: 2.18s	remaining: 615ms
# 351:	learn: 7.5811510	total: 2.19s	remaining: 609ms
# 352:	learn: 7.5772630	total: 2.19s	remaining: 603ms
# 353:	learn: 7.5736699	total: 2.2s	remaining: 596ms
# 354:	learn: 7.5705556	total: 2.2s	remaining: 590ms
# 355:	learn: 7.5670712	total: 2.21s	remaining: 583ms
# 356:	learn: 7.5643411	total: 2.21s	remaining: 577ms
# 357:	learn: 7.5599360	total: 2.22s	remaining: 570ms
# 358:	learn: 7.5564207	total: 2.23s	remaining: 564ms
# 359:	learn: 7.5532121	total: 2.23s	remaining: 557ms
# 360:	learn: 7.5516541	total: 2.23s	remaining: 551ms
# 361:	learn: 7.5477462	total: 2.24s	remaining: 545ms
# 362:	learn: 7.5437674	total: 2.25s	remaining: 538ms
# 363:	learn: 7.5413731	total: 2.25s	remaining: 532ms
# 364:	learn: 7.5387374	total: 2.26s	remaining: 526ms
# 365:	learn: 7.5358613	total: 2.26s	remaining: 519ms
# 366:	learn: 7.5340320	total: 2.27s	remaining: 513ms
# 367:	learn: 7.5304118	total: 2.27s	remaining: 507ms
# 368:	learn: 7.5287356	total: 2.28s	remaining: 500ms
# 369:	learn: 7.5260038	total: 2.28s	remaining: 494ms
# 370:	learn: 7.5232001	total: 2.29s	remaining: 487ms
# 371:	learn: 7.5213191	total: 2.29s	remaining: 481ms
# 372:	learn: 7.5179947	total: 2.3s	remaining: 475ms
# 373:	learn: 7.5148717	total: 2.3s	remaining: 468ms
# 374:	learn: 7.5130916	total: 2.31s	remaining: 462ms
# 375:	learn: 7.5103526	total: 2.32s	remaining: 456ms
# 376:	learn: 7.5065725	total: 2.32s	remaining: 450ms
# 377:	learn: 7.5038639	total: 2.33s	remaining: 443ms
# 378:	learn: 7.5010952	total: 2.33s	remaining: 437ms
# 379:	learn: 7.4982877	total: 2.34s	remaining: 431ms
# 380:	learn: 7.4944328	total: 2.34s	remaining: 425ms
# 381:	learn: 7.4900509	total: 2.35s	remaining: 418ms
# 382:	learn: 7.4864903	total: 2.35s	remaining: 412ms
# 383:	learn: 7.4821098	total: 2.36s	remaining: 406ms
# 384:	learn: 7.4797812	total: 2.37s	remaining: 400ms
# 385:	learn: 7.4769584	total: 2.37s	remaining: 393ms
# 386:	learn: 7.4739420	total: 2.38s	remaining: 387ms
# 387:	learn: 7.4713850	total: 2.38s	remaining: 381ms
# 388:	learn: 7.4681386	total: 2.39s	remaining: 375ms
# 389:	learn: 7.4667011	total: 2.4s	remaining: 368ms
# 390:	learn: 7.4637634	total: 2.4s	remaining: 362ms
# 391:	learn: 7.4608879	total: 2.4s	remaining: 356ms
# 392:	learn: 7.4569746	total: 2.41s	remaining: 350ms
# 393:	learn: 7.4541431	total: 2.42s	remaining: 343ms
# 394:	learn: 7.4509278	total: 2.42s	remaining: 337ms
# 395:	learn: 7.4484598	total: 2.43s	remaining: 331ms
# 396:	learn: 7.4452812	total: 2.43s	remaining: 325ms
# 397:	learn: 7.4421012	total: 2.44s	remaining: 319ms
# 398:	learn: 7.4382603	total: 2.45s	remaining: 313ms
# 399:	learn: 7.4355878	total: 2.45s	remaining: 306ms
# 400:	learn: 7.4316198	total: 2.46s	remaining: 301ms
# 401:	learn: 7.4272708	total: 2.47s	remaining: 295ms
# 402:	learn: 7.4242945	total: 2.47s	remaining: 289ms
# 403:	learn: 7.4207779	total: 2.48s	remaining: 282ms
# 404:	learn: 7.4196154	total: 2.48s	remaining: 276ms
# 405:	learn: 7.4166504	total: 2.49s	remaining: 270ms
# 406:	learn: 7.4144877	total: 2.5s	remaining: 264ms
# 407:	learn: 7.4111117	total: 2.5s	remaining: 258ms
# 408:	learn: 7.4093484	total: 2.51s	remaining: 252ms
# 409:	learn: 7.4065795	total: 2.51s	remaining: 245ms
# 410:	learn: 7.4037053	total: 2.52s	remaining: 239ms
# 411:	learn: 7.4008348	total: 2.53s	remaining: 233ms
# 412:	learn: 7.3986761	total: 2.53s	remaining: 227ms
# 413:	learn: 7.3946325	total: 2.54s	remaining: 221ms
# 414:	learn: 7.3904741	total: 2.54s	remaining: 215ms
# 415:	learn: 7.3865537	total: 2.55s	remaining: 208ms
# 416:	learn: 7.3848420	total: 2.56s	remaining: 202ms
# 417:	learn: 7.3818018	total: 2.56s	remaining: 196ms
# 418:	learn: 7.3795163	total: 2.57s	remaining: 190ms
# 419:	learn: 7.3757774	total: 2.57s	remaining: 184ms
# 420:	learn: 7.3739157	total: 2.58s	remaining: 178ms
# 421:	learn: 7.3722402	total: 2.58s	remaining: 172ms
# 422:	learn: 7.3699344	total: 2.59s	remaining: 165ms
# 423:	learn: 7.3659386	total: 2.6s	remaining: 159ms
# 424:	learn: 7.3607401	total: 2.61s	remaining: 153ms
# 425:	learn: 7.3590364	total: 2.62s	remaining: 147ms
# 426:	learn: 7.3564892	total: 2.62s	remaining: 141ms
# 427:	learn: 7.3556266	total: 2.63s	remaining: 135ms
# 428:	learn: 7.3530624	total: 2.64s	remaining: 129ms
# 429:	learn: 7.3510235	total: 2.64s	remaining: 123ms
# 430:	learn: 7.3469062	total: 2.65s	remaining: 117ms
# 431:	learn: 7.3452968	total: 2.66s	remaining: 111ms
# 432:	learn: 7.3420356	total: 2.67s	remaining: 105ms
# 433:	learn: 7.3418843	total: 2.67s	remaining: 98.5ms
# 434:	learn: 7.3394029	total: 2.68s	remaining: 92.3ms
# 435:	learn: 7.3378472	total: 2.68s	remaining: 86.2ms
# 436:	learn: 7.3351044	total: 2.69s	remaining: 80ms
# 437:	learn: 7.3330456	total: 2.7s	remaining: 73.9ms
# 438:	learn: 7.3294384	total: 2.7s	remaining: 67.7ms
# 439:	learn: 7.3270090	total: 2.71s	remaining: 61.6ms
# 440:	learn: 7.3230569	total: 2.72s	remaining: 55.5ms
# 441:	learn: 7.3195679	total: 2.73s	remaining: 49.3ms
# 442:	learn: 7.3162886	total: 2.73s	remaining: 43.2ms
# 443:	learn: 7.3141902	total: 2.74s	remaining: 37ms
# 444:	learn: 7.3120419	total: 2.75s	remaining: 30.9ms
# 445:	learn: 7.3098011	total: 2.75s	remaining: 24.7ms
# 446:	learn: 7.3076831	total: 2.76s	remaining: 18.5ms
# 447:	learn: 7.3040758	total: 2.77s	remaining: 12.3ms
# 448:	learn: 7.3023205	total: 2.77s	remaining: 6.17ms
# 449:	learn: 7.3003856	total: 2.78s	remaining: 0us
#                 Model Evaluation Metrics:
# Mean Absolute Error (MAE): 5.48430437322714
# Root Mean Squared Error (RMSE): 7.300385648778605
# R-squared (R2 ): 0.7387169832648618
# ADJUST_CAPACITY: 9.9712
# CURRENT_WAIT_TIME: 24.7008
# TIME_TO_PARADE_1: 7.2254
# TIME_TO_PARADE_2: 1.5314
# TIME_TO_NIGHT_SHOW: 7.3054
# temp: 1.7867
# dew_point: 1.6303
# feels_like: 1.8531
# pressure: 3.2907
# humidity: 2.0890
# wind_speed: 2.2239
# rain_1h: 2.2976
# snow_1h: 6.4242
# year: 3.0109
# month: 4.0283
# day: 3.1488
# hour: 17.4825

# %%
X_val = validation_file.copy()
X_val['DATETIME'] = pd.to_datetime(X_val['DATETIME'], errors='coerce')

X_val = pd.merge(X_val, weather_file, on='DATETIME', how='left')
X_val = pd.get_dummies(X_val, columns=['ENTITY_DESCRIPTION_SHORT'], drop_first=True, dtype=int)
X_val['year'] = X_val['DATETIME'].dt.year
X_val['month'] = X_val['DATETIME'].dt.month
X_val['day'] = X_val['DATETIME'].dt.day
X_val['hour'] = X_val['DATETIME'].dt.hour
X_val['minute'] = X_val['DATETIME'].dt.minute

X_val['TIME_TO_PARADE_1'] = X_val['TIME_TO_PARADE_1'].fillna(250)
X_val['TIME_TO_PARADE_2'] = X_val['TIME_TO_PARADE_2'].fillna(0)

X_val = X_val.sort_values(by='DATETIME')
X_val['rain_1h__6'] = X_val['rain_1h'].shift(-6)
X_val['rain_1h__3'] = X_val['rain_1h'].shift(-3)

X_val['snow_1h__6'] = X_val['snow_1h'].shift(-6)
X_val['snow_1h__3'] = X_val['snow_1h'].shift(-3)

# Fill NaNs by column
for col in X_val.select_dtypes(include=['number']).columns:
    # Compute mean and std of non-NaN values
    mean = X_val[col].mean()
    std = X_val[col].std()
    
    # Find number of NaNs
    n_nan = X_val[col].isna().sum()
    
    # Generate random numbers for NaNs
    random_values = np.random.normal(loc=mean, scale=std, size=n_nan)
    
    # Fill NaNs
    X_val.loc[X_val[col].isna(), col] = random_values

X_val = X_val.sort_index()
X_val = X_val.select_dtypes(include=['number']).drop(columns=['DOWNTIME','minute','clouds_all'])

# %%
y_pred_final = model.predict(X_val)

# %%
import pandas as pd
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score
import numpy as np

# %%
def evaluate_model(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    rmse = root_mean_squared_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    
    print("                Model Evaluation Metrics:")
    print(f"Mean Absolute Error (MAE): {mae}")
    print(f"Root Mean Squared Error (RMSE): {rmse}")
    print(f"R-squared (R2 ): {r2}")

# %%
def generate_csv(input, y_pred, key='Validation', filename='../output/random_forest_improved_predictions.csv'):
    output = input[['DATETIME', 'ENTITY_DESCRIPTION_SHORT']].copy()
    output['y_pred'] = y_pred
    output['KEY'] = [key] * len(y_pred)
    output.to_csv(filename, index=False)
    print(f"Predictions saved to {filename}")

# %%
train_route = '../data/waiting_times_train.csv'
validation_route = '../data/waiting_times_X_test_val.csv'
test_route = '../data/waiting_times_X_test_final.csv'
weather_route = '../data/weather_data.csv'

train_file = pd.read_csv(train_route)
validation_file = pd.read_csv(validation_route)
test_file = pd.read_csv(test_route)
weather_file = pd.read_csv(weather_route)

# %%
X_train = train_file.copy()
X_train['DATETIME'] = pd.to_datetime(X_train['DATETIME'], errors='coerce')

weather_file['DATETIME'] = pd.to_datetime(weather_file['DATETIME'], errors='coerce')
weather_file = weather_file.fillna(0)

X_train = pd.merge(X_train, weather_file, on='DATETIME', how='left')
X_train = pd.get_dummies(X_train, columns=['ENTITY_DESCRIPTION_SHORT'], drop_first=True, dtype=int)
X_train['year'] = X_train['DATETIME'].dt.year
X_train['month'] = X_train['DATETIME'].dt.month
X_train['day'] = X_train['DATETIME'].dt.day
X_train['hour'] = X_train['DATETIME'].dt.hour
X_train['minute'] = X_train['DATETIME'].dt.minute

X_train['TIME_TO_PARADE_1'] = X_train['TIME_TO_PARADE_1'].fillna(250)
X_train['TIME_TO_PARADE_2'] = X_train['TIME_TO_PARADE_2'].fillna(0)

X_train = X_train.sort_values(by='DATETIME')
X_train['rain_1h__6'] = X_train['rain_1h'].shift(-6)
X_train['rain_1h__3'] = X_train['rain_1h'].shift(-3)

X_train['snow_1h__6'] = X_train['snow_1h'].shift(-6)
X_train['snow_1h__3'] = X_train['snow_1h'].shift(-3)

print(X_train.head())

# Fill NaNs by column
for col in X_train.select_dtypes(include=['number']).columns:
    # Compute mean and std of non-NaN values
    mean = X_train[col].mean()
    std = X_train[col].std()
    
    # Find number of NaNs
    n_nan = X_train[col].isna().sum()
    
    # Generate random numbers for NaNs
    random_values = np.random.normal(loc=mean, scale=std, size=n_nan)
    
    # Fill NaNs
    X_train.loc[X_train[col].isna(), col] = random_values

X_train = X_train.sort_index()
y_train = X_train['WAIT_TIME_IN_2H']
X_train = X_train.select_dtypes(include=['number']).drop(columns=['WAIT_TIME_IN_2H','clouds_all', 'humidity'])
# Out:
#                  DATETIME  ADJUST_CAPACITY  DOWNTIME  CURRENT_WAIT_TIME  \
# 5927  2018-10-01 12:15:00            224.5         0                 20
# 8149  2018-10-01 12:15:00            756.0         0                 10
# 12003 2018-10-01 12:15:00            153.0         0                 25
# 13978 2018-10-01 12:30:00            153.0         0                 25
# 23029 2018-10-01 12:30:00            224.5         0                 20
#
#        TIME_TO_PARADE_1  TIME_TO_PARADE_2  TIME_TO_NIGHT_SHOW  \
# 5927              315.0              -5.0               465.0
# 8149              315.0              -5.0               465.0
# 12003             315.0              -5.0               465.0
# 13978             300.0             -20.0               450.0
# 23029             300.0             -20.0               450.0
#
#        WAIT_TIME_IN_2H   temp  dew_point  ...  \
# 5927              20.0  13.01       5.43  ...
# 8149              10.0  13.01       5.43  ...
# 12003             25.0  13.01       5.43  ...
# 13978             25.0  13.25       5.41  ...
# 23029             20.0  13.25       5.41  ...
#
#        ENTITY_DESCRIPTION_SHORT_Water Ride  year  month  day  hour  minute  \
# 5927                                     1  2018     10    1    12      15
# 8149                                     0  2018     10    1    12      15
# 12003                                    0  2018     10    1    12      15
# 13978                                    0  2018     10    1    12      30
# 23029                                    1  2018     10    1    12      30
#
#        rain_1h__6  rain_1h__3  snow_1h__6  snow_1h__3
# 5927       0.1239      0.1226         0.0         0.0
# 8149       0.1239      0.1226         0.0         0.0
# 12003      0.1239      0.1226         0.0         0.0
# 13978      0.1252      0.1239         0.0         0.0
# 23029      0.1252      0.1239         0.0         0.0
#
# [5 rows x 28 columns]

# %%
optimized_estimators = 1900
'''max_score = float('-inf')
for n in range(100, 5000, 100):
    model = XGBRegressor(n_estimators=n, learning_rate=0.1)
    scores = cross_val_score(model, X_train, y_train, scoring='neg_root_mean_squared_error', cv=5)
    score_mean = scores.mean()
    print(f"n_estimators: {n}, CV Mean RMSE: {-score_mean}")
    if score_mean > max_score:
        optimized_estimators = n
        max_score = score_mean'''



model = XGBRegressor(n_estimators=optimized_estimators, learning_rate=0.009, random_state=10)
scores = cross_val_score(model, X_train, y_train, scoring='neg_root_mean_squared_error', cv=5)
print(scores.mean(), scores.std())
model.fit(X_train, y_train)

y_pred = model.predict(X_train)
evaluate_model(y_train, y_pred)
# Out:
# -7.6567120632439565 0.12498849982052476
#                 Model Evaluation Metrics:
# Mean Absolute Error (MAE): 4.98972291063928
# Root Mean Squared Error (RMSE): 6.624667358649011
# R-squared (R2 ): 0.7848468402124719

# %%
X_val = validation_file.copy()
X_val['DATETIME'] = pd.to_datetime(X_val['DATETIME'], errors='coerce')

X_val = pd.merge(X_val, weather_file, on='DATETIME', how='left')
X_val = pd.get_dummies(X_val, columns=['ENTITY_DESCRIPTION_SHORT'], drop_first=True, dtype=int)
X_val['year'] = X_val['DATETIME'].dt.year
X_val['month'] = X_val['DATETIME'].dt.month
X_val['day'] = X_val['DATETIME'].dt.day
X_val['hour'] = X_val['DATETIME'].dt.hour
X_val['minute'] = X_val['DATETIME'].dt.minute

X_val['TIME_TO_PARADE_1'] = X_val['TIME_TO_PARADE_1'].fillna(250)
X_val['TIME_TO_PARADE_2'] = X_val['TIME_TO_PARADE_2'].fillna(0)

X_val = X_val.sort_values(by='DATETIME')
X_val['rain_1h__6'] = X_val['rain_1h'].shift(-6)
X_val['rain_1h__3'] = X_val['rain_1h'].shift(-3)

X_val['snow_1h__6'] = X_val['snow_1h'].shift(-6)
X_val['snow_1h__3'] = X_val['snow_1h'].shift(-3)

# Fill NaNs by column
for col in X_val.select_dtypes(include=['number']).columns:
    # Compute mean and std of non-NaN values
    mean = X_val[col].mean()
    std = X_val[col].std()
    
    # Find number of NaNs
    n_nan = X_val[col].isna().sum()
    
    # Generate random numbers for NaNs
    random_values = np.random.normal(loc=mean, scale=std, size=n_nan)
    
    # Fill NaNs
    X_val.loc[X_val[col].isna(), col] = random_values

X_val = X_val.sort_index()
X_val = X_val.select_dtypes(include=['number']).drop(columns=['clouds_all','humidity'])

# %%
y_pred_final_xgb = model.predict(X_val)

# %%
import pandas as pd
from lightgbm import LGBMRegressor, LGBMClassifier
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score
import numpy as np

# %%
def evaluate_model(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    rmse = root_mean_squared_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    
    print("                Model Evaluation Metrics:")
    print(f"Mean Absolute Error (MAE): {mae}")
    print(f"Root Mean Squared Error (RMSE): {rmse}")
    print(f"R-squared (R2 ): {r2}")

# %%
def generate_csv(input, y_pred, key='Validation', filename='../output/random_forest_improved_predictions.csv'):
    output = input[['DATETIME', 'ENTITY_DESCRIPTION_SHORT']].copy()
    output['y_pred'] = y_pred
    output['KEY'] = [key] * len(y_pred)
    output.to_csv(filename, index=False)
    print(f"Predictions saved to {filename}")

# %%
train_route = '../data/waiting_times_train.csv'
validation_route = '../data/waiting_times_X_test_val.csv'
test_route = '../data/waiting_times_X_test_final.csv'
weather_route = '../data/weather_data.csv'

train_file = pd.read_csv(train_route)
validation_file = pd.read_csv(validation_route)
test_file = pd.read_csv(test_route)
weather_file = pd.read_csv(weather_route)

# %%
X_train = train_file.copy()
X_train['DATETIME'] = pd.to_datetime(X_train['DATETIME'], errors='coerce')

weather_file['DATETIME'] = pd.to_datetime(weather_file['DATETIME'], errors='coerce')
weather_file = weather_file.fillna(0)

X_train = pd.merge(X_train, weather_file, on='DATETIME', how='left')
X_train = pd.get_dummies(X_train, columns=['ENTITY_DESCRIPTION_SHORT'], drop_first=True, dtype=int)
X_train['year'] = X_train['DATETIME'].dt.year
X_train['month'] = X_train['DATETIME'].dt.month
X_train['day'] = X_train['DATETIME'].dt.day
X_train['hour'] = X_train['DATETIME'].dt.hour
X_train['minute'] = X_train['DATETIME'].dt.minute

X_train['TIME_TO_PARADE_1'] = X_train['TIME_TO_PARADE_1'].fillna(250)
X_train['TIME_TO_PARADE_2'] = X_train['TIME_TO_PARADE_2'].fillna(0)

X_train = X_train.sort_values(by='DATETIME')
X_train['rain_1h__6'] = X_train['rain_1h'].shift(-6)
X_train['rain_1h__3'] = X_train['rain_1h'].shift(-3)

X_train['snow_1h__6'] = X_train['snow_1h'].shift(-6)
X_train['snow_1h__3'] = X_train['snow_1h'].shift(-3)

print(X_train.head())

# Fill NaNs by column
for col in X_train.select_dtypes(include=['number']).columns:
    # Compute mean and std of non-NaN values
    mean = X_train[col].mean()
    std = X_train[col].std()
    
    # Find number of NaNs
    n_nan = X_train[col].isna().sum()
    
    # Generate random numbers for NaNs
    random_values = np.random.normal(loc=mean, scale=std, size=n_nan)
    
    # Fill NaNs
    X_train.loc[X_train[col].isna(), col] = random_values

X_train = X_train.sort_index()
y_train = X_train['WAIT_TIME_IN_2H']
X_train = X_train.select_dtypes(include=['number']).drop(columns=['WAIT_TIME_IN_2H','pressure', 'minute','dew_point'])
# Out:
#                  DATETIME  ADJUST_CAPACITY  DOWNTIME  CURRENT_WAIT_TIME  \
# 5927  2018-10-01 12:15:00            224.5         0                 20
# 8149  2018-10-01 12:15:00            756.0         0                 10
# 12003 2018-10-01 12:15:00            153.0         0                 25
# 13978 2018-10-01 12:30:00            153.0         0                 25
# 23029 2018-10-01 12:30:00            224.5         0                 20
#
#        TIME_TO_PARADE_1  TIME_TO_PARADE_2  TIME_TO_NIGHT_SHOW  \
# 5927              315.0              -5.0               465.0
# 8149              315.0              -5.0               465.0
# 12003             315.0              -5.0               465.0
# 13978             300.0             -20.0               450.0
# 23029             300.0             -20.0               450.0
#
#        WAIT_TIME_IN_2H   temp  dew_point  ...  \
# 5927              20.0  13.01       5.43  ...
# 8149              10.0  13.01       5.43  ...
# 12003             25.0  13.01       5.43  ...
# 13978             25.0  13.25       5.41  ...
# 23029             20.0  13.25       5.41  ...
#
#        ENTITY_DESCRIPTION_SHORT_Water Ride  year  month  day  hour  minute  \
# 5927                                     1  2018     10    1    12      15
# 8149                                     0  2018     10    1    12      15
# 12003                                    0  2018     10    1    12      15
# 13978                                    0  2018     10    1    12      30
# 23029                                    1  2018     10    1    12      30
#
#        rain_1h__6  rain_1h__3  snow_1h__6  snow_1h__3
# 5927       0.1239      0.1226         0.0         0.0
# 8149       0.1239      0.1226         0.0         0.0
# 12003      0.1239      0.1226         0.0         0.0
# 13978      0.1252      0.1239         0.0         0.0
# 23029      0.1252      0.1239         0.0         0.0
#
# [5 rows x 28 columns]

# %%
optimized_estimators = 4500
'''max_score = float('-inf')
for n in range(100, 5000, 100):
    model = XGBRegressor(n_estimators=n, learning_rate=0.1)
    scores = cross_val_score(model, X_train, y_train, scoring='neg_root_mean_squared_error', cv=5)
    score_mean = scores.mean()
    print(f"n_estimators: {n}, CV Mean RMSE: {-score_mean}")
    if score_mean > max_score:
        optimized_estimators = n
        max_score = score_mean'''



model = LGBMRegressor(n_estimators=optimized_estimators, learning_rate=0.004, random_state=10)
scores = cross_val_score(model, X_train, y_train, scoring='neg_root_mean_squared_error', cv=5)
print(scores.mean(), scores.std())
model.fit(X_train, y_train)

y_pred = model.predict(X_train)
evaluate_model(y_train, y_pred)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003775 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3511
# [LightGBM] [Info] Number of data points in the train set: 29614, number of used features: 23
# [LightGBM] [Info] Start training from score 23.677484
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003064 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3502
# [LightGBM] [Info] Number of data points in the train set: 29614, number of used features: 23
# [LightGBM] [Info] Start training from score 23.534646
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006497 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3508
# [LightGBM] [Info] Number of data points in the train set: 29614, number of used features: 23
# [LightGBM] [Info] Start training from score 23.610792
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001299 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3496
# [LightGBM] [Info] Number of data points in the train set: 29615, number of used features: 23
# [LightGBM] [Info] Start training from score 23.645788
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002448 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3502
# [LightGBM] [Info] Number of data points in the train set: 29615, number of used features: 23
# [LightGBM] [Info] Start training from score 23.559683
# -7.816301201085307 0.14133336973352215
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005092 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3508
# [LightGBM] [Info] Number of data points in the train set: 37018, number of used features: 23
# [LightGBM] [Info] Start training from score 23.605678
#                 Model Evaluation Metrics:
# Mean Absolute Error (MAE): 5.351603198619332
# Root Mean Squared Error (RMSE): 7.083133628171297
# R-squared (R2 ): 0.7540366232883411

# %%
X_val = validation_file.copy()
X_val['DATETIME'] = pd.to_datetime(X_val['DATETIME'], errors='coerce')

X_val = pd.merge(X_val, weather_file, on='DATETIME', how='left')
X_val = pd.get_dummies(X_val, columns=['ENTITY_DESCRIPTION_SHORT'], drop_first=True, dtype=int)
X_val['year'] = X_val['DATETIME'].dt.year
X_val['month'] = X_val['DATETIME'].dt.month
X_val['day'] = X_val['DATETIME'].dt.day
X_val['hour'] = X_val['DATETIME'].dt.hour
X_val['minute'] = X_val['DATETIME'].dt.minute

X_val['TIME_TO_PARADE_1'] = X_val['TIME_TO_PARADE_1'].fillna(250)
X_val['TIME_TO_PARADE_2'] = X_val['TIME_TO_PARADE_2'].fillna(0)

X_val = X_val.sort_values(by='DATETIME')
X_val['rain_1h__6'] = X_val['rain_1h'].shift(-6)
X_val['rain_1h__3'] = X_val['rain_1h'].shift(-3)

X_val['snow_1h__6'] = X_val['snow_1h'].shift(-6)
X_val['snow_1h__3'] = X_val['snow_1h'].shift(-3)

# Fill NaNs by column
for col in X_val.select_dtypes(include=['number']).columns:
    # Compute mean and std of non-NaN values
    mean = X_val[col].mean()
    std = X_val[col].std()
    
    # Find number of NaNs
    n_nan = X_val[col].isna().sum()
    
    # Generate random numbers for NaNs
    random_values = np.random.normal(loc=mean, scale=std, size=n_nan)
    
    # Fill NaNs
    X_val.loc[X_val[col].isna(), col] = random_values

X_val = X_val.sort_index()
X_val = X_val.select_dtypes(include=['number']).drop(columns=['pressure', 'minute','dew_point'])

# %%
y_pred_final_lgbm = model.predict(X_val)

# %%
y_pred = (y_pred_final + y_pred_final_xgb+ y_pred_final_lgbm) / 3
generate_csv(validation_file, y_pred, key='Validation', filename='../output/ensemble_catboost_xgboost_predictions.csv')
# Out:
# Predictions saved to ../output/ensemble_catboost_xgboost_predictions.csv

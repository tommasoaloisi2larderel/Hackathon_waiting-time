# %%
import pandas as pd
from catboost import CatBoostRegressor
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score
import numpy as np

# %%
train_route = '../data/waiting_times_train.csv'
validation_route = '../data/waiting_times_X_test_val.csv'
test_route = '../data/waiting_times_X_test_final.csv'
weather_route = '../data/weather_data.csv'

train_file = pd.read_csv(train_route)
validation_file = pd.read_csv(validation_route)
test_file = pd.read_csv(test_route)
weather_file = pd.read_csv(weather_route)

# %%
X_train = train_file.copy()
X_train['DATETIME'] = pd.to_datetime(X_train['DATETIME'], errors='coerce')

weather_file['DATETIME'] = pd.to_datetime(weather_file['DATETIME'], errors='coerce')
weather_file = weather_file.fillna(0)

X_train = pd.merge(X_train, weather_file, on='DATETIME', how='left')
print(X_train.columns)
X_train['year'] = X_train['DATETIME'].dt.year
X_train['month'] = X_train['DATETIME'].dt.month
X_train['day'] = X_train['DATETIME'].dt.day
X_train['hour'] = X_train['DATETIME'].dt.hour
X_train['minute'] = X_train['DATETIME'].dt.minute

X_train['TIME_TO_PARADE_1'] = X_train['TIME_TO_PARADE_1'].fillna(250)
X_train['TIME_TO_PARADE_2'] = X_train['TIME_TO_PARADE_2'].fillna(0)

X_train = X_train.sort_values(by='DATETIME')
print(X_train.head())

# Fill NaNs by column
for col in X_train.select_dtypes(include=['number']).columns:
    # Compute mean and std of non-NaN values
    mean = X_train[col].mean()
    std = X_train[col].std()
    
    # Find number of NaNs
    n_nan = X_train[col].isna().sum()
    
    # Generate random numbers for NaNs
    random_values = np.random.normal(loc=mean, scale=std, size=n_nan)
    
    # Fill NaNs
    X_train.loc[X_train[col].isna(), col] = random_values

X_train = X_train.sort_index()
y_train = X_train['WAIT_TIME_IN_2H']
X_train = X_train.select_dtypes(include=['number']).drop(columns=['WAIT_TIME_IN_2H','DOWNTIME','minute','clouds_all'])
# Out:
# Index(['DATETIME', 'ENTITY_DESCRIPTION_SHORT', 'ADJUST_CAPACITY', 'DOWNTIME',
#        'CURRENT_WAIT_TIME', 'TIME_TO_PARADE_1', 'TIME_TO_PARADE_2',
#        'TIME_TO_NIGHT_SHOW', 'WAIT_TIME_IN_2H', 'temp', 'dew_point',
#        'feels_like', 'pressure', 'humidity', 'wind_speed', 'rain_1h',
#        'snow_1h', 'clouds_all'],
#       dtype='object')
#                  DATETIME ENTITY_DESCRIPTION_SHORT  ADJUST_CAPACITY  DOWNTIME  \
# 5927  2018-10-01 12:15:00               Water Ride            224.5         0
# 8149  2018-10-01 12:15:00           Flying Coaster            756.0         0
# 12003 2018-10-01 12:15:00              Pirate Ship            153.0         0
# 13978 2018-10-01 12:30:00              Pirate Ship            153.0         0
# 23029 2018-10-01 12:30:00               Water Ride            224.5         0
#
#        CURRENT_WAIT_TIME  TIME_TO_PARADE_1  TIME_TO_PARADE_2  \
# 5927                  20             315.0              -5.0
# 8149                  10             315.0              -5.0
# 12003                 25             315.0              -5.0
# 13978                 25             300.0             -20.0
# 23029                 20             300.0             -20.0
#
#        TIME_TO_NIGHT_SHOW  WAIT_TIME_IN_2H   temp  ...  humidity  wind_speed  \
# 5927                465.0             20.0  13.01  ...      60.0      5.7725
# 8149                465.0             10.0  13.01  ...      60.0      5.7725
# 12003               465.0             25.0  13.01  ...      60.0      5.7725
# 13978               450.0             25.0  13.25  ...      59.0      5.8750
# 23029               450.0             20.0  13.25  ...      59.0      5.8750
#
#        rain_1h  snow_1h  clouds_all  year  month  day  hour  minute
# 5927    0.1213      0.0        49.0  2018     10    1    12      15
# 8149    0.1213      0.0        49.0  2018     10    1    12      15
# 12003   0.1213      0.0        49.0  2018     10    1    12      15
# 13978   0.1226      0.0        53.0  2018     10    1    12      30
# 23029   0.1226      0.0        53.0  2018     10    1    12      30
#
# [5 rows x 23 columns]

# %%
optimized_estimators = 450
'''max_score = float('-inf')
for n in range(100, 5000, 100):
    model = XGBRegressor(n_estimators=n, learning_rate=0.1)
    scores = cross_val_score(model, X_train, y_train, scoring='neg_root_mean_squared_error', cv=5)
    score_mean = scores.mean()
    print(f"n_estimators: {n}, CV Mean RMSE: {-score_mean}")
    if score_mean > max_score:
        optimized_estimators = n
        max_score = score_mean'''



model = CatBoostRegressor(n_estimators=optimized_estimators, learning_rate=0.1, random_state=10)
scores = cross_val_score(model, X_train, y_train, scoring='neg_root_mean_squared_error', cv=5)
print(scores.mean(), scores.std())
model.fit(X_train, y_train)

y_pred = model.predict(X_train)
evaluate_model(y_train, y_pred)

importances = model.get_feature_importance()
feature_names = X_train.columns

for name, imp in zip(feature_names, importances):
    print(f"{name}: {imp:.4f}")
# Out:
# 0:	learn: 13.6939284	total: 8.65ms	remaining: 3.88s
# 1:	learn: 13.1853714	total: 15ms	remaining: 3.35s
# 2:	learn: 12.7540500	total: 27.1ms	remaining: 4.04s
# 3:	learn: 12.3692089	total: 35.7ms	remaining: 3.98s
# 4:	learn: 12.0379436	total: 43.5ms	remaining: 3.87s
# 5:	learn: 11.7517504	total: 49.3ms	remaining: 3.65s
# 6:	learn: 11.5085719	total: 57.1ms	remaining: 3.61s
# 7:	learn: 11.2927083	total: 63.4ms	remaining: 3.5s
# 8:	learn: 11.1010295	total: 75.4ms	remaining: 3.69s
# 9:	learn: 10.9341883	total: 82.4ms	remaining: 3.63s
# 10:	learn: 10.8004874	total: 93.3ms	remaining: 3.72s
# 11:	learn: 10.6775950	total: 102ms	remaining: 3.73s
# 12:	learn: 10.5617601	total: 112ms	remaining: 3.77s
# 13:	learn: 10.4699982	total: 122ms	remaining: 3.8s
# 14:	learn: 10.3830490	total: 129ms	remaining: 3.75s
# 15:	learn: 10.2998029	total: 138ms	remaining: 3.73s
# 16:	learn: 10.2227520	total: 145ms	remaining: 3.69s
# 17:	learn: 10.1556331	total: 152ms	remaining: 3.64s
# 18:	learn: 10.0931338	total: 158ms	remaining: 3.59s
# 19:	learn: 10.0347970	total: 167ms	remaining: 3.59s
# 20:	learn: 9.9843832	total: 174ms	remaining: 3.56s
# 21:	learn: 9.9348065	total: 181ms	remaining: 3.51s
# 22:	learn: 9.8981363	total: 189ms	remaining: 3.5s
# 23:	learn: 9.8631157	total: 195ms	remaining: 3.46s
# 24:	learn: 9.8270998	total: 203ms	remaining: 3.45s
# 25:	learn: 9.7949955	total: 209ms	remaining: 3.41s
# 26:	learn: 9.7548112	total: 220ms	remaining: 3.44s
# 27:	learn: 9.7187117	total: 227ms	remaining: 3.42s
# 28:	learn: 9.6976534	total: 235ms	remaining: 3.41s
# 29:	learn: 9.6686671	total: 242ms	remaining: 3.38s
# 30:	learn: 9.6397044	total: 253ms	remaining: 3.42s
# 31:	learn: 9.6167961	total: 259ms	remaining: 3.39s
# 32:	learn: 9.5988006	total: 268ms	remaining: 3.38s
# 33:	learn: 9.5747178	total: 274ms	remaining: 3.35s
# 34:	learn: 9.5477720	total: 283ms	remaining: 3.35s
# 35:	learn: 9.5261807	total: 290ms	remaining: 3.34s
# 36:	learn: 9.5056578	total: 299ms	remaining: 3.33s
# 37:	learn: 9.4845164	total: 306ms	remaining: 3.31s
# 38:	learn: 9.4612483	total: 314ms	remaining: 3.31s
# 39:	learn: 9.4429355	total: 321ms	remaining: 3.29s
# 40:	learn: 9.4278187	total: 328ms	remaining: 3.27s
# 41:	learn: 9.4029419	total: 335ms	remaining: 3.25s
# 42:	learn: 9.3848115	total: 342ms	remaining: 3.24s
# 43:	learn: 9.3687696	total: 350ms	remaining: 3.23s
# 44:	learn: 9.3580698	total: 357ms	remaining: 3.21s
# 45:	learn: 9.3447341	total: 365ms	remaining: 3.2s
# 46:	learn: 9.3304351	total: 374ms	remaining: 3.21s
# 47:	learn: 9.3191200	total: 384ms	remaining: 3.21s
# 48:	learn: 9.2980632	total: 392ms	remaining: 3.21s
# 49:	learn: 9.2869443	total: 399ms	remaining: 3.19s
# 50:	learn: 9.2693934	total: 416ms	remaining: 3.25s
# 51:	learn: 9.2557424	total: 425ms	remaining: 3.25s
# 52:	learn: 9.2424469	total: 431ms	remaining: 3.23s
# 53:	learn: 9.2297808	total: 438ms	remaining: 3.21s
# 54:	learn: 9.2126266	total: 447ms	remaining: 3.21s
# 55:	learn: 9.2043407	total: 454ms	remaining: 3.2s
# 56:	learn: 9.1960165	total: 462ms	remaining: 3.18s
# 57:	learn: 9.1785850	total: 469ms	remaining: 3.17s
# 58:	learn: 9.1666709	total: 479ms	remaining: 3.17s
# 59:	learn: 9.1520797	total: 485ms	remaining: 3.15s
# 60:	learn: 9.1454573	total: 493ms	remaining: 3.14s
# 61:	learn: 9.1333289	total: 503ms	remaining: 3.15s
# 62:	learn: 9.1206271	total: 510ms	remaining: 3.13s
# 63:	learn: 9.1096659	total: 521ms	remaining: 3.14s
# 64:	learn: 9.0943385	total: 529ms	remaining: 3.13s
# 65:	learn: 9.0837149	total: 538ms	remaining: 3.13s
# 66:	learn: 9.0738805	total: 545ms	remaining: 3.12s
# 67:	learn: 9.0661850	total: 554ms	remaining: 3.11s
# 68:	learn: 9.0603217	total: 561ms	remaining: 3.1s
# 69:	learn: 9.0497159	total: 570ms	remaining: 3.09s
# 70:	learn: 9.0438367	total: 576ms	remaining: 3.08s
# 71:	learn: 9.0358587	total: 584ms	remaining: 3.06s
# 72:	learn: 9.0261878	total: 591ms	remaining: 3.05s
# 73:	learn: 9.0198879	total: 597ms	remaining: 3.04s
# 74:	learn: 9.0083180	total: 606ms	remaining: 3.03s
# 75:	learn: 9.0044974	total: 613ms	remaining: 3.01s
# 76:	learn: 8.9963997	total: 622ms	remaining: 3.01s
# 77:	learn: 8.9842749	total: 630ms	remaining: 3s
# 78:	learn: 8.9767426	total: 639ms	remaining: 3s
# 79:	learn: 8.9670092	total: 649ms	remaining: 3s
# 80:	learn: 8.9563390	total: 661ms	remaining: 3.01s
# 81:	learn: 8.9474777	total: 670ms	remaining: 3.01s
# 82:	learn: 8.9432637	total: 677ms	remaining: 2.99s
# 83:	learn: 8.9355477	total: 686ms	remaining: 2.99s
# 84:	learn: 8.9234539	total: 693ms	remaining: 2.97s
# 85:	learn: 8.9143174	total: 707ms	remaining: 2.99s
# 86:	learn: 8.9047843	total: 721ms	remaining: 3.01s
# 87:	learn: 8.8974413	total: 738ms	remaining: 3.04s
# 88:	learn: 8.8886062	total: 754ms	remaining: 3.06s
# 89:	learn: 8.8779031	total: 770ms	remaining: 3.08s
# 90:	learn: 8.8718417	total: 789ms	remaining: 3.11s
# 91:	learn: 8.8674418	total: 806ms	remaining: 3.13s
# 92:	learn: 8.8563883	total: 821ms	remaining: 3.15s
# 93:	learn: 8.8460927	total: 836ms	remaining: 3.17s
# 94:	learn: 8.8380954	total: 849ms	remaining: 3.17s
# 95:	learn: 8.8312817	total: 864ms	remaining: 3.19s
# 96:	learn: 8.8259255	total: 881ms	remaining: 3.21s
# 97:	learn: 8.8155573	total: 890ms	remaining: 3.19s
# 98:	learn: 8.8099806	total: 898ms	remaining: 3.18s
# 99:	learn: 8.8047598	total: 907ms	remaining: 3.17s
# 100:	learn: 8.7947244	total: 918ms	remaining: 3.17s
# 101:	learn: 8.7874184	total: 928ms	remaining: 3.17s
# 102:	learn: 8.7838490	total: 935ms	remaining: 3.15s
# 103:	learn: 8.7726279	total: 943ms	remaining: 3.14s
# 104:	learn: 8.7655556	total: 952ms	remaining: 3.13s
# 105:	learn: 8.7578867	total: 962ms	remaining: 3.12s
# 106:	learn: 8.7514019	total: 971ms	remaining: 3.11s
# 107:	learn: 8.7432823	total: 979ms	remaining: 3.1s
# 108:	learn: 8.7351826	total: 988ms	remaining: 3.09s
# 109:	learn: 8.7275700	total: 996ms	remaining: 3.08s
# 110:	learn: 8.7208143	total: 1s	remaining: 3.06s
# 111:	learn: 8.7169265	total: 1.01s	remaining: 3.06s
# 112:	learn: 8.7097444	total: 1.02s	remaining: 3.05s
# 113:	learn: 8.7020378	total: 1.03s	remaining: 3.04s
# 114:	learn: 8.6948506	total: 1.05s	remaining: 3.06s
# 115:	learn: 8.6839922	total: 1.07s	remaining: 3.09s
# 116:	learn: 8.6789175	total: 1.09s	remaining: 3.11s
# 117:	learn: 8.6728918	total: 1.12s	remaining: 3.16s
# 118:	learn: 8.6627414	total: 1.15s	remaining: 3.19s
# 119:	learn: 8.6574698	total: 1.2s	remaining: 3.29s
# 120:	learn: 8.6499544	total: 1.22s	remaining: 3.32s
# 121:	learn: 8.6461905	total: 1.25s	remaining: 3.36s
# 122:	learn: 8.6375158	total: 1.28s	remaining: 3.4s
# 123:	learn: 8.6297492	total: 1.29s	remaining: 3.39s
# 124:	learn: 8.6205311	total: 1.3s	remaining: 3.39s
# 125:	learn: 8.6145120	total: 1.32s	remaining: 3.39s
# 126:	learn: 8.6060429	total: 1.33s	remaining: 3.4s
# 127:	learn: 8.5982085	total: 1.36s	remaining: 3.42s
# 128:	learn: 8.5896950	total: 1.37s	remaining: 3.42s
# 129:	learn: 8.5843421	total: 1.38s	remaining: 3.4s
# 130:	learn: 8.5729312	total: 1.41s	remaining: 3.43s
# 131:	learn: 8.5677742	total: 1.42s	remaining: 3.41s
# 132:	learn: 8.5610789	total: 1.43s	remaining: 3.41s
# 133:	learn: 8.5529463	total: 1.45s	remaining: 3.41s
# 134:	learn: 8.5461638	total: 1.46s	remaining: 3.41s
# 135:	learn: 8.5348525	total: 1.48s	remaining: 3.42s
# 136:	learn: 8.5268497	total: 1.51s	remaining: 3.45s
# 137:	learn: 8.5191192	total: 1.53s	remaining: 3.46s
# 138:	learn: 8.5132846	total: 1.55s	remaining: 3.46s
# 139:	learn: 8.5037916	total: 1.57s	remaining: 3.47s
# 140:	learn: 8.4957935	total: 1.59s	remaining: 3.48s
# 141:	learn: 8.4890994	total: 1.61s	remaining: 3.49s
# 142:	learn: 8.4815282	total: 1.63s	remaining: 3.49s
# 143:	learn: 8.4756338	total: 1.64s	remaining: 3.48s
# 144:	learn: 8.4694373	total: 1.66s	remaining: 3.48s
# 145:	learn: 8.4635545	total: 1.68s	remaining: 3.49s
# 146:	learn: 8.4589111	total: 1.69s	remaining: 3.49s
# 147:	learn: 8.4533795	total: 1.71s	remaining: 3.49s
# 148:	learn: 8.4459911	total: 1.72s	remaining: 3.48s
# 149:	learn: 8.4390196	total: 1.74s	remaining: 3.48s
# 150:	learn: 8.4333472	total: 1.75s	remaining: 3.48s
# 151:	learn: 8.4258925	total: 1.77s	remaining: 3.46s
# 152:	learn: 8.4170240	total: 1.78s	remaining: 3.45s
# 153:	learn: 8.4121345	total: 1.79s	remaining: 3.45s
# 154:	learn: 8.4058036	total: 1.81s	remaining: 3.45s
# 155:	learn: 8.3994167	total: 1.83s	remaining: 3.45s
# 156:	learn: 8.3944280	total: 1.84s	remaining: 3.43s
# 157:	learn: 8.3878600	total: 1.85s	remaining: 3.42s
# 158:	learn: 8.3829543	total: 1.87s	remaining: 3.42s
# 159:	learn: 8.3763214	total: 1.88s	remaining: 3.41s
# 160:	learn: 8.3715154	total: 1.9s	remaining: 3.4s
# 161:	learn: 8.3660757	total: 1.91s	remaining: 3.4s
# 162:	learn: 8.3603042	total: 1.93s	remaining: 3.39s
# 163:	learn: 8.3529600	total: 1.94s	remaining: 3.38s
# 164:	learn: 8.3482300	total: 1.96s	remaining: 3.38s
# 165:	learn: 8.3420863	total: 1.97s	remaining: 3.38s
# 166:	learn: 8.3341764	total: 1.99s	remaining: 3.38s
# 167:	learn: 8.3287047	total: 2.01s	remaining: 3.37s
# 168:	learn: 8.3231643	total: 2.03s	remaining: 3.37s
# 169:	learn: 8.3147959	total: 2.04s	remaining: 3.37s
# 170:	learn: 8.3109712	total: 2.06s	remaining: 3.37s
# 171:	learn: 8.3038453	total: 2.09s	remaining: 3.37s
# 172:	learn: 8.2990389	total: 2.11s	remaining: 3.37s
# 173:	learn: 8.2953825	total: 2.13s	remaining: 3.37s
# 174:	learn: 8.2886018	total: 2.15s	remaining: 3.37s
# 175:	learn: 8.2814004	total: 2.17s	remaining: 3.38s
# 176:	learn: 8.2734583	total: 2.19s	remaining: 3.38s
# 177:	learn: 8.2675705	total: 2.21s	remaining: 3.37s
# 178:	learn: 8.2612765	total: 2.22s	remaining: 3.36s
# 179:	learn: 8.2551430	total: 2.23s	remaining: 3.35s
# 180:	learn: 8.2507945	total: 2.25s	remaining: 3.35s
# 181:	learn: 8.2464495	total: 2.27s	remaining: 3.34s
# 182:	learn: 8.2441052	total: 2.28s	remaining: 3.32s
# 183:	learn: 8.2389252	total: 2.29s	remaining: 3.31s
# 184:	learn: 8.2331451	total: 2.31s	remaining: 3.32s
# 185:	learn: 8.2287680	total: 2.32s	remaining: 3.3s
# 186:	learn: 8.2248356	total: 2.33s	remaining: 3.28s
# 187:	learn: 8.2168764	total: 2.34s	remaining: 3.26s
# 188:	learn: 8.2152805	total: 2.35s	remaining: 3.24s
# 189:	learn: 8.2098287	total: 2.36s	remaining: 3.23s
# 190:	learn: 8.2085969	total: 2.36s	remaining: 3.21s
# 191:	learn: 8.2014831	total: 2.37s	remaining: 3.19s
# 192:	learn: 8.1966598	total: 2.38s	remaining: 3.17s
# 193:	learn: 8.1913364	total: 2.39s	remaining: 3.15s
# 194:	learn: 8.1869602	total: 2.4s	remaining: 3.13s
# 195:	learn: 8.1834828	total: 2.4s	remaining: 3.12s
# 196:	learn: 8.1782008	total: 2.41s	remaining: 3.1s
# 197:	learn: 8.1726868	total: 2.42s	remaining: 3.08s
# 198:	learn: 8.1703264	total: 2.43s	remaining: 3.06s
# 199:	learn: 8.1656066	total: 2.44s	remaining: 3.05s
# 200:	learn: 8.1593025	total: 2.45s	remaining: 3.03s
# 201:	learn: 8.1540130	total: 2.46s	remaining: 3.02s
# 202:	learn: 8.1525816	total: 2.46s	remaining: 3s
# 203:	learn: 8.1475460	total: 2.47s	remaining: 2.98s
# 204:	learn: 8.1401166	total: 2.48s	remaining: 2.96s
# 205:	learn: 8.1359357	total: 2.49s	remaining: 2.94s
# 206:	learn: 8.1345735	total: 2.49s	remaining: 2.93s
# 207:	learn: 8.1291462	total: 2.5s	remaining: 2.91s
# 208:	learn: 8.1230170	total: 2.51s	remaining: 2.89s
# 209:	learn: 8.1186936	total: 2.52s	remaining: 2.88s
# 210:	learn: 8.1135011	total: 2.52s	remaining: 2.86s
# 211:	learn: 8.1089081	total: 2.53s	remaining: 2.84s
# 212:	learn: 8.1048335	total: 2.54s	remaining: 2.83s
# 213:	learn: 8.1000082	total: 2.55s	remaining: 2.81s
# 214:	learn: 8.0967462	total: 2.56s	remaining: 2.8s
# 215:	learn: 8.0920437	total: 2.57s	remaining: 2.78s
# 216:	learn: 8.0851909	total: 2.59s	remaining: 2.79s
# 217:	learn: 8.0811281	total: 2.62s	remaining: 2.79s
# 218:	learn: 8.0764863	total: 2.64s	remaining: 2.78s
# 219:	learn: 8.0714085	total: 2.66s	remaining: 2.78s
# 220:	learn: 8.0668830	total: 2.68s	remaining: 2.78s
# 221:	learn: 8.0609425	total: 2.7s	remaining: 2.77s
# 222:	learn: 8.0574426	total: 2.71s	remaining: 2.76s
# 223:	learn: 8.0542135	total: 2.73s	remaining: 2.75s
# 224:	learn: 8.0485757	total: 2.75s	remaining: 2.75s
# 225:	learn: 8.0417867	total: 2.77s	remaining: 2.75s
# 226:	learn: 8.0381817	total: 2.79s	remaining: 2.74s
# 227:	learn: 8.0346680	total: 2.8s	remaining: 2.73s
# 228:	learn: 8.0292265	total: 2.81s	remaining: 2.71s
# 229:	learn: 8.0250065	total: 2.83s	remaining: 2.71s
# 230:	learn: 8.0215053	total: 2.84s	remaining: 2.69s
# 231:	learn: 8.0173673	total: 2.85s	remaining: 2.68s
# 232:	learn: 8.0150116	total: 2.86s	remaining: 2.67s
# 233:	learn: 8.0098913	total: 2.88s	remaining: 2.66s
# 234:	learn: 8.0059043	total: 2.9s	remaining: 2.65s
# 235:	learn: 8.0006435	total: 2.91s	remaining: 2.64s
# 236:	learn: 7.9948163	total: 2.92s	remaining: 2.63s
# 237:	learn: 7.9893552	total: 2.93s	remaining: 2.61s
# 238:	learn: 7.9882351	total: 2.95s	remaining: 2.6s
# 239:	learn: 7.9821026	total: 2.96s	remaining: 2.59s
# 240:	learn: 7.9777212	total: 2.97s	remaining: 2.58s
# 241:	learn: 7.9730615	total: 2.99s	remaining: 2.57s
# 242:	learn: 7.9690771	total: 3s	remaining: 2.55s
# 243:	learn: 7.9634719	total: 3.01s	remaining: 2.54s
# 244:	learn: 7.9582865	total: 3.02s	remaining: 2.52s
# 245:	learn: 7.9554658	total: 3.04s	remaining: 2.52s
# 246:	learn: 7.9517688	total: 3.05s	remaining: 2.51s
# 247:	learn: 7.9477839	total: 3.07s	remaining: 2.5s
# 248:	learn: 7.9428383	total: 3.08s	remaining: 2.48s
# 249:	learn: 7.9375374	total: 3.09s	remaining: 2.47s
# 250:	learn: 7.9354436	total: 3.11s	remaining: 2.46s
# 251:	learn: 7.9346154	total: 3.12s	remaining: 2.45s
# 252:	learn: 7.9308950	total: 3.13s	remaining: 2.44s
# 253:	learn: 7.9261764	total: 3.14s	remaining: 2.42s
# 254:	learn: 7.9200015	total: 3.17s	remaining: 2.42s
# 255:	learn: 7.9158654	total: 3.19s	remaining: 2.41s
# 256:	learn: 7.9097484	total: 3.19s	remaining: 2.4s
# 257:	learn: 7.9053151	total: 3.21s	remaining: 2.39s
# 258:	learn: 7.8979104	total: 3.22s	remaining: 2.38s
# 259:	learn: 7.8935486	total: 3.24s	remaining: 2.37s
# 260:	learn: 7.8884983	total: 3.25s	remaining: 2.35s
# 261:	learn: 7.8835419	total: 3.26s	remaining: 2.34s
# 262:	learn: 7.8801721	total: 3.27s	remaining: 2.33s
# 263:	learn: 7.8747769	total: 3.29s	remaining: 2.31s
# 264:	learn: 7.8698020	total: 3.29s	remaining: 2.3s
# 265:	learn: 7.8667334	total: 3.3s	remaining: 2.29s
# 266:	learn: 7.8628944	total: 3.33s	remaining: 2.28s
# 267:	learn: 7.8587743	total: 3.35s	remaining: 2.27s
# 268:	learn: 7.8538929	total: 3.36s	remaining: 2.26s
# 269:	learn: 7.8513132	total: 3.37s	remaining: 2.25s
# 270:	learn: 7.8474408	total: 3.39s	remaining: 2.24s
# 271:	learn: 7.8418060	total: 3.41s	remaining: 2.23s
# 272:	learn: 7.8368451	total: 3.43s	remaining: 2.23s
# 273:	learn: 7.8338970	total: 3.45s	remaining: 2.21s
# 274:	learn: 7.8298088	total: 3.46s	remaining: 2.2s
# 275:	learn: 7.8248907	total: 3.47s	remaining: 2.19s
# 276:	learn: 7.8210782	total: 3.48s	remaining: 2.17s
# 277:	learn: 7.8174608	total: 3.49s	remaining: 2.16s
# 278:	learn: 7.8144251	total: 3.5s	remaining: 2.14s
# 279:	learn: 7.8114019	total: 3.51s	remaining: 2.13s
# 280:	learn: 7.8082444	total: 3.52s	remaining: 2.12s
# 281:	learn: 7.8047259	total: 3.53s	remaining: 2.1s
# 282:	learn: 7.8013518	total: 3.54s	remaining: 2.09s
# 283:	learn: 7.7979646	total: 3.55s	remaining: 2.08s
# 284:	learn: 7.7949588	total: 3.56s	remaining: 2.06s
# 285:	learn: 7.7910173	total: 3.59s	remaining: 2.06s
# 286:	learn: 7.7858368	total: 3.6s	remaining: 2.04s
# 287:	learn: 7.7815376	total: 3.63s	remaining: 2.04s
# 288:	learn: 7.7776049	total: 3.65s	remaining: 2.03s
# 289:	learn: 7.7731169	total: 3.67s	remaining: 2.02s
# 290:	learn: 7.7697912	total: 3.68s	remaining: 2.01s
# 291:	learn: 7.7650315	total: 3.69s	remaining: 2s
# 292:	learn: 7.7622663	total: 3.7s	remaining: 1.98s
# 293:	learn: 7.7601555	total: 3.71s	remaining: 1.97s
# 294:	learn: 7.7572657	total: 3.73s	remaining: 1.96s
# 295:	learn: 7.7539492	total: 3.74s	remaining: 1.95s
# 296:	learn: 7.7501906	total: 3.75s	remaining: 1.93s
# 297:	learn: 7.7451520	total: 3.77s	remaining: 1.92s
# 298:	learn: 7.7442306	total: 3.78s	remaining: 1.91s
# 299:	learn: 7.7405775	total: 3.8s	remaining: 1.9s
# 300:	learn: 7.7355370	total: 3.81s	remaining: 1.89s
# 301:	learn: 7.7328065	total: 3.83s	remaining: 1.88s
# 302:	learn: 7.7294217	total: 3.84s	remaining: 1.86s
# 303:	learn: 7.7258809	total: 3.86s	remaining: 1.85s
# 304:	learn: 7.7201290	total: 3.87s	remaining: 1.84s
# 305:	learn: 7.7162737	total: 3.88s	remaining: 1.82s
# 306:	learn: 7.7114586	total: 3.89s	remaining: 1.81s
# 307:	learn: 7.7073381	total: 3.91s	remaining: 1.8s
# 308:	learn: 7.7012513	total: 3.92s	remaining: 1.79s
# 309:	learn: 7.6969291	total: 3.93s	remaining: 1.78s
# 310:	learn: 7.6923914	total: 3.95s	remaining: 1.76s
# 311:	learn: 7.6895256	total: 3.97s	remaining: 1.76s
# 312:	learn: 7.6844407	total: 3.99s	remaining: 1.75s
# 313:	learn: 7.6814928	total: 4s	remaining: 1.73s
# 314:	learn: 7.6782103	total: 4.01s	remaining: 1.72s
# 315:	learn: 7.6748451	total: 4.02s	remaining: 1.71s
# 316:	learn: 7.6711156	total: 4.04s	remaining: 1.69s
# 317:	learn: 7.6684429	total: 4.05s	remaining: 1.68s
# 318:	learn: 7.6641807	total: 4.06s	remaining: 1.67s
# 319:	learn: 7.6602940	total: 4.08s	remaining: 1.66s
# 320:	learn: 7.6560571	total: 4.1s	remaining: 1.65s
# 321:	learn: 7.6531326	total: 4.12s	remaining: 1.64s
# 322:	learn: 7.6479229	total: 4.14s	remaining: 1.63s
# 323:	learn: 7.6438314	total: 4.15s	remaining: 1.61s
# 324:	learn: 7.6380635	total: 4.17s	remaining: 1.6s
# 325:	learn: 7.6357608	total: 4.18s	remaining: 1.59s
# 326:	learn: 7.6322274	total: 4.2s	remaining: 1.58s
# 327:	learn: 7.6279363	total: 4.23s	remaining: 1.57s
# 328:	learn: 7.6237508	total: 4.26s	remaining: 1.57s
# 329:	learn: 7.6188521	total: 4.28s	remaining: 1.56s
# 330:	learn: 7.6157411	total: 4.29s	remaining: 1.54s
# 331:	learn: 7.6128073	total: 4.31s	remaining: 1.53s
# 332:	learn: 7.6095490	total: 4.33s	remaining: 1.52s
# 333:	learn: 7.6055925	total: 4.35s	remaining: 1.51s
# 334:	learn: 7.6023618	total: 4.37s	remaining: 1.5s
# 335:	learn: 7.5989990	total: 4.39s	remaining: 1.49s
# 336:	learn: 7.5961231	total: 4.42s	remaining: 1.48s
# 337:	learn: 7.5923039	total: 4.43s	remaining: 1.47s
# 338:	learn: 7.5881341	total: 4.44s	remaining: 1.45s
# 339:	learn: 7.5844737	total: 4.45s	remaining: 1.44s
# 340:	learn: 7.5799410	total: 4.46s	remaining: 1.43s
# 341:	learn: 7.5775806	total: 4.47s	remaining: 1.41s
# 342:	learn: 7.5744788	total: 4.49s	remaining: 1.4s
# 343:	learn: 7.5712637	total: 4.5s	remaining: 1.39s
# 344:	learn: 7.5680254	total: 4.51s	remaining: 1.37s
# 345:	learn: 7.5649851	total: 4.52s	remaining: 1.36s
# 346:	learn: 7.5597059	total: 4.54s	remaining: 1.35s
# 347:	learn: 7.5552507	total: 4.56s	remaining: 1.33s
# 348:	learn: 7.5524488	total: 4.57s	remaining: 1.32s
# 349:	learn: 7.5501850	total: 4.58s	remaining: 1.31s
# 350:	learn: 7.5482848	total: 4.59s	remaining: 1.29s
# 351:	learn: 7.5468348	total: 4.61s	remaining: 1.28s
# 352:	learn: 7.5445512	total: 4.62s	remaining: 1.27s
# 353:	learn: 7.5426250	total: 4.64s	remaining: 1.26s
# 354:	learn: 7.5401833	total: 4.67s	remaining: 1.25s
# 355:	learn: 7.5358666	total: 4.7s	remaining: 1.24s
# 356:	learn: 7.5333298	total: 4.72s	remaining: 1.23s
# 357:	learn: 7.5305803	total: 4.73s	remaining: 1.22s
# 358:	learn: 7.5266316	total: 4.74s	remaining: 1.2s
# 359:	learn: 7.5229096	total: 4.75s	remaining: 1.19s
# 360:	learn: 7.5180110	total: 4.75s	remaining: 1.17s
# 361:	learn: 7.5154241	total: 4.76s	remaining: 1.16s
# 362:	learn: 7.5134476	total: 4.77s	remaining: 1.14s
# 363:	learn: 7.5106799	total: 4.78s	remaining: 1.13s
# 364:	learn: 7.5076491	total: 4.79s	remaining: 1.11s
# 365:	learn: 7.5059458	total: 4.79s	remaining: 1.1s
# 366:	learn: 7.5010230	total: 4.8s	remaining: 1.09s
# 367:	learn: 7.4978907	total: 4.81s	remaining: 1.07s
# 368:	learn: 7.4957906	total: 4.82s	remaining: 1.06s
# 369:	learn: 7.4938038	total: 4.83s	remaining: 1.04s
# 370:	learn: 7.4918069	total: 4.84s	remaining: 1.03s
# 371:	learn: 7.4879806	total: 4.85s	remaining: 1.02s
# 372:	learn: 7.4855649	total: 4.86s	remaining: 1s
# 373:	learn: 7.4831806	total: 4.87s	remaining: 990ms
# 374:	learn: 7.4799438	total: 4.88s	remaining: 976ms
# 375:	learn: 7.4766285	total: 4.89s	remaining: 963ms
# 376:	learn: 7.4745200	total: 4.9s	remaining: 949ms
# 377:	learn: 7.4715285	total: 4.91s	remaining: 935ms
# 378:	learn: 7.4682801	total: 4.92s	remaining: 921ms
# 379:	learn: 7.4626786	total: 4.92s	remaining: 907ms
# 380:	learn: 7.4592158	total: 4.94s	remaining: 894ms
# 381:	learn: 7.4560688	total: 4.94s	remaining: 880ms
# 382:	learn: 7.4530585	total: 4.95s	remaining: 866ms
# 383:	learn: 7.4497377	total: 4.96s	remaining: 853ms
# 384:	learn: 7.4448305	total: 4.97s	remaining: 840ms
# 385:	learn: 7.4411520	total: 4.98s	remaining: 826ms
# 386:	learn: 7.4389587	total: 4.99s	remaining: 813ms
# 387:	learn: 7.4357955	total: 5s	remaining: 799ms
# 388:	learn: 7.4318046	total: 5.01s	remaining: 786ms
# 389:	learn: 7.4281110	total: 5.02s	remaining: 772ms
# 390:	learn: 7.4242025	total: 5.03s	remaining: 759ms
# 391:	learn: 7.4193328	total: 5.09s	remaining: 754ms
# 392:	learn: 7.4146271	total: 5.11s	remaining: 741ms
# 393:	learn: 7.4111976	total: 5.15s	remaining: 732ms
# 394:	learn: 7.4072825	total: 5.17s	remaining: 719ms
# 395:	learn: 7.4041100	total: 5.18s	remaining: 707ms
# 396:	learn: 7.4016911	total: 5.19s	remaining: 693ms
# 397:	learn: 7.3998884	total: 5.21s	remaining: 680ms
# 398:	learn: 7.3966427	total: 5.22s	remaining: 667ms
# 399:	learn: 7.3942286	total: 5.23s	remaining: 654ms
# 400:	learn: 7.3900451	total: 5.25s	remaining: 641ms
# 401:	learn: 7.3875761	total: 5.26s	remaining: 628ms
# 402:	learn: 7.3840127	total: 5.26s	remaining: 614ms
# 403:	learn: 7.3807946	total: 5.28s	remaining: 602ms
# 404:	learn: 7.3779874	total: 5.29s	remaining: 588ms
# 405:	learn: 7.3755211	total: 5.31s	remaining: 575ms
# 406:	learn: 7.3727558	total: 5.32s	remaining: 562ms
# 407:	learn: 7.3697476	total: 5.33s	remaining: 549ms
# 408:	learn: 7.3671525	total: 5.34s	remaining: 536ms
# 409:	learn: 7.3655532	total: 5.36s	remaining: 523ms
# 410:	learn: 7.3634487	total: 5.37s	remaining: 510ms
# 411:	learn: 7.3606299	total: 5.38s	remaining: 496ms
# 412:	learn: 7.3573689	total: 5.39s	remaining: 483ms
# 413:	learn: 7.3544376	total: 5.39s	remaining: 469ms
# 414:	learn: 7.3515357	total: 5.4s	remaining: 456ms
# 415:	learn: 7.3489972	total: 5.41s	remaining: 442ms
# 416:	learn: 7.3462061	total: 5.42s	remaining: 429ms
# 417:	learn: 7.3434939	total: 5.43s	remaining: 415ms
# 418:	learn: 7.3398706	total: 5.44s	remaining: 402ms
# 419:	learn: 7.3350698	total: 5.45s	remaining: 389ms
# 420:	learn: 7.3333916	total: 5.46s	remaining: 376ms
# 421:	learn: 7.3302963	total: 5.46s	remaining: 363ms
# 422:	learn: 7.3281603	total: 5.47s	remaining: 349ms
# 423:	learn: 7.3251815	total: 5.48s	remaining: 336ms
# 424:	learn: 7.3233993	total: 5.49s	remaining: 323ms
# 425:	learn: 7.3208632	total: 5.5s	remaining: 310ms
# 426:	learn: 7.3182372	total: 5.51s	remaining: 297ms
# 427:	learn: 7.3162638	total: 5.52s	remaining: 284ms
# 428:	learn: 7.3110015	total: 5.52s	remaining: 270ms
# 429:	learn: 7.3075242	total: 5.54s	remaining: 257ms
# 430:	learn: 7.3057936	total: 5.54s	remaining: 244ms
# 431:	learn: 7.3029730	total: 5.55s	remaining: 231ms
# 432:	learn: 7.2991057	total: 5.56s	remaining: 218ms
# 433:	learn: 7.2963823	total: 5.57s	remaining: 205ms
# 434:	learn: 7.2936910	total: 5.58s	remaining: 192ms
# 435:	learn: 7.2908360	total: 5.59s	remaining: 179ms
# 436:	learn: 7.2882885	total: 5.6s	remaining: 166ms
# 437:	learn: 7.2836562	total: 5.61s	remaining: 154ms
# 438:	learn: 7.2789218	total: 5.62s	remaining: 141ms
# 439:	learn: 7.2764500	total: 5.63s	remaining: 128ms
# 440:	learn: 7.2726800	total: 5.75s	remaining: 117ms
# 441:	learn: 7.2706164	total: 5.77s	remaining: 104ms
# 442:	learn: 7.2681112	total: 5.78s	remaining: 91.4ms
# 443:	learn: 7.2648978	total: 5.8s	remaining: 78.4ms
# 444:	learn: 7.2623329	total: 5.86s	remaining: 65.9ms
# 445:	learn: 7.2601282	total: 5.92s	remaining: 53.1ms
# 446:	learn: 7.2573105	total: 6s	remaining: 40.3ms
# 447:	learn: 7.2562176	total: 6.09s	remaining: 27.2ms
# 448:	learn: 7.2537159	total: 6.12s	remaining: 13.6ms
# 449:	learn: 7.2527494	total: 6.15s	remaining: 0us
# 0:	learn: 13.6616844	total: 18.9ms	remaining: 8.5s
# 1:	learn: 13.1399314	total: 44.2ms	remaining: 9.9s
# 2:	learn: 12.6998797	total: 62.6ms	remaining: 9.32s
# 3:	learn: 12.3130878	total: 80.4ms	remaining: 8.97s
# 4:	learn: 11.9896785	total: 101ms	remaining: 8.97s
# 5:	learn: 11.7097299	total: 114ms	remaining: 8.47s
# 6:	learn: 11.4513531	total: 129ms	remaining: 8.19s
# 7:	learn: 11.2398929	total: 141ms	remaining: 7.78s
# 8:	learn: 11.0542191	total: 152ms	remaining: 7.43s
# 9:	learn: 10.8875997	total: 164ms	remaining: 7.23s
# 10:	learn: 10.7508045	total: 178ms	remaining: 7.1s
# 11:	learn: 10.6303954	total: 199ms	remaining: 7.25s
# 12:	learn: 10.5168065	total: 212ms	remaining: 7.11s
# 13:	learn: 10.4262425	total: 225ms	remaining: 7.01s
# 14:	learn: 10.3375362	total: 239ms	remaining: 6.92s
# 15:	learn: 10.2612438	total: 256ms	remaining: 6.95s
# 16:	learn: 10.1919359	total: 272ms	remaining: 6.92s
# 17:	learn: 10.1348942	total: 282ms	remaining: 6.76s
# 18:	learn: 10.0775269	total: 293ms	remaining: 6.64s
# 19:	learn: 10.0202209	total: 307ms	remaining: 6.61s
# 20:	learn: 9.9652937	total: 319ms	remaining: 6.51s
# 21:	learn: 9.9153893	total: 330ms	remaining: 6.42s
# 22:	learn: 9.8665530	total: 350ms	remaining: 6.5s
# 23:	learn: 9.8235180	total: 359ms	remaining: 6.38s
# 24:	learn: 9.7873107	total: 374ms	remaining: 6.35s
# 25:	learn: 9.7560464	total: 385ms	remaining: 6.27s
# 26:	learn: 9.7229473	total: 395ms	remaining: 6.19s
# 27:	learn: 9.6980592	total: 405ms	remaining: 6.11s
# 28:	learn: 9.6656335	total: 417ms	remaining: 6.05s
# 29:	learn: 9.6314899	total: 425ms	remaining: 5.95s
# 30:	learn: 9.6033372	total: 437ms	remaining: 5.9s
# 31:	learn: 9.5807095	total: 447ms	remaining: 5.84s
# 32:	learn: 9.5538264	total: 463ms	remaining: 5.85s
# 33:	learn: 9.5321039	total: 484ms	remaining: 5.93s
# 34:	learn: 9.5143559	total: 498ms	remaining: 5.9s
# 35:	learn: 9.4958970	total: 507ms	remaining: 5.83s
# 36:	learn: 9.4766000	total: 518ms	remaining: 5.78s
# 37:	learn: 9.4533751	total: 529ms	remaining: 5.73s
# 38:	learn: 9.4325384	total: 537ms	remaining: 5.66s
# 39:	learn: 9.4128887	total: 549ms	remaining: 5.62s
# 40:	learn: 9.3996103	total: 557ms	remaining: 5.55s
# 41:	learn: 9.3872650	total: 567ms	remaining: 5.51s
# 42:	learn: 9.3694553	total: 577ms	remaining: 5.46s
# 43:	learn: 9.3547606	total: 587ms	remaining: 5.41s
# 44:	learn: 9.3445189	total: 596ms	remaining: 5.36s
# 45:	learn: 9.3331749	total: 604ms	remaining: 5.3s
# 46:	learn: 9.3213063	total: 624ms	remaining: 5.35s
# 47:	learn: 9.3070886	total: 633ms	remaining: 5.3s
# 48:	learn: 9.2884325	total: 642ms	remaining: 5.26s
# 49:	learn: 9.2773934	total: 650ms	remaining: 5.2s
# 50:	learn: 9.2664174	total: 663ms	remaining: 5.19s
# 51:	learn: 9.2530021	total: 673ms	remaining: 5.15s
# 52:	learn: 9.2428499	total: 681ms	remaining: 5.1s
# 53:	learn: 9.2310231	total: 693ms	remaining: 5.08s
# 54:	learn: 9.2158889	total: 702ms	remaining: 5.04s
# 55:	learn: 9.2020854	total: 712ms	remaining: 5.01s
# 56:	learn: 9.1904323	total: 721ms	remaining: 4.97s
# 57:	learn: 9.1809720	total: 729ms	remaining: 4.93s
# 58:	learn: 9.1699798	total: 739ms	remaining: 4.9s
# 59:	learn: 9.1514112	total: 748ms	remaining: 4.87s
# 60:	learn: 9.1399780	total: 757ms	remaining: 4.83s
# 61:	learn: 9.1295228	total: 764ms	remaining: 4.78s
# 62:	learn: 9.1213433	total: 773ms	remaining: 4.75s
# 63:	learn: 9.1076153	total: 781ms	remaining: 4.71s
# 64:	learn: 9.0936122	total: 789ms	remaining: 4.67s
# 65:	learn: 9.0784479	total: 796ms	remaining: 4.63s
# 66:	learn: 9.0663874	total: 805ms	remaining: 4.6s
# 67:	learn: 9.0579915	total: 811ms	remaining: 4.56s
# 68:	learn: 9.0509331	total: 820ms	remaining: 4.53s
# 69:	learn: 9.0423696	total: 829ms	remaining: 4.5s
# 70:	learn: 9.0355010	total: 838ms	remaining: 4.47s
# 71:	learn: 9.0268974	total: 846ms	remaining: 4.44s
# 72:	learn: 9.0145688	total: 856ms	remaining: 4.42s
# 73:	learn: 9.0060808	total: 875ms	remaining: 4.45s
# 74:	learn: 9.0013851	total: 886ms	remaining: 4.43s
# 75:	learn: 8.9900665	total: 898ms	remaining: 4.42s
# 76:	learn: 8.9767227	total: 906ms	remaining: 4.39s
# 77:	learn: 8.9713888	total: 914ms	remaining: 4.36s
# 78:	learn: 8.9648097	total: 921ms	remaining: 4.33s
# 79:	learn: 8.9475738	total: 930ms	remaining: 4.3s
# 80:	learn: 8.9421910	total: 938ms	remaining: 4.27s
# 81:	learn: 8.9355170	total: 949ms	remaining: 4.26s
# 82:	learn: 8.9253516	total: 959ms	remaining: 4.24s
# 83:	learn: 8.9159294	total: 968ms	remaining: 4.22s
# 84:	learn: 8.9041732	total: 976ms	remaining: 4.19s
# 85:	learn: 8.8952040	total: 984ms	remaining: 4.16s
# 86:	learn: 8.8881654	total: 992ms	remaining: 4.14s
# 87:	learn: 8.8775591	total: 1s	remaining: 4.12s
# 88:	learn: 8.8662012	total: 1.01s	remaining: 4.09s
# 89:	learn: 8.8587484	total: 1.02s	remaining: 4.07s
# 90:	learn: 8.8519138	total: 1.03s	remaining: 4.06s
# 91:	learn: 8.8430103	total: 1.05s	remaining: 4.07s
# 92:	learn: 8.8357523	total: 1.05s	remaining: 4.05s
# 93:	learn: 8.8309630	total: 1.07s	remaining: 4.04s
# 94:	learn: 8.8217468	total: 1.08s	remaining: 4.03s
# 95:	learn: 8.8183254	total: 1.09s	remaining: 4.03s
# 96:	learn: 8.8115043	total: 1.11s	remaining: 4.03s
# 97:	learn: 8.7990872	total: 1.12s	remaining: 4.03s
# 98:	learn: 8.7900262	total: 1.13s	remaining: 4.02s
# 99:	learn: 8.7852649	total: 1.15s	remaining: 4.01s
# 100:	learn: 8.7795914	total: 1.16s	remaining: 4s
# 101:	learn: 8.7709758	total: 1.17s	remaining: 4s
# 102:	learn: 8.7639109	total: 1.19s	remaining: 4s
# 103:	learn: 8.7542961	total: 1.21s	remaining: 4.01s
# 104:	learn: 8.7475436	total: 1.22s	remaining: 4.01s
# 105:	learn: 8.7437037	total: 1.24s	remaining: 4.01s
# 106:	learn: 8.7379687	total: 1.25s	remaining: 4s
# 107:	learn: 8.7275546	total: 1.25s	remaining: 3.97s
# 108:	learn: 8.7229504	total: 1.27s	remaining: 3.97s
# 109:	learn: 8.7159828	total: 1.28s	remaining: 3.94s
# 110:	learn: 8.7094720	total: 1.28s	remaining: 3.92s
# 111:	learn: 8.7026796	total: 1.29s	remaining: 3.91s
# 112:	learn: 8.6950932	total: 1.3s	remaining: 3.88s
# 113:	learn: 8.6888556	total: 1.31s	remaining: 3.87s
# 114:	learn: 8.6803655	total: 1.32s	remaining: 3.85s
# 115:	learn: 8.6724917	total: 1.33s	remaining: 3.84s
# 116:	learn: 8.6680112	total: 1.34s	remaining: 3.82s
# 117:	learn: 8.6578594	total: 1.35s	remaining: 3.81s
# 118:	learn: 8.6507192	total: 1.36s	remaining: 3.79s
# 119:	learn: 8.6442900	total: 1.37s	remaining: 3.77s
# 120:	learn: 8.6370550	total: 1.38s	remaining: 3.76s
# 121:	learn: 8.6291343	total: 1.39s	remaining: 3.75s
# 122:	learn: 8.6218476	total: 1.4s	remaining: 3.72s
# 123:	learn: 8.6154963	total: 1.41s	remaining: 3.71s
# 124:	learn: 8.6079850	total: 1.42s	remaining: 3.69s
# 125:	learn: 8.6002118	total: 1.43s	remaining: 3.67s
# 126:	learn: 8.5915825	total: 1.43s	remaining: 3.65s
# 127:	learn: 8.5856813	total: 1.44s	remaining: 3.63s
# 128:	learn: 8.5790228	total: 1.45s	remaining: 3.61s
# 129:	learn: 8.5713465	total: 1.46s	remaining: 3.58s
# 130:	learn: 8.5654368	total: 1.46s	remaining: 3.57s
# 131:	learn: 8.5594834	total: 1.47s	remaining: 3.55s
# 132:	learn: 8.5546183	total: 1.49s	remaining: 3.55s
# 133:	learn: 8.5462497	total: 1.5s	remaining: 3.53s
# 134:	learn: 8.5391570	total: 1.5s	remaining: 3.51s
# 135:	learn: 8.5317285	total: 1.51s	remaining: 3.5s
# 136:	learn: 8.5226196	total: 1.52s	remaining: 3.48s
# 137:	learn: 8.5166409	total: 1.53s	remaining: 3.46s
# 138:	learn: 8.5092522	total: 1.55s	remaining: 3.47s
# 139:	learn: 8.5009746	total: 1.56s	remaining: 3.46s
# 140:	learn: 8.4918647	total: 1.57s	remaining: 3.45s
# 141:	learn: 8.4857475	total: 1.59s	remaining: 3.44s
# 142:	learn: 8.4819923	total: 1.59s	remaining: 3.42s
# 143:	learn: 8.4758594	total: 1.6s	remaining: 3.41s
# 144:	learn: 8.4718495	total: 1.61s	remaining: 3.39s
# 145:	learn: 8.4665133	total: 1.62s	remaining: 3.37s
# 146:	learn: 8.4580805	total: 1.63s	remaining: 3.36s
# 147:	learn: 8.4516285	total: 1.64s	remaining: 3.34s
# 148:	learn: 8.4450989	total: 1.64s	remaining: 3.32s
# 149:	learn: 8.4415244	total: 1.65s	remaining: 3.3s
# 150:	learn: 8.4352184	total: 1.66s	remaining: 3.28s
# 151:	learn: 8.4280249	total: 1.67s	remaining: 3.27s
# 152:	learn: 8.4198911	total: 1.68s	remaining: 3.26s
# 153:	learn: 8.4150642	total: 1.69s	remaining: 3.25s
# 154:	learn: 8.4121686	total: 1.7s	remaining: 3.23s
# 155:	learn: 8.4081029	total: 1.71s	remaining: 3.21s
# 156:	learn: 8.4007579	total: 1.71s	remaining: 3.2s
# 157:	learn: 8.3950286	total: 1.72s	remaining: 3.18s
# 158:	learn: 8.3898346	total: 1.73s	remaining: 3.16s
# 159:	learn: 8.3807559	total: 1.74s	remaining: 3.15s
# 160:	learn: 8.3749698	total: 1.74s	remaining: 3.13s
# 161:	learn: 8.3670532	total: 1.75s	remaining: 3.11s
# 162:	learn: 8.3576302	total: 1.76s	remaining: 3.1s
# 163:	learn: 8.3553852	total: 1.77s	remaining: 3.09s
# 164:	learn: 8.3500658	total: 1.78s	remaining: 3.07s
# 165:	learn: 8.3443266	total: 1.79s	remaining: 3.06s
# 166:	learn: 8.3368809	total: 1.79s	remaining: 3.04s
# 167:	learn: 8.3332815	total: 1.8s	remaining: 3.02s
# 168:	learn: 8.3277301	total: 1.81s	remaining: 3.01s
# 169:	learn: 8.3205503	total: 1.82s	remaining: 2.99s
# 170:	learn: 8.3133998	total: 1.82s	remaining: 2.98s
# 171:	learn: 8.3088163	total: 1.83s	remaining: 2.96s
# 172:	learn: 8.3035219	total: 1.84s	remaining: 2.95s
# 173:	learn: 8.2980069	total: 1.85s	remaining: 2.93s
# 174:	learn: 8.2904609	total: 1.86s	remaining: 2.92s
# 175:	learn: 8.2846686	total: 1.86s	remaining: 2.9s
# 176:	learn: 8.2805334	total: 1.87s	remaining: 2.89s
# 177:	learn: 8.2753535	total: 1.88s	remaining: 2.88s
# 178:	learn: 8.2705241	total: 1.89s	remaining: 2.87s
# 179:	learn: 8.2652812	total: 1.9s	remaining: 2.85s
# 180:	learn: 8.2597701	total: 1.92s	remaining: 2.85s
# 181:	learn: 8.2543307	total: 1.93s	remaining: 2.84s
# 182:	learn: 8.2524047	total: 1.94s	remaining: 2.83s
# 183:	learn: 8.2478256	total: 1.95s	remaining: 2.82s
# 184:	learn: 8.2427319	total: 1.96s	remaining: 2.81s
# 185:	learn: 8.2367359	total: 1.97s	remaining: 2.79s
# 186:	learn: 8.2303715	total: 1.98s	remaining: 2.78s
# 187:	learn: 8.2255005	total: 1.99s	remaining: 2.77s
# 188:	learn: 8.2172185	total: 2s	remaining: 2.76s
# 189:	learn: 8.2113045	total: 2.01s	remaining: 2.75s
# 190:	learn: 8.2069099	total: 2.02s	remaining: 2.74s
# 191:	learn: 8.2027306	total: 2.03s	remaining: 2.73s
# 192:	learn: 8.1977215	total: 2.05s	remaining: 2.73s
# 193:	learn: 8.1936452	total: 2.06s	remaining: 2.72s
# 194:	learn: 8.1904999	total: 2.07s	remaining: 2.71s
# 195:	learn: 8.1865572	total: 2.08s	remaining: 2.7s
# 196:	learn: 8.1806440	total: 2.1s	remaining: 2.7s
# 197:	learn: 8.1754505	total: 2.11s	remaining: 2.69s
# 198:	learn: 8.1682089	total: 2.13s	remaining: 2.68s
# 199:	learn: 8.1629712	total: 2.13s	remaining: 2.67s
# 200:	learn: 8.1587335	total: 2.14s	remaining: 2.66s
# 201:	learn: 8.1542956	total: 2.15s	remaining: 2.64s
# 202:	learn: 8.1489670	total: 2.16s	remaining: 2.63s
# 203:	learn: 8.1429157	total: 2.17s	remaining: 2.62s
# 204:	learn: 8.1386000	total: 2.19s	remaining: 2.62s
# 205:	learn: 8.1332260	total: 2.2s	remaining: 2.61s
# 206:	learn: 8.1315277	total: 2.22s	remaining: 2.6s
# 207:	learn: 8.1248803	total: 2.23s	remaining: 2.6s
# 208:	learn: 8.1217987	total: 2.25s	remaining: 2.59s
# 209:	learn: 8.1174315	total: 2.26s	remaining: 2.58s
# 210:	learn: 8.1112876	total: 2.27s	remaining: 2.57s
# 211:	learn: 8.1046423	total: 2.28s	remaining: 2.56s
# 212:	learn: 8.1012752	total: 2.31s	remaining: 2.56s
# 213:	learn: 8.0944851	total: 2.33s	remaining: 2.56s
# 214:	learn: 8.0871267	total: 2.34s	remaining: 2.56s
# 215:	learn: 8.0806842	total: 2.36s	remaining: 2.56s
# 216:	learn: 8.0740821	total: 2.37s	remaining: 2.55s
# 217:	learn: 8.0685912	total: 2.38s	remaining: 2.54s
# 218:	learn: 8.0622880	total: 2.39s	remaining: 2.52s
# 219:	learn: 8.0554614	total: 2.4s	remaining: 2.51s
# 220:	learn: 8.0521932	total: 2.41s	remaining: 2.49s
# 221:	learn: 8.0474762	total: 2.41s	remaining: 2.48s
# 222:	learn: 8.0411802	total: 2.42s	remaining: 2.46s
# 223:	learn: 8.0351997	total: 2.43s	remaining: 2.45s
# 224:	learn: 8.0301105	total: 2.44s	remaining: 2.44s
# 225:	learn: 8.0258746	total: 2.44s	remaining: 2.42s
# 226:	learn: 8.0214178	total: 2.45s	remaining: 2.41s
# 227:	learn: 8.0158667	total: 2.46s	remaining: 2.4s
# 228:	learn: 8.0148570	total: 2.47s	remaining: 2.38s
# 229:	learn: 8.0106971	total: 2.47s	remaining: 2.37s
# 230:	learn: 8.0048274	total: 2.48s	remaining: 2.35s
# 231:	learn: 7.9996440	total: 2.49s	remaining: 2.34s
# 232:	learn: 7.9953376	total: 2.51s	remaining: 2.33s
# 233:	learn: 7.9909640	total: 2.52s	remaining: 2.32s
# 234:	learn: 7.9839168	total: 2.52s	remaining: 2.31s
# 235:	learn: 7.9811184	total: 2.53s	remaining: 2.3s
# 236:	learn: 7.9758738	total: 2.54s	remaining: 2.28s
# 237:	learn: 7.9724671	total: 2.56s	remaining: 2.28s
# 238:	learn: 7.9672597	total: 2.59s	remaining: 2.29s
# 239:	learn: 7.9618003	total: 2.6s	remaining: 2.28s
# 240:	learn: 7.9562180	total: 2.61s	remaining: 2.27s
# 241:	learn: 7.9508024	total: 2.62s	remaining: 2.25s
# 242:	learn: 7.9498765	total: 2.63s	remaining: 2.24s
# 243:	learn: 7.9451840	total: 2.64s	remaining: 2.23s
# 244:	learn: 7.9403682	total: 2.65s	remaining: 2.21s
# 245:	learn: 7.9363132	total: 2.65s	remaining: 2.2s
# 246:	learn: 7.9309392	total: 2.66s	remaining: 2.19s
# 247:	learn: 7.9260109	total: 2.67s	remaining: 2.17s
# 248:	learn: 7.9210494	total: 2.68s	remaining: 2.16s
# 249:	learn: 7.9184014	total: 2.69s	remaining: 2.15s
# 250:	learn: 7.9131464	total: 2.7s	remaining: 2.14s
# 251:	learn: 7.9130179	total: 2.71s	remaining: 2.13s
# 252:	learn: 7.9111698	total: 2.72s	remaining: 2.12s
# 253:	learn: 7.9067828	total: 2.72s	remaining: 2.1s
# 254:	learn: 7.9015904	total: 2.73s	remaining: 2.09s
# 255:	learn: 7.8948675	total: 2.74s	remaining: 2.08s
# 256:	learn: 7.8909906	total: 2.75s	remaining: 2.06s
# 257:	learn: 7.8861231	total: 2.76s	remaining: 2.05s
# 258:	learn: 7.8818296	total: 2.77s	remaining: 2.04s
# 259:	learn: 7.8806455	total: 2.78s	remaining: 2.03s
# 260:	learn: 7.8765389	total: 2.78s	remaining: 2.02s
# 261:	learn: 7.8718275	total: 2.79s	remaining: 2s
# 262:	learn: 7.8668665	total: 2.8s	remaining: 1.99s
# 263:	learn: 7.8630386	total: 2.81s	remaining: 1.98s
# 264:	learn: 7.8573764	total: 2.82s	remaining: 1.97s
# 265:	learn: 7.8528404	total: 2.82s	remaining: 1.95s
# 266:	learn: 7.8486548	total: 2.83s	remaining: 1.94s
# 267:	learn: 7.8436957	total: 2.84s	remaining: 1.93s
# 268:	learn: 7.8381451	total: 2.85s	remaining: 1.91s
# 269:	learn: 7.8325892	total: 2.86s	remaining: 1.91s
# 270:	learn: 7.8290859	total: 2.87s	remaining: 1.9s
# 271:	learn: 7.8219413	total: 2.91s	remaining: 1.9s
# 272:	learn: 7.8182550	total: 2.93s	remaining: 1.9s
# 273:	learn: 7.8150689	total: 2.95s	remaining: 1.89s
# 274:	learn: 7.8105486	total: 2.96s	remaining: 1.88s
# 275:	learn: 7.8065544	total: 2.98s	remaining: 1.88s
# 276:	learn: 7.8018708	total: 2.99s	remaining: 1.87s
# 277:	learn: 7.7983780	total: 3s	remaining: 1.85s
# 278:	learn: 7.7956807	total: 3.01s	remaining: 1.84s
# 279:	learn: 7.7886650	total: 3.02s	remaining: 1.83s
# 280:	learn: 7.7825037	total: 3.03s	remaining: 1.82s
# 281:	learn: 7.7784917	total: 3.03s	remaining: 1.81s
# 282:	learn: 7.7738551	total: 3.04s	remaining: 1.79s
# 283:	learn: 7.7682492	total: 3.05s	remaining: 1.78s
# 284:	learn: 7.7643174	total: 3.06s	remaining: 1.77s
# 285:	learn: 7.7610601	total: 3.08s	remaining: 1.77s
# 286:	learn: 7.7588571	total: 3.09s	remaining: 1.75s
# 287:	learn: 7.7547266	total: 3.1s	remaining: 1.74s
# 288:	learn: 7.7517210	total: 3.11s	remaining: 1.73s
# 289:	learn: 7.7478513	total: 3.12s	remaining: 1.72s
# 290:	learn: 7.7447045	total: 3.13s	remaining: 1.71s
# 291:	learn: 7.7401892	total: 3.15s	remaining: 1.7s
# 292:	learn: 7.7318259	total: 3.15s	remaining: 1.69s
# 293:	learn: 7.7274599	total: 3.16s	remaining: 1.68s
# 294:	learn: 7.7224681	total: 3.17s	remaining: 1.67s
# 295:	learn: 7.7173145	total: 3.18s	remaining: 1.65s
# 296:	learn: 7.7146266	total: 3.19s	remaining: 1.64s
# 297:	learn: 7.7103928	total: 3.19s	remaining: 1.63s
# 298:	learn: 7.7067165	total: 3.21s	remaining: 1.62s
# 299:	learn: 7.7035698	total: 3.21s	remaining: 1.6s
# 300:	learn: 7.7016103	total: 3.23s	remaining: 1.6s
# 301:	learn: 7.6975046	total: 3.23s	remaining: 1.58s
# 302:	learn: 7.6931891	total: 3.24s	remaining: 1.57s
# 303:	learn: 7.6882947	total: 3.25s	remaining: 1.56s
# 304:	learn: 7.6846597	total: 3.26s	remaining: 1.55s
# 305:	learn: 7.6815830	total: 3.27s	remaining: 1.54s
# 306:	learn: 7.6787784	total: 3.27s	remaining: 1.52s
# 307:	learn: 7.6755556	total: 3.28s	remaining: 1.51s
# 308:	learn: 7.6705356	total: 3.29s	remaining: 1.5s
# 309:	learn: 7.6670310	total: 3.29s	remaining: 1.49s
# 310:	learn: 7.6626057	total: 3.3s	remaining: 1.48s
# 311:	learn: 7.6601919	total: 3.31s	remaining: 1.46s
# 312:	learn: 7.6564485	total: 3.36s	remaining: 1.47s
# 313:	learn: 7.6534271	total: 3.37s	remaining: 1.46s
# 314:	learn: 7.6491236	total: 3.39s	remaining: 1.45s
# 315:	learn: 7.6440316	total: 3.45s	remaining: 1.46s
# 316:	learn: 7.6394797	total: 3.46s	remaining: 1.45s
# 317:	learn: 7.6343646	total: 3.48s	remaining: 1.45s
# 318:	learn: 7.6318338	total: 3.49s	remaining: 1.43s
# 319:	learn: 7.6287856	total: 3.5s	remaining: 1.42s
# 320:	learn: 7.6250297	total: 3.51s	remaining: 1.41s
# 321:	learn: 7.6210284	total: 3.51s	remaining: 1.4s
# 322:	learn: 7.6171604	total: 3.52s	remaining: 1.38s
# 323:	learn: 7.6140585	total: 3.53s	remaining: 1.37s
# 324:	learn: 7.6109330	total: 3.54s	remaining: 1.36s
# 325:	learn: 7.6095152	total: 3.54s	remaining: 1.35s
# 326:	learn: 7.6054597	total: 3.55s	remaining: 1.34s
# 327:	learn: 7.6024513	total: 3.57s	remaining: 1.33s
# 328:	learn: 7.5985165	total: 3.58s	remaining: 1.32s
# 329:	learn: 7.5964053	total: 3.59s	remaining: 1.3s
# 330:	learn: 7.5934480	total: 3.6s	remaining: 1.29s
# 331:	learn: 7.5902518	total: 3.6s	remaining: 1.28s
# 332:	learn: 7.5858575	total: 3.61s	remaining: 1.27s
# 333:	learn: 7.5844362	total: 3.62s	remaining: 1.26s
# 334:	learn: 7.5801418	total: 3.63s	remaining: 1.24s
# 335:	learn: 7.5774145	total: 3.63s	remaining: 1.23s
# 336:	learn: 7.5748636	total: 3.64s	remaining: 1.22s
# 337:	learn: 7.5716080	total: 3.65s	remaining: 1.21s
# 338:	learn: 7.5679244	total: 3.66s	remaining: 1.2s
# 339:	learn: 7.5634504	total: 3.67s	remaining: 1.19s
# 340:	learn: 7.5593562	total: 3.67s	remaining: 1.17s
# 341:	learn: 7.5562470	total: 3.68s	remaining: 1.16s
# 342:	learn: 7.5529674	total: 3.69s	remaining: 1.15s
# 343:	learn: 7.5480420	total: 3.7s	remaining: 1.14s
# 344:	learn: 7.5452864	total: 3.71s	remaining: 1.13s
# 345:	learn: 7.5411204	total: 3.71s	remaining: 1.12s
# 346:	learn: 7.5373724	total: 3.72s	remaining: 1.1s
# 347:	learn: 7.5335262	total: 3.73s	remaining: 1.09s
# 348:	learn: 7.5284898	total: 3.74s	remaining: 1.08s
# 349:	learn: 7.5240590	total: 3.75s	remaining: 1.07s
# 350:	learn: 7.5217846	total: 3.76s	remaining: 1.06s
# 351:	learn: 7.5216686	total: 3.77s	remaining: 1.05s
# 352:	learn: 7.5178169	total: 3.78s	remaining: 1.04s
# 353:	learn: 7.5129856	total: 3.79s	remaining: 1.03s
# 354:	learn: 7.5106377	total: 3.81s	remaining: 1.02s
# 355:	learn: 7.5069464	total: 3.82s	remaining: 1.01s
# 356:	learn: 7.5042775	total: 3.83s	remaining: 997ms
# 357:	learn: 7.4999269	total: 3.84s	remaining: 987ms
# 358:	learn: 7.4958612	total: 3.85s	remaining: 977ms
# 359:	learn: 7.4945737	total: 3.86s	remaining: 966ms
# 360:	learn: 7.4945000	total: 3.87s	remaining: 955ms
# 361:	learn: 7.4901246	total: 3.88s	remaining: 944ms
# 362:	learn: 7.4870525	total: 3.89s	remaining: 933ms
# 363:	learn: 7.4847464	total: 3.9s	remaining: 922ms
# 364:	learn: 7.4811624	total: 3.91s	remaining: 911ms
# 365:	learn: 7.4785257	total: 3.92s	remaining: 900ms
# 366:	learn: 7.4754929	total: 3.93s	remaining: 889ms
# 367:	learn: 7.4717691	total: 3.94s	remaining: 877ms
# 368:	learn: 7.4681547	total: 3.95s	remaining: 867ms
# 369:	learn: 7.4651776	total: 3.96s	remaining: 856ms
# 370:	learn: 7.4641369	total: 3.97s	remaining: 845ms
# 371:	learn: 7.4606388	total: 3.99s	remaining: 836ms
# 372:	learn: 7.4585283	total: 4.01s	remaining: 828ms
# 373:	learn: 7.4543698	total: 4.03s	remaining: 818ms
# 374:	learn: 7.4513223	total: 4.03s	remaining: 807ms
# 375:	learn: 7.4487489	total: 4.05s	remaining: 796ms
# 376:	learn: 7.4444971	total: 4.06s	remaining: 786ms
# 377:	learn: 7.4417245	total: 4.07s	remaining: 775ms
# 378:	learn: 7.4390295	total: 4.08s	remaining: 764ms
# 379:	learn: 7.4361662	total: 4.09s	remaining: 753ms
# 380:	learn: 7.4332182	total: 4.1s	remaining: 742ms
# 381:	learn: 7.4327332	total: 4.11s	remaining: 731ms
# 382:	learn: 7.4274174	total: 4.12s	remaining: 720ms
# 383:	learn: 7.4246831	total: 4.13s	remaining: 711ms
# 384:	learn: 7.4225275	total: 4.15s	remaining: 701ms
# 385:	learn: 7.4172750	total: 4.17s	remaining: 692ms
# 386:	learn: 7.4122093	total: 4.19s	remaining: 683ms
# 387:	learn: 7.4079124	total: 4.22s	remaining: 674ms
# 388:	learn: 7.4044007	total: 4.23s	remaining: 664ms
# 389:	learn: 7.4018676	total: 4.25s	remaining: 654ms
# 390:	learn: 7.3987465	total: 4.26s	remaining: 643ms
# 391:	learn: 7.3960867	total: 4.27s	remaining: 632ms
# 392:	learn: 7.3934673	total: 4.29s	remaining: 622ms
# 393:	learn: 7.3906729	total: 4.3s	remaining: 612ms
# 394:	learn: 7.3883282	total: 4.31s	remaining: 601ms
# 395:	learn: 7.3848876	total: 4.32s	remaining: 590ms
# 396:	learn: 7.3823562	total: 4.33s	remaining: 579ms
# 397:	learn: 7.3786991	total: 4.34s	remaining: 568ms
# 398:	learn: 7.3748726	total: 4.36s	remaining: 557ms
# 399:	learn: 7.3720070	total: 4.37s	remaining: 546ms
# 400:	learn: 7.3691991	total: 4.38s	remaining: 535ms
# 401:	learn: 7.3687985	total: 4.39s	remaining: 525ms
# 402:	learn: 7.3653840	total: 4.41s	remaining: 514ms
# 403:	learn: 7.3615503	total: 4.42s	remaining: 503ms
# 404:	learn: 7.3583867	total: 4.44s	remaining: 493ms
# 405:	learn: 7.3554114	total: 4.46s	remaining: 483ms
# 406:	learn: 7.3518676	total: 4.48s	remaining: 473ms
# 407:	learn: 7.3485680	total: 4.5s	remaining: 463ms
# 408:	learn: 7.3465091	total: 4.52s	remaining: 453ms
# 409:	learn: 7.3438454	total: 4.54s	remaining: 443ms
# 410:	learn: 7.3418409	total: 4.56s	remaining: 433ms
# 411:	learn: 7.3383963	total: 4.59s	remaining: 423ms
# 412:	learn: 7.3344822	total: 4.61s	remaining: 413ms
# 413:	learn: 7.3298312	total: 4.63s	remaining: 403ms
# 414:	learn: 7.3283457	total: 4.65s	remaining: 392ms
# 415:	learn: 7.3249467	total: 4.67s	remaining: 382ms
# 416:	learn: 7.3233203	total: 4.69s	remaining: 371ms
# 417:	learn: 7.3193759	total: 4.71s	remaining: 360ms
# 418:	learn: 7.3170720	total: 4.74s	remaining: 351ms
# 419:	learn: 7.3140369	total: 4.76s	remaining: 340ms
# 420:	learn: 7.3102085	total: 4.79s	remaining: 330ms
# 421:	learn: 7.3071954	total: 4.8s	remaining: 319ms
# 422:	learn: 7.3035874	total: 4.82s	remaining: 308ms
# 423:	learn: 7.3003172	total: 4.84s	remaining: 297ms
# 424:	learn: 7.2983787	total: 4.85s	remaining: 285ms
# 425:	learn: 7.2955585	total: 4.86s	remaining: 274ms
# 426:	learn: 7.2935170	total: 4.87s	remaining: 263ms
# 427:	learn: 7.2913987	total: 4.89s	remaining: 251ms
# 428:	learn: 7.2877493	total: 4.91s	remaining: 240ms
# 429:	learn: 7.2851337	total: 4.93s	remaining: 229ms
# 430:	learn: 7.2823805	total: 4.94s	remaining: 218ms
# 431:	learn: 7.2803355	total: 4.96s	remaining: 207ms
# 432:	learn: 7.2762966	total: 4.97s	remaining: 195ms
# 433:	learn: 7.2734587	total: 4.99s	remaining: 184ms
# 434:	learn: 7.2708834	total: 5.01s	remaining: 173ms
# 435:	learn: 7.2686885	total: 5.02s	remaining: 161ms
# 436:	learn: 7.2658027	total: 5.05s	remaining: 150ms
# 437:	learn: 7.2619845	total: 5.08s	remaining: 139ms
# 438:	learn: 7.2590114	total: 5.09s	remaining: 128ms
# 439:	learn: 7.2572510	total: 5.11s	remaining: 116ms
# 440:	learn: 7.2546409	total: 5.13s	remaining: 105ms
# 441:	learn: 7.2518288	total: 5.14s	remaining: 93.1ms
# 442:	learn: 7.2475682	total: 5.16s	remaining: 81.5ms
# 443:	learn: 7.2443668	total: 5.17s	remaining: 69.9ms
# 444:	learn: 7.2416699	total: 5.19s	remaining: 58.4ms
# 445:	learn: 7.2379502	total: 5.22s	remaining: 46.8ms
# 446:	learn: 7.2343583	total: 5.24s	remaining: 35.2ms
# 447:	learn: 7.2310775	total: 5.26s	remaining: 23.5ms
# 448:	learn: 7.2278237	total: 5.28s	remaining: 11.8ms
# 449:	learn: 7.2247695	total: 5.29s	remaining: 0us
# 0:	learn: 13.7033911	total: 28.4ms	remaining: 12.7s
# 1:	learn: 13.1878285	total: 50ms	remaining: 11.2s
# 2:	learn: 12.7479050	total: 67.8ms	remaining: 10.1s
# 3:	learn: 12.3666189	total: 92.7ms	remaining: 10.3s
# 4:	learn: 12.0385706	total: 111ms	remaining: 9.92s
# 5:	learn: 11.7554414	total: 130ms	remaining: 9.63s
# 6:	learn: 11.4983085	total: 149ms	remaining: 9.43s
# 7:	learn: 11.2930069	total: 170ms	remaining: 9.38s
# 8:	learn: 11.1094235	total: 201ms	remaining: 9.84s
# 9:	learn: 10.9530101	total: 224ms	remaining: 9.85s
# 10:	learn: 10.8130121	total: 255ms	remaining: 10.2s
# 11:	learn: 10.6926961	total: 292ms	remaining: 10.7s
# 12:	learn: 10.5849100	total: 310ms	remaining: 10.4s
# 13:	learn: 10.4892747	total: 322ms	remaining: 10s
# 14:	learn: 10.3942620	total: 334ms	remaining: 9.69s
# 15:	learn: 10.3152341	total: 350ms	remaining: 9.49s
# 16:	learn: 10.2445107	total: 365ms	remaining: 9.31s
# 17:	learn: 10.1790679	total: 388ms	remaining: 9.3s
# 18:	learn: 10.1174107	total: 405ms	remaining: 9.18s
# 19:	learn: 10.0653950	total: 420ms	remaining: 9.02s
# 20:	learn: 10.0214501	total: 437ms	remaining: 8.93s
# 21:	learn: 9.9745623	total: 455ms	remaining: 8.86s
# 22:	learn: 9.9295202	total: 478ms	remaining: 8.88s
# 23:	learn: 9.8795584	total: 503ms	remaining: 8.94s
# 24:	learn: 9.8413827	total: 527ms	remaining: 8.96s
# 25:	learn: 9.8082005	total: 544ms	remaining: 8.87s
# 26:	learn: 9.7790602	total: 559ms	remaining: 8.76s
# 27:	learn: 9.7498399	total: 575ms	remaining: 8.66s
# 28:	learn: 9.7236594	total: 592ms	remaining: 8.59s
# ...
# 151:	learn: 8.4558390	total: 2.99s	remaining: 5.86s
# 152:	learn: 8.4489082	total: 3s	remaining: 5.83s
# 153:	learn: 8.4428618	total: 3.03s	remaining: 5.82s
# 154:	learn: 8.4387646	total: 3.05s	remaining: 5.81s
# 155:	learn: 8.4335738	total: 3.08s	remaining: 5.8s
# 156:	learn: 8.4276383	total: 3.12s	remaining: 5.81s
# 157:	learn: 8.4194202	total: 3.14s	remaining: 5.81s
# 158:	learn: 8.4129662	total: 3.17s	remaining: 5.79s
# 159:	learn: 8.4060091	total: 3.19s	remaining: 5.78s
# 160:	learn: 8.4003467	total: 3.21s	remaining: 5.76s
# 161:	learn: 8.3961359	total: 3.24s	remaining: 5.76s
# 162:	learn: 8.3898155	total: 3.27s	remaining: 5.76s
# 163:	learn: 8.3835959	total: 3.29s	remaining: 5.74s
# 164:	learn: 8.3779093	total: 3.3s	remaining: 5.7s
# 165:	learn: 8.3718581	total: 3.31s	remaining: 5.67s
# 166:	learn: 8.3645537	total: 3.33s	remaining: 5.64s
# 167:	learn: 8.3586991	total: 3.34s	remaining: 5.6s
# 168:	learn: 8.3539769	total: 3.35s	remaining: 5.57s
# 169:	learn: 8.3488256	total: 3.36s	remaining: 5.54s
# 170:	learn: 8.3479855	total: 3.37s	remaining: 5.5s
# 171:	learn: 8.3405351	total: 3.39s	remaining: 5.48s
# 172:	learn: 8.3340126	total: 3.42s	remaining: 5.47s
# 173:	learn: 8.3283115	total: 3.43s	remaining: 5.45s
# 174:	learn: 8.3234790	total: 3.45s	remaining: 5.43s
# 175:	learn: 8.3173879	total: 3.48s	remaining: 5.42s
# 176:	learn: 8.3098740	total: 3.51s	remaining: 5.41s
# 177:	learn: 8.3043342	total: 3.53s	remaining: 5.39s
# 178:	learn: 8.2990020	total: 3.54s	remaining: 5.37s
# 179:	learn: 8.2959768	total: 3.56s	remaining: 5.34s
# 180:	learn: 8.2891587	total: 3.57s	remaining: 5.31s
# 181:	learn: 8.2841210	total: 3.58s	remaining: 5.28s
# 182:	learn: 8.2799021	total: 3.6s	remaining: 5.25s
# 183:	learn: 8.2742195	total: 3.6s	remaining: 5.21s
# 184:	learn: 8.2702550	total: 3.62s	remaining: 5.18s
# 185:	learn: 8.2629827	total: 3.63s	remaining: 5.15s
# 186:	learn: 8.2567283	total: 3.64s	remaining: 5.12s
# 187:	learn: 8.2493330	total: 3.74s	remaining: 5.21s
# 188:	learn: 8.2425033	total: 3.8s	remaining: 5.25s
# 189:	learn: 8.2379579	total: 3.87s	remaining: 5.29s
# 190:	learn: 8.2317431	total: 3.94s	remaining: 5.34s
# 191:	learn: 8.2271208	total: 4.03s	remaining: 5.42s
# 192:	learn: 8.2237681	total: 4.09s	remaining: 5.45s
# 193:	learn: 8.2178496	total: 4.15s	remaining: 5.48s
# 194:	learn: 8.2114103	total: 4.21s	remaining: 5.51s
# 195:	learn: 8.2051426	total: 4.24s	remaining: 5.49s
# 196:	learn: 8.1997887	total: 4.25s	remaining: 5.46s
# 197:	learn: 8.1951550	total: 4.26s	remaining: 5.42s
# 198:	learn: 8.1913334	total: 4.28s	remaining: 5.39s
# 199:	learn: 8.1856702	total: 4.29s	remaining: 5.36s
# 200:	learn: 8.1813890	total: 4.3s	remaining: 5.32s
# 201:	learn: 8.1769368	total: 4.31s	remaining: 5.29s
# 202:	learn: 8.1702540	total: 4.32s	remaining: 5.26s
# 203:	learn: 8.1656261	total: 4.33s	remaining: 5.22s
# 204:	learn: 8.1606503	total: 4.35s	remaining: 5.2s
# 205:	learn: 8.1549582	total: 4.37s	remaining: 5.18s
# 206:	learn: 8.1484589	total: 4.41s	remaining: 5.17s
# 207:	learn: 8.1413662	total: 4.43s	remaining: 5.16s
# 208:	learn: 8.1356615	total: 4.45s	remaining: 5.13s
# 209:	learn: 8.1304248	total: 4.47s	remaining: 5.11s
# 210:	learn: 8.1265509	total: 4.49s	remaining: 5.08s
# 211:	learn: 8.1210540	total: 4.51s	remaining: 5.07s
# 212:	learn: 8.1172881	total: 4.53s	remaining: 5.04s
# 213:	learn: 8.1124459	total: 4.55s	remaining: 5.01s
# 214:	learn: 8.1087202	total: 4.58s	remaining: 5s
# 215:	learn: 8.1053747	total: 4.61s	remaining: 4.99s
# 216:	learn: 8.0994374	total: 4.62s	remaining: 4.96s
# 217:	learn: 8.0949757	total: 4.64s	remaining: 4.94s
# 218:	learn: 8.0912268	total: 4.67s	remaining: 4.93s
# 219:	learn: 8.0867981	total: 4.69s	remaining: 4.9s
# 220:	learn: 8.0841632	total: 4.71s	remaining: 4.88s
# 221:	learn: 8.0784869	total: 4.72s	remaining: 4.85s
# 222:	learn: 8.0752934	total: 4.74s	remaining: 4.82s
# 223:	learn: 8.0691148	total: 4.76s	remaining: 4.8s
# 224:	learn: 8.0654023	total: 4.78s	remaining: 4.78s
# 225:	learn: 8.0600625	total: 4.81s	remaining: 4.77s
# 226:	learn: 8.0550798	total: 4.84s	remaining: 4.75s
# 227:	learn: 8.0516914	total: 4.85s	remaining: 4.73s
# 228:	learn: 8.0469292	total: 4.87s	remaining: 4.7s
# 229:	learn: 8.0424402	total: 4.89s	remaining: 4.68s
# 230:	learn: 8.0390748	total: 4.91s	remaining: 4.65s
# 231:	learn: 8.0340613	total: 4.93s	remaining: 4.63s
# 232:	learn: 8.0308088	total: 4.95s	remaining: 4.61s
# 233:	learn: 8.0272505	total: 4.98s	remaining: 4.59s
# 234:	learn: 8.0231207	total: 4.99s	remaining: 4.57s
# 235:	learn: 8.0195303	total: 5.01s	remaining: 4.54s
# 236:	learn: 8.0158402	total: 5.02s	remaining: 4.52s
# 237:	learn: 8.0109750	total: 5.05s	remaining: 4.5s
# 238:	learn: 8.0066511	total: 5.07s	remaining: 4.48s
# 239:	learn: 8.0021980	total: 5.1s	remaining: 4.46s
# 240:	learn: 7.9993580	total: 5.12s	remaining: 4.44s
# 241:	learn: 7.9954540	total: 5.14s	remaining: 4.42s
# 242:	learn: 7.9904624	total: 5.15s	remaining: 4.39s
# 243:	learn: 7.9863761	total: 5.17s	remaining: 4.37s
# 244:	learn: 7.9811971	total: 5.19s	remaining: 4.34s
# 245:	learn: 7.9795714	total: 5.21s	remaining: 4.32s
# 246:	learn: 7.9750029	total: 5.22s	remaining: 4.29s
# 247:	learn: 7.9695495	total: 5.25s	remaining: 4.27s
# 248:	learn: 7.9640158	total: 5.28s	remaining: 4.26s
# 249:	learn: 7.9600999	total: 5.34s	remaining: 4.28s
# 250:	learn: 7.9580149	total: 5.43s	remaining: 4.31s
# 251:	learn: 7.9539210	total: 5.5s	remaining: 4.32s
# 252:	learn: 7.9483685	total: 5.55s	remaining: 4.32s
# 253:	learn: 7.9438177	total: 5.61s	remaining: 4.33s
# 254:	learn: 7.9395233	total: 5.62s	remaining: 4.3s
# 255:	learn: 7.9366554	total: 5.64s	remaining: 4.27s
# 256:	learn: 7.9329804	total: 5.65s	remaining: 4.24s
# 257:	learn: 7.9282986	total: 5.66s	remaining: 4.21s
# 258:	learn: 7.9232646	total: 5.68s	remaining: 4.19s
# 259:	learn: 7.9199451	total: 5.71s	remaining: 4.17s
# 260:	learn: 7.9149475	total: 5.73s	remaining: 4.15s
# 261:	learn: 7.9093368	total: 5.75s	remaining: 4.13s
# 262:	learn: 7.9057949	total: 5.78s	remaining: 4.11s
# 263:	learn: 7.9018275	total: 5.8s	remaining: 4.08s
# 264:	learn: 7.8957551	total: 5.81s	remaining: 4.06s
# 265:	learn: 7.8930633	total: 5.83s	remaining: 4.03s
# 266:	learn: 7.8876106	total: 5.84s	remaining: 4s
# 267:	learn: 7.8844914	total: 5.86s	remaining: 3.98s
# 268:	learn: 7.8779622	total: 5.88s	remaining: 3.96s
# 269:	learn: 7.8739757	total: 5.9s	remaining: 3.93s
# 270:	learn: 7.8698580	total: 5.92s	remaining: 3.91s
# 271:	learn: 7.8654390	total: 5.93s	remaining: 3.88s
# 272:	learn: 7.8585400	total: 5.96s	remaining: 3.86s
# 273:	learn: 7.8506344	total: 5.98s	remaining: 3.84s
# 274:	learn: 7.8462059	total: 6.01s	remaining: 3.82s
# 275:	learn: 7.8461266	total: 6.02s	remaining: 3.79s
# 276:	learn: 7.8405053	total: 6.04s	remaining: 3.77s
# 277:	learn: 7.8392030	total: 6.05s	remaining: 3.74s
# 278:	learn: 7.8346251	total: 6.07s	remaining: 3.72s
# 279:	learn: 7.8307539	total: 6.08s	remaining: 3.69s
# 280:	learn: 7.8284303	total: 6.1s	remaining: 3.67s
# 281:	learn: 7.8250055	total: 6.12s	remaining: 3.64s
# 282:	learn: 7.8225084	total: 6.14s	remaining: 3.62s
# 283:	learn: 7.8186955	total: 6.16s	remaining: 3.6s
# 284:	learn: 7.8163985	total: 6.19s	remaining: 3.58s
# 285:	learn: 7.8131009	total: 6.21s	remaining: 3.56s
# 286:	learn: 7.8097586	total: 6.23s	remaining: 3.54s
# 287:	learn: 7.8096829	total: 6.24s	remaining: 3.51s
# 288:	learn: 7.8059033	total: 6.26s	remaining: 3.49s
# 289:	learn: 7.8016001	total: 6.27s	remaining: 3.46s
# 290:	learn: 7.8011764	total: 6.3s	remaining: 3.44s
# 291:	learn: 7.7983535	total: 6.31s	remaining: 3.42s
# 292:	learn: 7.7935962	total: 6.33s	remaining: 3.39s
# 293:	learn: 7.7898645	total: 6.34s	remaining: 3.37s
# 294:	learn: 7.7859192	total: 6.37s	remaining: 3.35s
# 295:	learn: 7.7834055	total: 6.4s	remaining: 3.33s
# 296:	learn: 7.7833409	total: 6.42s	remaining: 3.31s
# 297:	learn: 7.7791946	total: 6.44s	remaining: 3.29s
# 298:	learn: 7.7755610	total: 6.46s	remaining: 3.27s
# 299:	learn: 7.7718452	total: 6.48s	remaining: 3.24s
# 300:	learn: 7.7682562	total: 6.5s	remaining: 3.22s
# 301:	learn: 7.7647364	total: 6.52s	remaining: 3.2s
# 302:	learn: 7.7618470	total: 6.54s	remaining: 3.17s
# 303:	learn: 7.7585952	total: 6.56s	remaining: 3.15s
# 304:	learn: 7.7546185	total: 6.6s	remaining: 3.14s
# 305:	learn: 7.7508953	total: 6.62s	remaining: 3.11s
# 306:	learn: 7.7477733	total: 6.63s	remaining: 3.09s
# 307:	learn: 7.7477001	total: 6.65s	remaining: 3.07s
# 308:	learn: 7.7453005	total: 6.67s	remaining: 3.04s
# 309:	learn: 7.7425558	total: 6.69s	remaining: 3.02s
# 310:	learn: 7.7401501	total: 6.7s	remaining: 3s
# 311:	learn: 7.7359813	total: 6.72s	remaining: 2.97s
# 312:	learn: 7.7328978	total: 6.74s	remaining: 2.95s
# 313:	learn: 7.7296926	total: 6.76s	remaining: 2.93s
# 314:	learn: 7.7292082	total: 6.78s	remaining: 2.91s
# 315:	learn: 7.7267361	total: 6.8s	remaining: 2.88s
# 316:	learn: 7.7265888	total: 6.83s	remaining: 2.86s
# 317:	learn: 7.7236850	total: 6.85s	remaining: 2.84s
# 318:	learn: 7.7216380	total: 6.86s	remaining: 2.82s
# 319:	learn: 7.7167891	total: 6.88s	remaining: 2.8s
# 320:	learn: 7.7122565	total: 6.91s	remaining: 2.78s
# 321:	learn: 7.7093835	total: 6.93s	remaining: 2.75s
# 322:	learn: 7.7093275	total: 6.94s	remaining: 2.73s
# 323:	learn: 7.7042233	total: 6.96s	remaining: 2.71s
# 324:	learn: 7.7003919	total: 6.99s	remaining: 2.69s
# 325:	learn: 7.6966960	total: 7.01s	remaining: 2.67s
# 326:	learn: 7.6935855	total: 7.04s	remaining: 2.65s
# 327:	learn: 7.6900695	total: 7.06s	remaining: 2.63s
# 328:	learn: 7.6862806	total: 7.08s	remaining: 2.6s
# 329:	learn: 7.6835171	total: 7.1s	remaining: 2.58s
# 330:	learn: 7.6794579	total: 7.12s	remaining: 2.56s
# 331:	learn: 7.6761846	total: 7.13s	remaining: 2.54s
# 332:	learn: 7.6737890	total: 7.15s	remaining: 2.51s
# 333:	learn: 7.6712326	total: 7.16s	remaining: 2.49s
# 334:	learn: 7.6672656	total: 7.19s	remaining: 2.47s
# 335:	learn: 7.6648957	total: 7.22s	remaining: 2.45s
# 336:	learn: 7.6602699	total: 7.25s	remaining: 2.43s
# 337:	learn: 7.6602161	total: 7.27s	remaining: 2.41s
# 338:	learn: 7.6560298	total: 7.28s	remaining: 2.38s
# 339:	learn: 7.6537157	total: 7.3s	remaining: 2.36s
# 340:	learn: 7.6507359	total: 7.31s	remaining: 2.34s
# 341:	learn: 7.6474223	total: 7.34s	remaining: 2.32s
# 342:	learn: 7.6433527	total: 7.35s	remaining: 2.29s
# 343:	learn: 7.6373531	total: 7.37s	remaining: 2.27s
# 344:	learn: 7.6350936	total: 7.38s	remaining: 2.25s
# 345:	learn: 7.6310789	total: 7.4s	remaining: 2.22s
# 346:	learn: 7.6279707	total: 7.42s	remaining: 2.2s
# 347:	learn: 7.6249510	total: 7.45s	remaining: 2.18s
# 348:	learn: 7.6211522	total: 7.47s	remaining: 2.16s
# 349:	learn: 7.6156626	total: 7.49s	remaining: 2.14s
# 350:	learn: 7.6107718	total: 7.51s	remaining: 2.12s
# 351:	learn: 7.6093136	total: 7.53s	remaining: 2.1s
# 352:	learn: 7.6052092	total: 7.55s	remaining: 2.07s
# 353:	learn: 7.6027324	total: 7.56s	remaining: 2.05s
# 354:	learn: 7.5978786	total: 7.58s	remaining: 2.03s
# 355:	learn: 7.5946869	total: 7.6s	remaining: 2.01s
# 356:	learn: 7.5913499	total: 7.62s	remaining: 1.99s
# 357:	learn: 7.5874149	total: 7.66s	remaining: 1.97s
# 358:	learn: 7.5843806	total: 7.68s	remaining: 1.95s
# 359:	learn: 7.5825737	total: 7.7s	remaining: 1.93s
# 360:	learn: 7.5782640	total: 7.72s	remaining: 1.9s
# 361:	learn: 7.5738920	total: 7.74s	remaining: 1.88s
# 362:	learn: 7.5709546	total: 7.76s	remaining: 1.86s
# 363:	learn: 7.5708949	total: 7.77s	remaining: 1.84s
# 364:	learn: 7.5681845	total: 7.8s	remaining: 1.81s
# 365:	learn: 7.5648710	total: 7.82s	remaining: 1.79s
# 366:	learn: 7.5610861	total: 7.84s	remaining: 1.77s
# 367:	learn: 7.5571676	total: 7.87s	remaining: 1.75s
# 368:	learn: 7.5537948	total: 7.89s	remaining: 1.73s
# 369:	learn: 7.5534985	total: 7.91s	remaining: 1.71s
# 370:	learn: 7.5506480	total: 7.93s	remaining: 1.69s
# 371:	learn: 7.5476858	total: 7.96s	remaining: 1.67s
# 372:	learn: 7.5456318	total: 7.97s	remaining: 1.65s
# 373:	learn: 7.5431978	total: 7.99s	remaining: 1.62s
# 374:	learn: 7.5392473	total: 8.01s	remaining: 1.6s
# 375:	learn: 7.5391930	total: 8.02s	remaining: 1.58s
# 376:	learn: 7.5368385	total: 8.05s	remaining: 1.56s
# 377:	learn: 7.5349642	total: 8.07s	remaining: 1.54s
# 378:	learn: 7.5317958	total: 8.1s	remaining: 1.52s
# 379:	learn: 7.5292426	total: 8.12s	remaining: 1.5s
# 380:	learn: 7.5260453	total: 8.14s	remaining: 1.47s
# 381:	learn: 7.5230179	total: 8.16s	remaining: 1.45s
# 382:	learn: 7.5201733	total: 8.18s	remaining: 1.43s
# 383:	learn: 7.5170685	total: 8.2s	remaining: 1.41s
# 384:	learn: 7.5136416	total: 8.21s	remaining: 1.39s
# 385:	learn: 7.5114855	total: 8.24s	remaining: 1.37s
# 386:	learn: 7.5080600	total: 8.27s	remaining: 1.35s
# 387:	learn: 7.5041166	total: 8.31s	remaining: 1.33s
# 388:	learn: 7.5022903	total: 8.32s	remaining: 1.3s
# 389:	learn: 7.5002539	total: 8.35s	remaining: 1.28s
# 390:	learn: 7.4961505	total: 8.37s	remaining: 1.26s
# 391:	learn: 7.4946300	total: 8.39s	remaining: 1.24s
# 392:	learn: 7.4915270	total: 8.4s	remaining: 1.22s
# 393:	learn: 7.4886875	total: 8.42s	remaining: 1.2s
# 394:	learn: 7.4829518	total: 8.44s	remaining: 1.18s
# 395:	learn: 7.4802306	total: 8.47s	remaining: 1.15s
# 396:	learn: 7.4752872	total: 8.51s	remaining: 1.14s
# 397:	learn: 7.4708807	total: 8.53s	remaining: 1.11s
# 398:	learn: 7.4688929	total: 8.55s	remaining: 1.09s
# 399:	learn: 7.4655414	total: 8.56s	remaining: 1.07s
# 400:	learn: 7.4619833	total: 8.58s	remaining: 1.05s
# 401:	learn: 7.4588171	total: 8.6s	remaining: 1.03s
# 402:	learn: 7.4555211	total: 8.62s	remaining: 1s
# 403:	learn: 7.4544438	total: 8.64s	remaining: 983ms
# 404:	learn: 7.4507603	total: 8.65s	remaining: 961ms
# 405:	learn: 7.4484503	total: 8.68s	remaining: 941ms
# 406:	learn: 7.4465035	total: 8.73s	remaining: 922ms
# 407:	learn: 7.4447830	total: 8.75s	remaining: 901ms
# 408:	learn: 7.4415934	total: 8.77s	remaining: 879ms
# 409:	learn: 7.4376314	total: 8.78s	remaining: 857ms
# 410:	learn: 7.4355416	total: 8.8s	remaining: 835ms
# 411:	learn: 7.4316888	total: 8.82s	remaining: 814ms
# 412:	learn: 7.4277527	total: 8.84s	remaining: 792ms
# 413:	learn: 7.4255592	total: 8.86s	remaining: 770ms
# 414:	learn: 7.4227260	total: 8.88s	remaining: 749ms
# 415:	learn: 7.4201102	total: 8.9s	remaining: 727ms
# 416:	learn: 7.4169918	total: 8.95s	remaining: 708ms
# 417:	learn: 7.4137962	total: 9.04s	remaining: 692ms
# 418:	learn: 7.4111684	total: 9.11s	remaining: 674ms
# 419:	learn: 7.4086978	total: 9.16s	remaining: 654ms
# 420:	learn: 7.4070433	total: 9.22s	remaining: 636ms
# 421:	learn: 7.4040883	total: 9.24s	remaining: 613ms
# 422:	learn: 7.4012644	total: 9.26s	remaining: 591ms
# 423:	learn: 7.3988422	total: 9.28s	remaining: 569ms
# 424:	learn: 7.3949354	total: 9.3s	remaining: 547ms
# 425:	learn: 7.3914484	total: 9.32s	remaining: 525ms
# 426:	learn: 7.3888856	total: 9.34s	remaining: 503ms
# 427:	learn: 7.3868341	total: 9.37s	remaining: 482ms
# 428:	learn: 7.3841419	total: 9.4s	remaining: 460ms
# 429:	learn: 7.3817791	total: 9.41s	remaining: 438ms
# 430:	learn: 7.3786238	total: 9.43s	remaining: 416ms
# 431:	learn: 7.3758272	total: 9.45s	remaining: 394ms
# 432:	learn: 7.3732805	total: 9.47s	remaining: 372ms
# 433:	learn: 7.3707718	total: 9.48s	remaining: 350ms
# 434:	learn: 7.3707196	total: 9.51s	remaining: 328ms
# 435:	learn: 7.3672961	total: 9.53s	remaining: 306ms
# 436:	learn: 7.3649018	total: 9.56s	remaining: 284ms
# 437:	learn: 7.3629888	total: 9.59s	remaining: 263ms
# 438:	learn: 7.3604079	total: 9.61s	remaining: 241ms
# 439:	learn: 7.3574936	total: 9.63s	remaining: 219ms
# 440:	learn: 7.3535930	total: 9.64s	remaining: 197ms
# 441:	learn: 7.3511517	total: 9.66s	remaining: 175ms
# 442:	learn: 7.3487961	total: 9.68s	remaining: 153ms
# 443:	learn: 7.3487481	total: 9.7s	remaining: 131ms
# 444:	learn: 7.3462472	total: 9.71s	remaining: 109ms
# 445:	learn: 7.3429978	total: 9.73s	remaining: 87.3ms
# 446:	learn: 7.3393482	total: 9.75s	remaining: 65.4ms
# 447:	learn: 7.3376736	total: 9.78s	remaining: 43.7ms
# 448:	learn: 7.3354801	total: 9.81s	remaining: 21.9ms
# 449:	learn: 7.3338155	total: 9.83s	remaining: 0us
#                 Model Evaluation Metrics:
# Mean Absolute Error (MAE): 5.51588742767828
# Root Mean Squared Error (RMSE): 7.333815489247083
# R-squared (R2 ): 0.7363185761696023
# ADJUST_CAPACITY: 10.0241
# CURRENT_WAIT_TIME: 24.9015
# TIME_TO_PARADE_1: 6.7801
# TIME_TO_PARADE_2: 1.6789
# TIME_TO_NIGHT_SHOW: 7.0553
# temp: 1.4380
# dew_point: 2.0033
# feels_like: 1.7602
# pressure: 3.2281
# humidity: 2.2322
# wind_speed: 2.3407
# rain_1h: 2.2590
# snow_1h: 6.7025
# year: 2.7460
# month: 3.7168
# day: 3.2445
# hour: 17.8890

# %%
X_val = test_file.copy()
X_val['DATETIME'] = pd.to_datetime(X_val['DATETIME'], errors='coerce')

X_val = pd.merge(X_val, weather_file, on='DATETIME', how='left')
X_val = pd.get_dummies(X_val, columns=['ENTITY_DESCRIPTION_SHORT'], drop_first=True, dtype=int)
X_val['year'] = X_val['DATETIME'].dt.year
X_val['month'] = X_val['DATETIME'].dt.month
X_val['day'] = X_val['DATETIME'].dt.day
X_val['hour'] = X_val['DATETIME'].dt.hour
X_val['minute'] = X_val['DATETIME'].dt.minute

X_val['TIME_TO_PARADE_1'] = X_val['TIME_TO_PARADE_1'].fillna(250)
X_val['TIME_TO_PARADE_2'] = X_val['TIME_TO_PARADE_2'].fillna(0)

X_val = X_val.sort_values(by='DATETIME')
X_val['rain_1h__6'] = X_val['rain_1h'].shift(-6)
X_val['rain_1h__3'] = X_val['rain_1h'].shift(-3)

X_val['snow_1h__6'] = X_val['snow_1h'].shift(-6)
X_val['snow_1h__3'] = X_val['snow_1h'].shift(-3)

# Fill NaNs by column
for col in X_val.select_dtypes(include=['number']).columns:
    # Compute mean and std of non-NaN values
    mean = X_val[col].mean()
    std = X_val[col].std()
    
    # Find number of NaNs
    n_nan = X_val[col].isna().sum()
    
    # Generate random numbers for NaNs
    random_values = np.random.normal(loc=mean, scale=std, size=n_nan)
    
    # Fill NaNs
    X_val.loc[X_val[col].isna(), col] = random_values

X_val = X_val.sort_index()
X_val = X_val.select_dtypes(include=['number']).drop(columns=['DOWNTIME','minute','clouds_all'])

# %%
y_pred_final = model.predict(X_val)

# %%
import pandas as pd
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score
import numpy as np

# %%
def evaluate_model(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    rmse = root_mean_squared_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    
    print("                Model Evaluation Metrics:")
    print(f"Mean Absolute Error (MAE): {mae}")
    print(f"Root Mean Squared Error (RMSE): {rmse}")
    print(f"R-squared (R2 ): {r2}")

# %%
def generate_csv(input, y_pred, key='Final', filename='../outpu_final/TEST_cast_boost.csv'):
    output = input[['DATETIME', 'ENTITY_DESCRIPTION_SHORT']].copy()
    output['y_pred'] = y_pred
    output['KEY'] = [key] * len(y_pred)
    output.to_csv(filename, index=False)
    print(f"Predictions saved to {filename}")

# %%
train_route = '../data/waiting_times_train.csv'
validation_route = '../data/waiting_times_X_test_val.csv'
test_route = '../data/waiting_times_X_test_final.csv'
weather_route = '../data/weather_data.csv'

train_file = pd.read_csv(train_route)
validation_file = pd.read_csv(validation_route)
test_file = pd.read_csv(test_route)
weather_file = pd.read_csv(weather_route)

# %%
X_train = train_file.copy()
X_train['DATETIME'] = pd.to_datetime(X_train['DATETIME'], errors='coerce')

weather_file['DATETIME'] = pd.to_datetime(weather_file['DATETIME'], errors='coerce')
weather_file = weather_file.fillna(0)

X_train = pd.merge(X_train, weather_file, on='DATETIME', how='left')
X_train = pd.get_dummies(X_train, columns=['ENTITY_DESCRIPTION_SHORT'], drop_first=True, dtype=int)
X_train['year'] = X_train['DATETIME'].dt.year
X_train['month'] = X_train['DATETIME'].dt.month
X_train['day'] = X_train['DATETIME'].dt.day
X_train['hour'] = X_train['DATETIME'].dt.hour
X_train['minute'] = X_train['DATETIME'].dt.minute

X_train['TIME_TO_PARADE_1'] = X_train['TIME_TO_PARADE_1'].fillna(250)
X_train['TIME_TO_PARADE_2'] = X_train['TIME_TO_PARADE_2'].fillna(0)

X_train = X_train.sort_values(by='DATETIME')
X_train['rain_1h__6'] = X_train['rain_1h'].shift(-6)
X_train['rain_1h__3'] = X_train['rain_1h'].shift(-3)

X_train['snow_1h__6'] = X_train['snow_1h'].shift(-6)
X_train['snow_1h__3'] = X_train['snow_1h'].shift(-3)

print(X_train.head())

# Fill NaNs by column
for col in X_train.select_dtypes(include=['number']).columns:
    # Compute mean and std of non-NaN values
    mean = X_train[col].mean()
    std = X_train[col].std()
    
    # Find number of NaNs
    n_nan = X_train[col].isna().sum()
    
    # Generate random numbers for NaNs
    random_values = np.random.normal(loc=mean, scale=std, size=n_nan)
    
    # Fill NaNs
    X_train.loc[X_train[col].isna(), col] = random_values

X_train = X_train.sort_index()
y_train = X_train['WAIT_TIME_IN_2H']
X_train = X_train.select_dtypes(include=['number']).drop(columns=['WAIT_TIME_IN_2H','clouds_all', 'humidity'])
# Out:
#                  DATETIME  ADJUST_CAPACITY  DOWNTIME  CURRENT_WAIT_TIME  \
# 5927  2018-10-01 12:15:00            224.5         0                 20
# 8149  2018-10-01 12:15:00            756.0         0                 10
# 12003 2018-10-01 12:15:00            153.0         0                 25
# 13978 2018-10-01 12:30:00            153.0         0                 25
# 23029 2018-10-01 12:30:00            224.5         0                 20
#
#        TIME_TO_PARADE_1  TIME_TO_PARADE_2  TIME_TO_NIGHT_SHOW  \
# 5927              315.0              -5.0               465.0
# 8149              315.0              -5.0               465.0
# 12003             315.0              -5.0               465.0
# 13978             300.0             -20.0               450.0
# 23029             300.0             -20.0               450.0
#
#        WAIT_TIME_IN_2H   temp  dew_point  ...  \
# 5927              20.0  13.01       5.43  ...
# 8149              10.0  13.01       5.43  ...
# 12003             25.0  13.01       5.43  ...
# 13978             25.0  13.25       5.41  ...
# 23029             20.0  13.25       5.41  ...
#
#        ENTITY_DESCRIPTION_SHORT_Water Ride  year  month  day  hour  minute  \
# 5927                                     1  2018     10    1    12      15
# 8149                                     0  2018     10    1    12      15
# 12003                                    0  2018     10    1    12      15
# 13978                                    0  2018     10    1    12      30
# 23029                                    1  2018     10    1    12      30
#
#        rain_1h__6  rain_1h__3  snow_1h__6  snow_1h__3
# 5927       0.1239      0.1226         0.0         0.0
# 8149       0.1239      0.1226         0.0         0.0
# 12003      0.1239      0.1226         0.0         0.0
# 13978      0.1252      0.1239         0.0         0.0
# 23029      0.1252      0.1239         0.0         0.0
#
# [5 rows x 28 columns]

# %%
optimized_estimators = 1900
'''max_score = float('-inf')
for n in range(100, 5000, 100):
    model = XGBRegressor(n_estimators=n, learning_rate=0.1)
    scores = cross_val_score(model, X_train, y_train, scoring='neg_root_mean_squared_error', cv=5)
    score_mean = scores.mean()
    print(f"n_estimators: {n}, CV Mean RMSE: {-score_mean}")
    if score_mean > max_score:
        optimized_estimators = n
        max_score = score_mean'''



model = XGBRegressor(n_estimators=optimized_estimators, learning_rate=0.009, random_state=10)
scores = cross_val_score(model, X_train, y_train, scoring='neg_root_mean_squared_error', cv=5)
print(scores.mean(), scores.std())
model.fit(X_train, y_train)

y_pred = model.predict(X_train)
evaluate_model(y_train, y_pred)
# Out:
# -7.674991786485701 0.13117967004688835
#                 Model Evaluation Metrics:
# Mean Absolute Error (MAE): 4.974875815857568
# Root Mean Squared Error (RMSE): 6.620973309131593
# R-squared (R2 ): 0.7850867208852705

# %%
X_val = test_file.copy()
X_val['DATETIME'] = pd.to_datetime(X_val['DATETIME'], errors='coerce')

X_val = pd.merge(X_val, weather_file, on='DATETIME', how='left')
X_val = pd.get_dummies(X_val, columns=['ENTITY_DESCRIPTION_SHORT'], drop_first=True, dtype=int)
X_val['year'] = X_val['DATETIME'].dt.year
X_val['month'] = X_val['DATETIME'].dt.month
X_val['day'] = X_val['DATETIME'].dt.day
X_val['hour'] = X_val['DATETIME'].dt.hour
X_val['minute'] = X_val['DATETIME'].dt.minute

X_val['TIME_TO_PARADE_1'] = X_val['TIME_TO_PARADE_1'].fillna(250)
X_val['TIME_TO_PARADE_2'] = X_val['TIME_TO_PARADE_2'].fillna(0)

X_val = X_val.sort_values(by='DATETIME')
X_val['rain_1h__6'] = X_val['rain_1h'].shift(-6)
X_val['rain_1h__3'] = X_val['rain_1h'].shift(-3)

X_val['snow_1h__6'] = X_val['snow_1h'].shift(-6)
X_val['snow_1h__3'] = X_val['snow_1h'].shift(-3)

# Fill NaNs by column
for col in X_val.select_dtypes(include=['number']).columns:
    # Compute mean and std of non-NaN values
    mean = X_val[col].mean()
    std = X_val[col].std()
    
    # Find number of NaNs
    n_nan = X_val[col].isna().sum()
    
    # Generate random numbers for NaNs
    random_values = np.random.normal(loc=mean, scale=std, size=n_nan)
    
    # Fill NaNs
    X_val.loc[X_val[col].isna(), col] = random_values

X_val = X_val.sort_index()
X_val = X_val.select_dtypes(include=['number']).drop(columns=['clouds_all','humidity'])

# %%
y_pred_final_xgb = model.predict(X_val)

# %%
import pandas as pd
from lightgbm import LGBMRegressor, LGBMClassifier
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score
import numpy as np

# %%
def evaluate_model(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    rmse = root_mean_squared_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    
    print("                Model Evaluation Metrics:")
    print(f"Mean Absolute Error (MAE): {mae}")
    print(f"Root Mean Squared Error (RMSE): {rmse}")
    print(f"R-squared (R2 ): {r2}")

# %%
def generate_csv(input, y_pred, key='Final', filename='../outpu_final/TEST_cat_boost.csv'):
    output = input[['DATETIME', 'ENTITY_DESCRIPTION_SHORT']].copy()
    output['y_pred'] = y_pred
    output['KEY'] = [key] * len(y_pred)
    output.to_csv(filename, index=False)
    print(f"Predictions saved to {filename}")

# %%
train_route = '../data/waiting_times_train.csv'
validation_route = '../data/waiting_times_X_test_val.csv'
test_route = '../data/waiting_times_X_test_final.csv'
weather_route = '../data/weather_data.csv'

train_file = pd.read_csv(train_route)
validation_file = pd.read_csv(validation_route)
test_file = pd.read_csv(test_route)
weather_file = pd.read_csv(weather_route)

# %%
X_train = train_file.copy()
X_train['DATETIME'] = pd.to_datetime(X_train['DATETIME'], errors='coerce')

weather_file['DATETIME'] = pd.to_datetime(weather_file['DATETIME'], errors='coerce')
weather_file = weather_file.fillna(0)

X_train = pd.merge(X_train, weather_file, on='DATETIME', how='left')
X_train = pd.get_dummies(X_train, columns=['ENTITY_DESCRIPTION_SHORT'], drop_first=True, dtype=int)
X_train['year'] = X_train['DATETIME'].dt.year
X_train['month'] = X_train['DATETIME'].dt.month
X_train['day'] = X_train['DATETIME'].dt.day
X_train['hour'] = X_train['DATETIME'].dt.hour
X_train['minute'] = X_train['DATETIME'].dt.minute

X_train['TIME_TO_PARADE_1'] = X_train['TIME_TO_PARADE_1'].fillna(250)
X_train['TIME_TO_PARADE_2'] = X_train['TIME_TO_PARADE_2'].fillna(0)

X_train = X_train.sort_values(by='DATETIME')
X_train['rain_1h__6'] = X_train['rain_1h'].shift(-6)
X_train['rain_1h__3'] = X_train['rain_1h'].shift(-3)

X_train['snow_1h__6'] = X_train['snow_1h'].shift(-6)
X_train['snow_1h__3'] = X_train['snow_1h'].shift(-3)

print(X_train.head())

# Fill NaNs by column
for col in X_train.select_dtypes(include=['number']).columns:
    # Compute mean and std of non-NaN values
    mean = X_train[col].mean()
    std = X_train[col].std()
    
    # Find number of NaNs
    n_nan = X_train[col].isna().sum()
    
    # Generate random numbers for NaNs
    random_values = np.random.normal(loc=mean, scale=std, size=n_nan)
    
    # Fill NaNs
    X_train.loc[X_train[col].isna(), col] = random_values

X_train = X_train.sort_index()
y_train = X_train['WAIT_TIME_IN_2H']
X_train = X_train.select_dtypes(include=['number']).drop(columns=['WAIT_TIME_IN_2H','pressure', 'minute','dew_point'])
# Out:
#                  DATETIME  ADJUST_CAPACITY  DOWNTIME  CURRENT_WAIT_TIME  \
# 5927  2018-10-01 12:15:00            224.5         0                 20
# 8149  2018-10-01 12:15:00            756.0         0                 10
# 12003 2018-10-01 12:15:00            153.0         0                 25
# 13978 2018-10-01 12:30:00            153.0         0                 25
# 23029 2018-10-01 12:30:00            224.5         0                 20
#
#        TIME_TO_PARADE_1  TIME_TO_PARADE_2  TIME_TO_NIGHT_SHOW  \
# 5927              315.0              -5.0               465.0
# 8149              315.0              -5.0               465.0
# 12003             315.0              -5.0               465.0
# 13978             300.0             -20.0               450.0
# 23029             300.0             -20.0               450.0
#
#        WAIT_TIME_IN_2H   temp  dew_point  ...  \
# 5927              20.0  13.01       5.43  ...
# 8149              10.0  13.01       5.43  ...
# 12003             25.0  13.01       5.43  ...
# 13978             25.0  13.25       5.41  ...
# 23029             20.0  13.25       5.41  ...
#
#        ENTITY_DESCRIPTION_SHORT_Water Ride  year  month  day  hour  minute  \
# 5927                                     1  2018     10    1    12      15
# 8149                                     0  2018     10    1    12      15
# 12003                                    0  2018     10    1    12      15
# 13978                                    0  2018     10    1    12      30
# 23029                                    1  2018     10    1    12      30
#
#        rain_1h__6  rain_1h__3  snow_1h__6  snow_1h__3
# 5927       0.1239      0.1226         0.0         0.0
# 8149       0.1239      0.1226         0.0         0.0
# 12003      0.1239      0.1226         0.0         0.0
# 13978      0.1252      0.1239         0.0         0.0
# 23029      0.1252      0.1239         0.0         0.0
#
# [5 rows x 28 columns]

# %%
optimized_estimators = 4500
'''max_score = float('-inf')
for n in range(100, 5000, 100):
    model = XGBRegressor(n_estimators=n, learning_rate=0.1)
    scores = cross_val_score(model, X_train, y_train, scoring='neg_root_mean_squared_error', cv=5)
    score_mean = scores.mean()
    print(f"n_estimators: {n}, CV Mean RMSE: {-score_mean}")
    if score_mean > max_score:
        optimized_estimators = n
        max_score = score_mean'''



model = LGBMRegressor(n_estimators=optimized_estimators, learning_rate=0.004, random_state=10)
scores = cross_val_score(model, X_train, y_train, scoring='neg_root_mean_squared_error', cv=5)
print(scores.mean(), scores.std())
model.fit(X_train, y_train)

y_pred = model.predict(X_train)
evaluate_model(y_train, y_pred)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003674 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3511
# [LightGBM] [Info] Number of data points in the train set: 29614, number of used features: 23
# [LightGBM] [Info] Start training from score 23.677484
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001708 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3502
# [LightGBM] [Info] Number of data points in the train set: 29614, number of used features: 23
# [LightGBM] [Info] Start training from score 23.534646
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004092 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3508
# [LightGBM] [Info] Number of data points in the train set: 29614, number of used features: 23
# [LightGBM] [Info] Start training from score 23.610792
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003539 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3496
# [LightGBM] [Info] Number of data points in the train set: 29615, number of used features: 23
# [LightGBM] [Info] Start training from score 23.645788
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004207 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3502
# [LightGBM] [Info] Number of data points in the train set: 29615, number of used features: 23
# [LightGBM] [Info] Start training from score 23.559683
# -7.811376411796891 0.1458544959459539
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006088 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3508
# [LightGBM] [Info] Number of data points in the train set: 37018, number of used features: 23
# [LightGBM] [Info] Start training from score 23.605678
#                 Model Evaluation Metrics:
# Mean Absolute Error (MAE): 5.33386552042352
# Root Mean Squared Error (RMSE): 7.050940103119196
# R-squared (R2 ): 0.7562673967101801

# %%
X_val = test_file.copy()
X_val['DATETIME'] = pd.to_datetime(X_val['DATETIME'], errors='coerce')

X_val = pd.merge(X_val, weather_file, on='DATETIME', how='left')
X_val = pd.get_dummies(X_val, columns=['ENTITY_DESCRIPTION_SHORT'], drop_first=True, dtype=int)
X_val['year'] = X_val['DATETIME'].dt.year
X_val['month'] = X_val['DATETIME'].dt.month
X_val['day'] = X_val['DATETIME'].dt.day
X_val['hour'] = X_val['DATETIME'].dt.hour
X_val['minute'] = X_val['DATETIME'].dt.minute

X_val['TIME_TO_PARADE_1'] = X_val['TIME_TO_PARADE_1'].fillna(250)
X_val['TIME_TO_PARADE_2'] = X_val['TIME_TO_PARADE_2'].fillna(0)

X_val = X_val.sort_values(by='DATETIME')
X_val['rain_1h__6'] = X_val['rain_1h'].shift(-6)
X_val['rain_1h__3'] = X_val['rain_1h'].shift(-3)

X_val['snow_1h__6'] = X_val['snow_1h'].shift(-6)
X_val['snow_1h__3'] = X_val['snow_1h'].shift(-3)

# Fill NaNs by column
for col in X_val.select_dtypes(include=['number']).columns:
    # Compute mean and std of non-NaN values
    mean = X_val[col].mean()
    std = X_val[col].std()
    
    # Find number of NaNs
    n_nan = X_val[col].isna().sum()
    
    # Generate random numbers for NaNs
    random_values = np.random.normal(loc=mean, scale=std, size=n_nan)
    
    # Fill NaNs
    X_val.loc[X_val[col].isna(), col] = random_values

X_val = X_val.sort_index()
X_val = X_val.select_dtypes(include=['number']).drop(columns=['pressure', 'minute','dew_point'])

# %%
y_pred_final_lgbm = model.predict(X_val)

# %%
y_pred = (y_pred_final + y_pred_final_xgb+ y_pred_final_lgbm) / 3
generate_csv(test_file, y_pred)
# Out:
# Predictions saved to ../outpu_final/TEST_cat_boost.csv
